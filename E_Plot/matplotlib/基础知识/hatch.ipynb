# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 30))
ax1 = plt.subplot(911)
ax1.bar(range(1, 5), range(1, 5), color='red',
        hatch="/") # 纹理设置

ax2 = plt.subplot(912)
ax2.bar(range(1, 5), range(1, 5), color='red', hatch="//")

ax3 = plt.subplot(913)
ax3.bar(range(1, 5), range(1, 5), color='red', hatch="+")

ax4 = plt.subplot(914)
ax4.bar(range(1, 5), range(1, 5), color='red', hatch="-")

ax5 = plt.subplot(915)
ax5.bar(range(1, 5), range(1, 5), color='red', hatch="x")

ax6 = plt.subplot(916)
ax6.bar(range(1, 5), range(1, 5), color='red', hatch="*")

ax7 = plt.subplot(917)
ax7.bar(range(1, 5), range(1, 5), color='red', hatch=".")

ax8 = plt.subplot(918)
ax8.bar(range(1, 5), range(1, 5), color='red', hatch="o")

ax9 = plt.subplot(918)
ax9.bar(range(1, 5), range(1, 5), color='red', hatch="O")

plt.show()
# Out:
# <ipython-input-15-476bb57546e8>:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax9 = plt.subplot(918)
