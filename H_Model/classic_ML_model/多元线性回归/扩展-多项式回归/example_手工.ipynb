# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.uniform(-3, 3, size=100)
X = x.reshape(-1, 1)
y = 0.5 * x ** 2 + x + 2 + np.random.normal(0, 1, 100)

# %%
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_predict = lin_reg.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color='r')  # 线性函数拟合效果较差
plt.show()

# %%
X2 = np.hstack([X, X ** 2])  # 添加一个特征(二次项)
lin_reg2 = LinearRegression()  # 再使用多元线性回归进行拟合
lin_reg2.fit(X2, y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color='red')  # 必须对x进行排序,因为x是随机生成的
plt.show()

# %%
lin_reg2.coef_  # 解释变量(X , X**2)的系数
# Out:
# array([1.07744921, 0.55261794])

# %%
print(lin_reg2.coef_[0])  # 一次项系数
print(lin_reg2.coef_[1])  # 二次项系数
# Out:
# 1.077449212428911
# 0.5526179367276696

# %%
lin_reg2.intercept_  # 截距
# Out:
# 1.863560905714038

# %% [markdown]
# 故最终方程为$ y = \mathrm{lin\_reg2.coef\_[0]} x^2 + \mathrm{lin\_reg2.coef\_[1]} x^1 + \mathrm{lin\_reg2.intercept\_} $
