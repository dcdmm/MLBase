# %%
import numpy as np

# %%
x = np.array([[[0, 1], [2, 3]],
              [[4, 5], [6, 7]]])
x
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
np.swapaxes(x, 0, 1)  # 交换维度0和维度1
# Out:
# array([[[0, 1],
#         [4, 5]],
#
#        [[2, 3],
#         [6, 7]]])

# %%
x  # x不变
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
np.swapaxes(x, 0, 2)
# Out:
# array([[[0, 4],
#         [2, 6]],
#
#        [[1, 5],
#         [3, 7]]])
