# %%
import numpy as np
import  matplotlib.pyplot as plt
import  seaborn as sns
'''
def set_palette(palette, n_colors=None, desat=None, color_codes=False):
    """Set the matplotlib color cycle using a seaborn palette.

    Parameters
    ----------
    palette : seaborn color paltte | matplotlib colormap | hls | husl
        Palette definition. Should be something that :func:`color_palette`
        can process.
    n_colors : int
        Number of colors in the cycle. The default number of colors will depend
        on the format of ``palette``, see the :func:`color_palette`
        documentation for more information.
    desat : float
        Proportion to desaturate each color by.
'''
sns.set_palette('hls', n_colors=3) # 设置全局调色盘样式
fig = plt.figure(figsize=(10, 25))

with sns.color_palette("Set1", 8):
    # 设置局部调色盘样式,用with做代码块区分
    ax1 = plt.subplot(311)
    plt.plot(np.c_[np.zeros(8), np.arange(8)].T)

ax2 = plt.subplot(312)
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(7):
        plt.plot(x, np.sin(x + i * 0.5) * (7 - i) * flip)
sinplot()

data = np.random.normal(size=(20, 6)) + np.arange(6)/2
ax3 = plt.subplot(313)
ax3.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x26cd82a70f0>,
#  <matplotlib.lines.Line2D at 0x26cd82a7240>,
#  <matplotlib.lines.Line2D at 0x26cd82a7390>,
#  <matplotlib.lines.Line2D at 0x26cd7eafdd8>,
#  <matplotlib.lines.Line2D at 0x26cd82a75f8>,
#  <matplotlib.lines.Line2D at 0x26cd82a7748>]
