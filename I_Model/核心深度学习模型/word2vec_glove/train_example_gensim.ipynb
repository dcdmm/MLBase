# %%
import pandas as pd
from gensim.models import Word2Vec
import jieba

# %%
# 读取数据集
train = pd.read_csv('../../../Other/datasets/cnews/train.tsv', sep='\t', header=None, names=['label', 'content'])
val = pd.read_csv('../../../Other/datasets/cnews/dev.tsv', sep='\t', header=None, names=['label', 'content'])
test = pd.read_csv('../../../Other/datasets/cnews/test.tsv', sep='\t', header=None, names=['label', 'content'])

# %%
train.head()
# Out:
#   label                                            content
# 0    体育  马晓旭意外受伤让国奥警惕 无奈大雨格外青睐殷家军记者傅亚雨沈阳报道 来到沈阳，国奥队依然没有...
# 1    体育  商瑞华首战复仇心切 中国玫瑰要用美国方式攻克瑞典多曼来了，瑞典来了，商瑞华首战求3分的信心也...
# 2    体育  冠军球队迎新欢乐派对 黄旭获大奖张军赢下PK赛新浪体育讯12月27日晚，“冠军高尔夫球队迎新...
# 3    体育  辽足签约危机引注册难关 高层威逼利诱合同笑里藏刀新浪体育讯2月24日，辽足爆发了集体拒签风波...
# 4    体育  揭秘谢亚龙被带走：总局电话骗局 复制南杨轨迹体坛周报特约记者张锐北京报道  谢亚龙已经被公安...

# %%
def sentence_cut(x):
    x = jieba.lcut(x)
    x = " ".join(x)
    return x

# %%
train['content'] = train['content'].map(lambda x: sentence_cut(x))
val['content'] = val['content'].map(lambda x: sentence_cut(x))
test['content'] = test['content'].map(lambda x: sentence_cut(x))
train.head()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\duanm\AppData\Local\Temp\jieba.cache
# Loading model cost 1.006 seconds.
# Prefix dict has been built successfully.
#   label                                            content
# 0    体育  马晓旭 意外 受伤 让 国奥 警惕   无奈 大雨 格外 青睐 殷家 军 记者 傅亚雨 沈阳...
# 1    体育  商瑞华 首战 复仇 心切   中国 玫瑰 要 用 美国 方式 攻克 瑞典 多曼来 了 ， 瑞...
# 2    体育  冠军 球队 迎新 欢乐 派对   黄旭获 大奖 张军 赢 下 PK 赛 新浪 体育讯 12 ...
# 3    体育  辽足 签约 危机 引 注册 难关   高层 威逼利诱 合同 笑里藏刀 新浪 体育讯 2 月 ...
# 4    体育  揭秘 谢亚龙 被 带走 ： 总局 电话 骗局   复制 南杨 轨迹 体坛周报 特约记者 张锐...

# %%
sentences_train = [document.split(' ') for document in train['content'].values]

# %% [markdown]
# ### 训练word2vec

# %%
model = Word2Vec(sentences=sentences_train,
                 # Dimensionality of the word vectors.
                 vector_size=200,  # 默认:100
                 # Maximum distance between the current and predicted word within a sentence.
                 window=5,  # 默认:5
                 # Ignores all words with total frequency lower than this.
                 min_count=2,  # 默认5
                 # Training algorithm: 1 for skip-gram; otherwise CBOW.
                 sg=0,  # 默认:0
                 # If 1, hierarchical softmax will be used for model training.
                 # If 0, and `negative` is non-zero, negative sampling will be used.
                 hs=0,  # 默认0
                 # If > 0, negative sampling will be used, the int for negative specifies how many "noise words"
                 # should be drawn (usually between 5-20).
                 # If set to 0, no negative sampling is used.
                 negative=5,  # 默认:5
                 # The initial learning rate.
                 alpha=0.025,  # 默认:0.025
                 # Learning rate will linearly drop to `min_alpha` as training progresses.
                 min_alpha=0.0001,  # 默认:0.0001,
                 # The threshold for configuring which higher-frequency words are randomly downsampled,
                 # useful range is (0, 1e-5).
                 sample=0.001,  # 默认:1e-3
                 # Number of iterations (epochs) over the corpus.
                 epochs=5,  # 默认:5
                 # If True, computes and stores loss value which can be retrieved using :meth: `~gensim.models.word2vec.Word2Vec.get_latest_training_loss`.
                 compute_loss=True,  # 默认:False
                 workers=8,
                 seed=2018
                 )

# %%
# Save the model. This saved model can be loaded again using load(), which supports online training and getting vectors for vocabulary words.
model.save('cnew_200')  # full model

# %%
# Store the input-hidden weight matrix in the same format used by the original C word2vec-tool, for compatibility.
model.wv.save_word2vec_format("cnew_200.txt")  # KeyedVectors(不支持进一步训练)

# %%
# 词表
model.wv.key_to_index
# Out:
# {'，': 0,
#  '的': 1,
#  '。': 2,
#  '': 3,
#  '在': 4,
#  '、': 5,
#  '了': 6,
#  '是': 7,
#  '“': 8,
#  '”': 9,
#  '和': 10,
#  '：': 11,
#  '也': 12,
#  '有': 13,
#  '》': 14,
#  '《': 15,
#  ')': 16,
#  '(': 17,
#  '我': 18,
#  '他': 19,
#  '都': 20,
#  '\xa0': 21,
#  '中': 22,
#  '将': 23,
#  '月': 24,
#  '就': 25,
#  '我们': 26,
#  '对': 27,
#  '年': 28,
#  '为': 29,
#  '上': 30,
#  '一个': 31,
#  '与': 32,
#  '不': 33,
#  '-': 34,
#  '到': 35,
#  '这': 36,
#  '而': 37,
#  '中国': 38,
#  '会': 39,
#  '但': 40,
#  '说': 41,
#  '人': 42,
#  '可以': 43,
#  '基金': 44,
#  '日': 45,
#  '等': 46,
#  '你': 47,
#  '要': 48,
#  '很': 49,
#  '还': 50,
#  '？': 51,
#  '没有': 52,
#  '被': 53,
#  '让': 54,
#  '从': 55,
#  '自己': 56,
#  '后': 57,
#  '并': 58,
#  '他们': 59,
#  '市场': 60,
#  '这个': 61,
#  '更': 62,
#  '；': 63,
#  '已经': 64,
#  '以': 65,
#  '时': 66,
#  '表示': 67,
#  '多': 68,
#  '3': 69,
#  '个': 70,
#  '公司': 71,
#  '美国': 72,
#  '2': 73,
#  '能': 74,
#  '—': 75,
#  '1': 76,
#  '记者': 77,
#  '学生': 78,
#  '时间': 79,
#  '游戏': 80,
#  '分': 81,
#  '就是': 82,
#  '北京': 83,
#  '可能': 84,
#  '进行': 85,
#  '地': 86,
#  '投资': 87,
#  '最': 88,
#  '她': 89,
#  '好': 90,
#  '来': 91,
#  '大': 92,
#  '！': 93,
#  '目前': 94,
#  '5': 95,
#  '新': 96,
#  '问题': 97,
#  '如果': 98,
#  '现在': 99,
#  '电影': 100,
#  '10': 101,
#  '.': 102,
#  '又': 103,
#  '4': 104,
#  '给': 105,
#  '下': 106,
#  '一些': 107,
#  '发展': 108,
#  '做': 109,
#  '但是': 110,
#  '因为': 111,
#  '把': 112,
#  '开始': 113,
#  '于': 114,
#  '/': 115,
#  '项目': 116,
#  '很多': 117,
#  '银行': 118,
#  '非常': 119,
#  '这样': 120,
#  '认为': 121,
#  '这些': 122,
#  '着': 123,
#  '还是': 124,
#  '比赛': 125,
#  '它': 126,
#  '去': 127,
#  '工作': 128,
#  '留学': 129,
#  '成为': 130,
#  '6': 131,
#  '对于': 132,
#  '元': 133,
#  '企业': 134,
#  '需要': 135,
#  '其': 136,
#  '大学': 137,
#  '经济': 138,
#  '今年': 139,
#  '通过': 140,
#  '不是': 141,
#  '里': 142,
#  '选择': 143,
#  '出现': 144,
#  '房地产': 145,
#  '可': 146,
#  '由': 147,
#  '同时': 148,
#  '7': 149,
#  '前': 150,
#  '情况': 151,
#  '时候': 152,
#  '或': 153,
#  '8': 154,
#  '这种': 155,
#  '国际': 156,
#  '新浪': 157,
#  '已': 158,
#  '以及': 159,
#  '及': 160,
#  '据': 161,
#  '该': 162,
#  '国家': 163,
#  '发现': 164,
#  '只': 165,
#  '们': 166,
#  '则': 167,
#  '所以': 168,
#  '却': 169,
#  '之后': 170,
#  '玩家': 171,
#  '其中': 172,
#  '用': 173,
#  '向': 174,
#  '9': 175,
#  '看': 176,
#  '不过': 177,
#  '高': 178,
#  '研究': 179,
#  '再': 180,
#  '12': 181,
#  '得': 182,
#  '什么': 183,
#  '大家': 184,
#  '比': 185,
#  '所': 186,
#  '一': 187,
#  '希望': 188,
#  '亿元': 189,
#  '过': 190,
#  '小': 191,
#  '作为': 192,
#  '想': 193,
#  '主要': 194,
#  '还有': 195,
#  '方面': 196,
#  '活动': 197,
#  '申请': 198,
#  '虽然': 199,
#  '·': 200,
#  ',': 201,
#  '产品': 202,
#  '影响': 203,
#  '设计': 204,
#  '出': 205,
#  '要求': 206,
#  '由于': 207,
#  '比较': 208,
#  '重要': 209,
#  '包括': 210,
#  '提供': 211,
#  '11': 212,
#  '生活': 213,
#  '能够': 214,
#  '不会': 215,
#  '不同': 216,
#  '获得': 217,
#  '城市': 218,
#  '学校': 219,
#  '一定': 220,
#  '一直': 221,
#  '上海': 222,
#  '…': 223,
#  '导演': 224,
#  '世界': 225,
#  '英国': 226,
#  '2009': 227,
#  '其他': 228,
#  '觉得': 229,
#  '表现': 230,
#  '得到': 231,
#  '价格': 232,
#  '才': 233,
#  '政策': 234,
#  '相关': 235,
#  '应该': 236,
#  '而且': 237,
#  '不能': 238,
#  '进入': 239,
#  '合作': 240,
#  '最后': 241,
#  '一种': 242,
#  '了解': 243,
#  '资金': 244,
#  '显示': 245,
#  '国内': 246,
#  '20': 247,
#  '达到': 248,
#  '政府': 249,
#  '像': 250,
#  '图': 251,
#  '那': 252,
#  '因此': 253,
#  '内': 254,
#  '看到': 255,
#  '超过': 256,
#  '只有': 257,
#  '教育': 258,
#  '今天': 259,
#  '为了': 260,
#  '方式': 261,
#  '2008': 262,
#  '能力': 263,
#  '土地': 264,
#  '数据': 265,
#  '知道': 266,
#  '跟': 267,
#  '专业': 268,
#  '根据': 269,
#  '消息': 270,
#  '报道': 271,
#  '管理': 272,
#  '计划': 273,
#  '机会': 274,
#  '当': 275,
#  '一样': 276,
#  '那么': 277,
#  '球队': 278,
#  '甚至': 279,
#  '开发商': 280,
#  '影片': 281,
#  '开发': 282,
#  '称': 283,
#  '一次': 284,
#  '特别': 285,
#  '来说': 286,
#  '其实': 287,
#  '搭配': 288,
#  '部分': 289,
#  '较': 290,
#  '之': 291,
#  '这是': 292,
#  '未来': 293,
#  '万': 294,
#  '30': 295,
#  '继续': 296,
#  '所有': 297,
#  '增长': 298,
#  '香港': 299,
#  '或者': 300,
#  '增加': 301,
#  '万元': 302,
#  '至': 303,
#  '地产': 304,
#  '打': 305,
#  '最大': 306,
#  '关注': 307,
#  '学习': 308,
#  '火箭': 309,
#  '机构': 310,
#  '去年': 311,
#  '拍摄': 312,
#  '销售': 313,
#  '地方': 314,
#  '两个': 315,
#  '曾': 316,
#  '行业': 317,
#  '使用': 318,
#  '房价': 319,
#  '号': 320,
#  '移民': 321,
#  '呢': 322,
#  '发生': 323,
#  '之前': 324,
#  '时尚': 325,
#  '过程': 326,
#  '拍': 327,
#  '没': 328,
#  '只是': 329,
#  '日本': 330,
#  '如何': 331,
#  '孩子': 332,
#  '有关': 333,
#  '贷款': 334,
#  '介绍': 335,
#  '建设': 336,
#  '次': 337,
#  '以上': 338,
#  '是否': 339,
#  '15': 340,
#  '接受': 341,
#  '仍': 342,
#  '支持': 343,
#  '中心': 344,
#  '完成': 345,
#  '专家': 346,
#  '当时': 347,
#  '人民币': 348,
#  '全国': 349,
#  '月份': 350,
#  '存在': 351,
#  '不少': 352,
#  '感觉': 353,
#  '拥有': 354,
#  '带来': 355,
#  '全球': 356,
#  '交易': 357,
#  '媒体': 358,
#  '留学生': 359,
#  '发行': 360,
#  '篮板': 361,
#  '除了': 362,
#  '服务': 363,
#  '空间': 364,
#  '必须': 365,
#  '最终': 366,
#  '环境': 367,
#  '成功': 368,
#  '风险': 369,
#  '喜欢': 370,
#  '社会': 371,
#  '球员': 372,
#  '另外': 373,
#  '准备': 374,
#  '原因': 375,
#  '以来': 376,
#  '观众': 377,
#  '正在': 378,
#  '调整': 379,
#  '一起': 380,
#  '上涨': 381,
#  '参加': 382,
#  '直接': 383,
#  '使': 384,
#  '吧': 385,
#  '公布': 386,
#  '这次': 387,
#  '客户': 388,
#  '2010': 389,
#  '更加': 390,
#  '约': 391,
#  '角色': 392,
#  '需求': 393,
#  '投资者': 394,
#  '均': 395,
#  '完全': 396,
#  '技术': 397,
#  '人士': 398,
#  '地区': 399,
#  '一般': 400,
#  '系统': 401,
#  '考虑': 402,
#  '台湾': 403,
#  '楼市': 404,
#  '之间': 405,
#  '整个': 406,
#  '一位': 407,
#  '?': 408,
#  '不断': 409,
#  '文化': 410,
#  '个人': 411,
#  '分别': 412,
#  '风格': 413,
#  '人们': 414,
#  '点': 415,
#  '信息': 416,
#  '家': 417,
#  '历史': 418,
#  '决定': 419,
#  '提高': 420,
#  ':': 421,
#  '评论': 422,
#  '品牌': 423,
#  '随着': 424,
#  '推出': 425,
#  '您': 426,
#  '实现': 427,
#  '具有': 428,
#  '来自': 429,
#  '透露': 430,
#  '现场': 431,
#  '占': 432,
#  '之一': 433,
#  '岁': 434,
#  '它们': 435,
#  '住房': 436,
#  '任何': 437,
#  '人员': 438,
#  '左右': 439,
#  '票房': 440,
#  '债券': 441,
#  '一年': 442,
#  '区域': 443,
#  '有些': 444,
#  '关系': 445,
#  '吗': 446,
#  '集团': 447,
#  '指出': 448,
#  '过去': 449,
#  '告诉': 450,
#  '帮助': 451,
#  '最近': 452,
#  '当然': 453,
#  '出来': 454,
#  '签证': 455,
#  '这一': 456,
#  '讯': 457,
#  '不仅': 458,
#  '资产': 459,
#  '优势': 460,
#  '结束': 461,
#  '起来': 462,
#  '股票': 463,
#  '此次': 464,
#  '下降': 465,
#  '拿': 466,
#  '如': 467,
#  '组图': 468,
#  '形成': 469,
#  '结果': 470,
#  '成绩': 471,
#  '明显': 472,
#  '国外': 473,
#  '购买': 474,
#  '第一': 475,
#  '美元': 476,
#  '比例': 477,
#  '价值': 478,
#  '走': 479,
#  '）': 480,
#  '比如': 481,
#  '娱乐': 482,
#  '’': 483,
#  '穿': 484,
#  '这里': 485,
#  '收益': 486,
#  '产生': 487,
#  '任务': 488,
#  '规定': 489,
#  '这么': 490,
#  '基本': 491,
#  '造成': 492,
#  '作品': 493,
#  '调查': 494,
#  '参与': 495,
#  '各': 496,
#  '16': 497,
#  '来看': 498,
#  '我要': 499,
#  '无法': 500,
#  '请': 501,
#  '科学家': 502,
#  '18': 503,
#  '一下': 504,
#  '达': 505,
#  '变化': 506,
#  '分析': 507,
#  '同样': 508,
#  '正式': 509,
#  '故事': 510,
#  '13': 511,
#  '建筑': 512,
#  '代表': 513,
#  '主持人': 514,
#  '水平': 515,
#  '很大': 516,
#  '东西': 517,
#  '朋友': 518,
#  '一点': 519,
#  '业务': 520,
#  '楼盘': 521,
#  '规模': 522,
#  '课程': 523,
#  '模式': 524,
#  '+': 525,
#  '2007': 526,
#  '采访': 527,
#  '上市': 528,
#  '热火': 529,
#  '成': 530,
#  '家庭': 531,
#  '买': 532,
#  '14': 533,
#  '按照': 534,
#  '太': 535,
#  '此外': 536,
#  '取得': 537,
#  '持续': 538,
#  '许多': 539,
#  '保持': 540,
#  '进一步': 541,
#  '部门': 542,
#  '大量': 543,
#  '关于': 544,
#  '海外': 545,
#  '最高': 546,
#  '（': 547,
#  '标准': 548,
#  '事情': 549,
#  '导致': 550,
#  '100': 551,
#  '‘': 552,
#  '外': 553,
#  '仅': 554,
#  '报告': 555,
#  '每': 556,
#  '并且': 557,
#  '提出': 558,
#  '建议': 559,
#  '利用': 560,
#  '奇才': 561,
#  '平方米': 562,
#  '一场': 563,
#  '地球': 564,
#  '系列': 565,
#  '经过': 566,
#  '加拿大': 567,
#  '真正': 568,
#  '各种': 569,
#  '内容': 570,
#  '防守': 571,
#  '怎么': 572,
#  '成交': 573,
#  '的话': 574,
#  '功能': 575,
#  '自': 576,
#  '亿': 577,
#  '采用': 578,
#  '住宅': 579,
#  '发布': 580,
#  '稳定': 581,
#  '压力': 582,
#  '演员': 583,
#  '再次': 584,
#  '名': 585,
#  '只要': 586,
#  '尽管': 587,
#  '昨日': 588,
#  '简单': 589,
#  '受到': 590,
#  '面积': 591,
#  '相对': 592,
#  '面对': 593,
#  '秒': 594,
#  '总': 595,
#  '17': 596,
#  '效果': 597,
#  '越来越': 598,
#  '近': 599,
#  '科技': 600,
#  '目标': 601,
#  '期间': 602,
#  '首次': 603,
#  '如此': 604,
#  '低': 605,
#  '作用': 606,
#  '谁': 607,
#  '几乎': 608,
#  '自然': 609,
#  '只能': 610,
#  '每个': 611,
#  '举行': 612,
#  '商业': 613,
#  '连续': 614,
#  '更是': 615,
#  '进攻': 616,
#  '整体': 617,
#  '规划': 618,
#  '状态': 619,
#  '陈水扁': 620,
#  '因': 621,
#  '消费': 622,
#  '最好': 623,
#  '房子': 624,
#  '找': 625,
#  '经验': 626,
#  '那些': 627,
#  '起': 628,
#  '三': 629,
#  '钱': 630,
#  '语言': 631,
#  '50': 632,
#  '以后': 633,
#  '条件': 634,
#  '助攻': 635,
#  '加强': 636,
#  '然后': 637,
#  '旗下': 638,
#  '明星': 639,
#  '第': 640,
#  '澳大利亚': 641,
#  '小时': 642,
#  '收入': 643,
#  '才能': 644,
#  '手机': 645,
#  '经历': 646,
#  '最新': 647,
#  '类': 648,
#  '平均': 649,
#  '组织': 650,
#  '以下': 651,
#  '我国': 652,
#  '不要': 653,
#  '适合': 654,
#  '仍然': 655,
#  '即': 656,
#  '成本': 657,
#  '安全': 658,
#  '分钟': 659,
#  '相信': 660,
#  '当地': 661,
#  '出国': 662,
#  '全部': 663,
#  '职业': 664,
#  '有限公司': 665,
#  '近期': 666,
#  '预期': 667,
#  '依然': 668,
#  '找到': 669,
#  '领域': 670,
#  '此前': 671,
#  '另': 672,
#  '事件': 673,
#  '25': 674,
#  '解决': 675,
#  '上映': 676,
#  '赛季': 677,
#  '尤其': 678,
#  '制作': 679,
#  '相比': 680,
#  '首先': 681,
#  '不错': 682,
#  '十分': 683,
#  '每年': 684,
#  '基础': 685,
#  '容易': 686,
#  '共同': 687,
#  '质量': 688,
#  '未': 689,
#  '相当': 690,
#  '21': 691,
#  '确定': 692,
#  '肯定': 693,
#  '经理': 694,
#  '对手': 695,
#  '改变': 696,
#  '单位': 697,
#  '利率': 698,
#  '联盟': 699,
#  '提升': 700,
#  '19': 701,
#  '双方': 702,
#  '问': 703,
#  '命中': 704,
#  '学院': 705,
#  '积极': 706,
#  '内地': 707,
#  '广州': 708,
#  '体育讯': 709,
#  '型基金': 710,
#  '正': 711,
#  '房': 712,
#  '为什么': 713,
#  '下跌': 714,
#  '程度': 715,
#  '现象': 716,
#  '预计': 717,
#  '成立': 718,
#  '全面': 719,
#  '爱': 720,
#  '带': 721,
#  '努力': 722,
#  '金融': 723,
#  '便': 724,
#  '投': 725,
#  '三分': 726,
#  '24': 727,
#  '新闻': 728,
#  '重点': 729,
#  '传统': 730,
#  '吸引': 731,
#  '级': 732,
#  '因素': 733,
#  '交流': 734,
#  '人类': 735,
#  '而是': 736,
#  '日前': 737,
#  '统计': 738,
#  '一部': 739,
#  '法国': 740,
#  '宣布': 741,
#  '真的': 742,
#  '突破': 743,
#  '加上': 744,
#  '近日': 745,
#  '减少': 746,
#  '指数': 747,
#  '负责人': 748,
#  '似乎': 749,
#  '里面': 750,
#  '背景': 751,
#  '曾经': 752,
#  '位于': 753,
#  '22': 754,
#  '针对': 755,
#  '数量': 756,
#  '款': 757,
#  '阶段': 758,
#  '几个': 759,
#  '时代': 760,
#  '速度': 761,
#  '确实': 762,
#  '应': 763,
#  '控制': 764,
#  '信用卡': 765,
#  '大幅': 766,
#  '艺术': 767,
#  '黑色': 768,
#  '网站': 769,
#  '对此': 770,
#  '以前': 771,
#  '即将': 772,
#  '先生': 773,
#  '费用': 774,
#  '有人': 775,
#  '排名': 776,
#  '韩国': 777,
#  '消费者': 778,
#  '型': 779,
#  '万科': 780,
#  '拿到': 781,
#  '受': 782,
#  '网友': 783,
#  '造型': 784,
#  '然而': 785,
#  '位置': 786,
#  '行为': 787,
#  '戏': 788,
#  '论坛': 789,
#  '2011': 790,
#  '家长': 791,
#  '属于': 792,
#  '得分': 793,
#  '不到': 794,
#  '业主': 795,
#  '23': 796,
#  '实施': 797,
#  '科学': 798,
#  '地块': 799,
#  '如今': 800,
#  '深圳': 801,
#  '人物': 802,
#  '证明': 803,
#  '太阳': 804,
#  '打造': 805,
#  '至少': 806,
#  '照片': 807,
#  '二': 808,
#  '重新': 809,
#  '一家': 810,
#  '最佳': 811,
#  '推动': 812,
#  '产业': 813,
#  '挑战': 814,
#  '日电': 815,
#  '>': 816,
#  '建立': 817,
#  '詹姆斯': 818,
#  '平台': 819,
#  '那个': 820,
#  '这部': 821,
#  '色彩': 822,
#  '湖人': 823,
#  '场': 824,
#  '考试': 825,
#  '事': 826,
#  '大型': 827,
#  '巨大': 828,
#  '视频': 829,
#  '保护': 830,
#  '范围': 831,
#  '昨天': 832,
#  '面临': 833,
#  '上升': 834,
#  '上半年': 835,
#  '一名': 836,
#  '众多': 837,
#  '享受': 838,
#  '体验': 839,
#  '将会': 840,
#  '金融危机': 841,
#  '世纪': 842,
#  '完美': 843,
#  '多少': 844,
#  '欧洲': 845,
#  '创新': 846,
#  '王': 847,
#  '科比': 848,
#  '经典': 849,
#  '老师': 850,
#  '有效': 851,
#  '米': 852,
#  '领先': 853,
#  '处理': 854,
#  '当前': 855,
#  '连': 856,
#  '且': 857,
#  '具体': 858,
#  '【': 859,
#  '强调': 860,
#  '快': 861,
#  '】': 862,
#  '处于': 863,
#  '26': 864,
#  '实际': 865,
#  '健康': 866,
#  '会议': 867,
#  '三个': 868,
#  '第一次': 869,
#  '天': 870,
#  '拿下': 871,
#  '后来': 872,
#  '倍': 873,
#  '就业': 874,
#  '网络': 875,
#  '副': 876,
#  '保障': 877,
#  '实际上': 878,
#  '长期': 879,
#  '业绩': 880,
#  '地震': 881,
#  '还要': 882,
#  '40': 883,
#  '公开': 884,
#  '动作': 885,
#  '同比': 886,
#  '需': 887,
#  '趋势': 888,
#  '绝对': 889,
#  '此': 890,
#  '按': 891,
#  '吃': 892,
#  '发挥': 893,
#  '更好': 894,
#  '资源': 895,
#  '即使': 896,
#  '保证': 897,
#  '截至': 898,
#  '普通': 899,
#  '姚明': 900,
#  '"': 901,
#  '安排': 902,
#  '讲': 903,
#  '第二': 904,
#  '本': 905,
#  '制度': 906,
#  '随后': 907,
#  '著名': 908,
#  '显得': 909,
#  '据悉': 910,
#  '大陆': 911,
#  '套': 912,
#  '某': 913,
#  '正是': 914,
#  '先': 915,
#  '合同': 916,
#  '年代': 917,
#  '非': 918,
#  '方法': 919,
#  '80': 920,
#  '注意': 921,
#  '无': 922,
#  '加入': 923,
#  '目的': 924,
#  '团队': 925,
#  '采取': 926,
#  '院校': 927,
#  '万平方米': 928,
#  '操作': 929,
#  '说明': 930,
#  '上述': 931,
#  '学费': 932,
#  '使得': 933,
#  '货币': 934,
#  '方案': 935,
#  '担心': 936,
#  '材料': 937,
#  '女性': 938,
#  '大部分': 939,
#  '一切': 940,
#  'A': 941,
#  '27': 942,
#  '体现': 943,
#  '大约': 944,
#  '负责': 945,
#  '28': 946,
#  '充满': 947,
#  '颜色': 948,
#  '期待': 949,
#  '终于': 950,
#  '感受': 951,
#  '理财产品': 952,
#  '核心': 953,
#  '主场': 954,
#  '位': 955,
#  '内线': 956,
#  '录取': 957,
#  '宣传': 958,
#  '类似': 959,
#  '关键': 960,
#  '住': 961,
#  '净值': 962,
#  '一款': 963,
#  '令': 964,
#  '教授': 965,
#  '啊': 966,
#  '办理': 967,
#  '促进': 968,
#  '信贷': 969,
#  '坚持': 970,
#  '多年': 971,
#  '60': 972,
#  '明年': 973,
#  '完': 974,
#  '限制': 975,
#  '主席': 976,
#  '两年': 977,
#  '解释': 978,
#  '版': 979,
#  '集中': 980,
#  '长': 981,
#  '做出': 982,
#  '经营': 983,
#  '综合': 984,
#  '提前': 985,
#  '女人': 986,
#  ']': 987,
#  '办法': 988,
#  '方向': 989,
#  '明确': 990,
#  '老': 991,
#  '房屋': 992,
#  '本身': 993,
#  '年轻': 994,
#  '变成': 995,
#  '主演': 996,
#  '创造': 997,
#  '生产': 998,
#  '扩大': 999,
#  ...}

# %%
# get numpy vector of a word
model.wv['方案']
# Out:
# array([ 5.9322506e-01, -1.4075698e+00,  8.6693859e-01, -9.6600515e-01,
#        -4.7815621e-01,  3.1963637e-01,  9.2254274e-02,  7.2466379e-01,
#        -3.8719168e-01, -1.0834543e+00,  2.9158115e-01, -2.3868439e-01,
#         7.5923443e-01,  1.0866537e-03,  2.7507706e+00, -1.1225307e+00,
#         8.3004880e-01,  6.8823677e-01,  1.6812716e-01, -1.2630341e+00,
#        -3.2953227e-01, -1.8835351e+00, -8.0532562e-03, -2.8475627e-02,
#        -2.4536330e-01,  6.8327111e-01,  9.6777427e-01, -4.4113743e-01,
#         3.1353557e+00,  2.5795727e+00, -1.0177273e+00,  2.3666617e-01,
#        -7.9416895e-01,  1.9296849e-01,  2.3040051e+00,  3.7113893e-01,
#        -1.3672287e+00,  1.5595134e+00,  1.0433791e+00,  3.0832997e-01,
#         2.0558093e+00, -2.9601581e+00,  7.8482151e-01, -5.5296445e-01,
#         2.7337825e-01, -1.7974573e+00,  6.9916807e-02, -1.7238606e+00,
#        -1.7326745e-01,  1.1214123e+00, -2.2292212e-01, -1.4287496e+00,
#        -8.7346584e-01, -1.5866026e+00, -4.0783310e-01,  2.3133293e-01,
#        -3.2626870e+00,  3.3040076e-02, -2.1843624e+00,  1.0838162e+00,
#         5.1669073e-01, -2.2647154e+00, -6.8548334e-01, -5.6995863e-01,
#         2.8578365e+00,  5.2347475e-01, -9.0579313e-01, -2.9876564e+00,
#         5.6634158e-01,  1.4313476e-01, -1.0905592e+00,  2.4233537e+00,
#         1.4429318e+00,  3.0030684e+00,  5.4303437e-01, -3.2327038e-01,
#         3.3949944e-01, -1.3856938e+00, -6.3792890e-01, -1.0011362e+00,
#         9.8486114e-01, -2.2293225e-01, -6.1316490e-01,  1.4023719e+00,
#        -4.8329264e-01, -4.4994539e-01, -1.1305037e+00,  4.7238162e-01,
#        -1.5119148e+00,  1.8735449e+00,  2.7915388e-01,  3.0527484e-01,
#        -9.4630694e-01, -6.8864316e-01,  3.2212200e+00, -5.9665793e-01,
#         3.9480785e-01,  2.5403923e-01,  2.1572134e-01, -2.0649853e-01,
#         1.6084710e-01, -3.2247692e-01,  1.7448485e-01,  4.9826163e-01,
#         3.2851818e-01,  4.9327293e-01, -1.0898070e+00,  4.7532356e-01,
#         1.1931224e+00,  4.6277973e-01,  9.8492157e-01,  3.4626360e+00,
#        -4.5957100e-01,  1.4769549e+00,  7.1849096e-01, -2.6609606e-01,
#         2.2516310e+00,  1.8437817e+00,  9.4399023e-01, -5.9543395e-01,
#        -3.2112804e-01, -2.9406643e+00,  8.2584314e-02,  6.6312474e-01,
#         4.4289032e-01, -2.2699435e+00,  6.8775284e-01,  2.4949684e+00,
#        -6.3582110e-01,  5.0073549e-02, -1.0376712e+00, -2.0286622e+00,
#         1.7439924e+00,  2.1240604e+00,  3.2473084e-01,  1.4119955e+00,
#        -1.4109776e+00,  7.5281210e-02, -4.7868755e-01, -4.0344191e-01,
#         1.5218359e+00, -6.3814729e-01,  1.5890024e+00,  1.2622596e+00,
#        -9.1434754e-02, -3.4079707e-01,  1.1625113e+00, -1.0891665e+00,
#         1.3615460e+00, -9.9547559e-01,  1.3209396e-02,  1.4931679e+00,
#        -1.7825744e+00,  1.8115686e-01, -1.1687262e-01, -8.4544760e-01,
#         5.6954747e-01,  9.4699502e-01,  1.9376253e+00,  2.3226326e+00,
#        -7.1820748e-01, -1.8291310e+00, -2.5111350e-01, -2.6218330e-02,
#        -2.6313317e+00,  1.6347743e+00, -1.2210666e+00,  1.0910537e-01,
#        -8.7715226e-01, -5.6932867e-01,  1.5974157e+00,  1.2104679e+00,
#        -1.2682004e+00, -2.2750099e-01, -9.5062190e-01, -1.2277157e+00,
#        -1.7796279e+00, -3.9650148e-01,  9.5272481e-02, -3.2627711e-01,
#        -1.2543958e+00,  1.1075047e+00, -1.5043890e-03, -2.0972593e+00,
#         3.9972764e-01,  2.3868712e-02,  1.5268377e+00,  3.7383643e-01,
#        -2.7331403e-01, -7.3391712e-01, -1.3516886e+00,  6.1121291e-01,
#        -2.8481871e-02, -8.5496616e-01, -1.3937912e+00,  2.4388257e-01,
#        -1.6838548e+00,  7.7102864e-01,  1.6663212e+00,  3.4258277e+00],
#       dtype=float32)

# %%
# Find the top-N most similar keys
sims = model.wv.most_similar('方案', topn=10)
sims
# Out:
# [('细则', 0.6278690099716187),
#  ('计划', 0.6158345341682434),
#  ('预案', 0.6070582270622253),
#  ('解决方案', 0.6036876440048218),
#  ('设计方案', 0.5521835088729858),
#  ('规划', 0.5518771409988403),
#  ('举措', 0.5470309257507324),
#  ('时间表', 0.5459707379341125),
#  ('新规', 0.5441619753837585),
#  ('步骤', 0.5423238277435303)]

# %%
# Compute cosine distance between two keys
model.wv.distance("方案", "计划")
# Out:
# 0.3841654062271118

# %% [markdown]
# ### 增量学习

# %%
sentences_val = [document.split(' ') for document in val['content'].values]

# Load a previously saved Word2Vec model.
model_new = Word2Vec.load("cnew_200")

# Build vocabulary from a sequence of sentences (can be a once-only generator stream).
model_new.build_vocab(sentences_val,
                      #  If true, the new words in `sentences` will be added to model's vocab.
                      update=True)
# Update the model's neural weights from a sequence of sentences
trained_word_count, raw_word_count = model_new.train(corpus_iterable=sentences_val, total_examples=model.corpus_count, epochs=model.epochs)

# %%
# 增量学习成功
model_new.wv.most_similar('方案', topn=10)
# Out:
# [('细则', 0.6041954159736633),
#  ('预案', 0.5758479237556458),
#  ('计划', 0.5653831362724304),
#  ('时间表', 0.5599968433380127),
#  ('解决方案', 0.5414493680000305),
#  ('实施方案', 0.533754825592041),
#  ('政策措施', 0.5297344326972961),
#  ('步骤', 0.5195085406303406),
#  ('设计方案', 0.5184329748153687),
#  ('新规', 0.5169488191604614)]
