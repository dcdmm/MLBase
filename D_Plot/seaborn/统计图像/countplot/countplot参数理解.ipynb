# %%
import seaborn as sns

sns.set(style="darkgrid")

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Show value counts for a single categorical variable:
ax = sns.countplot(x="class",  # 分组列"class"每种分组的计数
                   data=titanic)
ax
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x="class", data=titanic,
              palette='Set1')  # 通过调色盘为不同分组绘制不同颜色
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
v = sns.color_palette(palette=['pink', 'g', '#fac205'], n_colors=3, desat=0.9)  # 自定义颜色列表
sns.countplot(x="class", data=titanic,
              palette=v)  # 自定义调色盘颜色
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
# Show value counts for two categorical variables:
sns.countplot(x="class",
              hue="who",  # 指定第二个分组列为"sex"
              data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
# Plot the bars horizontally:
sns.countplot(y="class",  # 水平方向
              hue="who",
              data=titanic,
              palette='Set1')  # 通过调色盘为不同分组绘制不同颜色(第一个分组列颜色相同)
# Out:
# <AxesSubplot:xlabel='count', ylabel='class'>

# %%
sns.countplot(x="who", data=titanic,
              order=['woman', 'man', 'child'])  # 自定义分组顺序
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>
