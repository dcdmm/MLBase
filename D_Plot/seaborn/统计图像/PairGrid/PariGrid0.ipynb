# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Draw a scatterplot for each pairwise relationship:
g = sns.PairGrid(data=iris) # DataFrame
g = g.map(plt.scatter)
print(g.fig, len(g.fig.get_axes()), end='\n\n')
for i in g.fig.get_axes():
    print('title:', i.get_title())
    print('xlabel:', i.get_xlabel())
    print('ylabel:', i.get_ylabel())
    print('xlim:', i.get_xlim())
    print('ylim:', i.get_ylim())
    print('xticks:', i.get_xticks())
    print('xticklabels:', i.get_xticklabels(), end='\n\n')
# Out:
# Figure(720x720) 16
#
# title:
# xlabel:
# ylabel: sepal_length
# xlim: (4.12, 8.08)
# ylim: (4.12, 8.08)
# xticks: [4. 5. 6. 7. 8. 9.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (1.88, 4.5200000000000005)
# ylim: (4.12, 8.08)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (0.705, 7.195)
# ylim: (4.12, 8.08)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.01999999999999999, 2.62)
# ylim: (4.12, 8.08)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel: sepal_width
# xlim: (4.12, 8.08)
# ylim: (1.88, 4.5200000000000005)
# xticks: [4. 5. 6. 7. 8. 9.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (1.88, 4.5200000000000005)
# ylim: (1.88, 4.5200000000000005)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (0.705, 7.195)
# ylim: (1.88, 4.5200000000000005)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.01999999999999999, 2.62)
# ylim: (1.88, 4.5200000000000005)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel: petal_length
# xlim: (4.12, 8.08)
# ylim: (0.705, 7.195)
# xticks: [4. 5. 6. 7. 8. 9.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (1.88, 4.5200000000000005)
# ylim: (0.705, 7.195)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (0.705, 7.195)
# ylim: (0.705, 7.195)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: []
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.01999999999999999, 2.62)
# ylim: (0.705, 7.195)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: []
#
# title:
# xlabel: sepal_length
# ylabel: petal_width
# xlim: (4.12, 8.08)
# ylim: (-0.01999999999999999, 2.62)
# xticks: [4. 5. 6. 7. 8. 9.]
# xticklabels: [Text(0.0, 0, '0.00'), Text(0.25, 0, '0.25'), Text(0.5, 0, '0.50'), Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00'), Text(0, 0, '')]
#
# title:
# xlabel: sepal_width
# ylabel:
# xlim: (1.88, 4.5200000000000005)
# ylim: (-0.01999999999999999, 2.62)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: [Text(0.0, 0, '0.00'), Text(0.25, 0, '0.25'), Text(0.5, 0, '0.50'), Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00')]
#
# title:
# xlabel: petal_length
# ylabel:
# xlim: (0.705, 7.195)
# ylim: (-0.01999999999999999, 2.62)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: [Text(0.0, 0, '0.00'), Text(0.25, 0, '0.25'), Text(0.5, 0, '0.50'), Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00')]
#
# title:
# xlabel: petal_width
# ylabel:
# xlim: (-0.01999999999999999, 2.62)
# ylim: (-0.01999999999999999, 2.62)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: [Text(0.0, 0, '0.00'), Text(0.25, 0, '0.25'), Text(0.5, 0, '0.50'), Text(0.75, 0, '0.75'), Text(1.0, 0, '1.00')]

# %%
# Show a univariate distribution on the diagonal:
g = sns.PairGrid(iris)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
# Color the points using a categorical variable:
g = sns.PairGrid(iris, hue="species")
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
#Use a different style to show multiple histograms:
g = sns.PairGrid(iris, hue="species")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
# Plot a subset of variables
g = sns.PairGrid(iris, vars=["sepal_length", "sepal_width"])
g = g.map(plt.scatter)

# %%
# Pass additional keyword arguments to the functions
g = sns.PairGrid(iris)
g = g.map_diag(plt.hist, edgecolor="w")
g = g.map_offdiag(plt.scatter, edgecolor="w", s=40)

# %%
# Use different variables for the rows and columns:
g = sns.PairGrid(iris,
                  x_vars=["sepal_length", "sepal_width"],
                  y_vars=["petal_length", "petal_width"])
g = g.map(plt.scatter)

# %%
# Use different functions on the upper and lower triangles:
g = sns.PairGrid(iris)
import  numpy as np
g = g.map_upper(plt.scatter, color=plt.cm.cool(np.linspace(0, 1, len(iris['sepal_length']))))
# g = g.map_lower(sns.kdeplot, cmap="Blues_d")
g = g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
# Use different colors and markers for each categorical level:
g = sns.PairGrid(iris, hue="species", palette="Set2",
                  hue_kws={"marker": ["o", "s", "D"]}, despine=True,
                 height=3, aspect=1)
g = g.map(plt.scatter, linewidths=1, edgecolor="w", s=40)
g = g.add_legend()
