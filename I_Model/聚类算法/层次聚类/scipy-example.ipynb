# %%
# %matplotlib inline
from scipy.cluster.hierarchy import dendrogram, linkage # 使用scipy进行层次聚类
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data
X.shape
# Out:
# (150, 4)

# %%
# method='single' :最小距离
# method='complete' :最大距离
# method='average' :平均距离
# method='ward' :ward minimizes the variance of the clusters being merged.
Z = linkage(X, method='ward', 
            metric='euclidean') # 欧式距离
                                # cosine 与余弦距离
                                # correlation 相关系数
                                # chebyshev 切比雪夫距离
                                # cityblock 曼哈顿距离

Z
# Out:
# array([[1.01000000e+02, 1.42000000e+02, 0.00000000e+00, 2.00000000e+00],
#        [7.00000000e+00, 3.90000000e+01, 1.00000000e-01, 2.00000000e+00],
#        [0.00000000e+00, 1.70000000e+01, 1.00000000e-01, 2.00000000e+00],
#        [9.00000000e+00, 3.40000000e+01, 1.00000000e-01, 2.00000000e+00],
#        [1.28000000e+02, 1.32000000e+02, 1.00000000e-01, 2.00000000e+00],
#        [1.00000000e+01, 4.80000000e+01, 1.00000000e-01, 2.00000000e+00],
#        [4.00000000e+00, 3.70000000e+01, 1.41421356e-01, 2.00000000e+00],
#        [1.90000000e+01, 2.10000000e+01, 1.41421356e-01, 2.00000000e+00],
#        [2.90000000e+01, 3.00000000e+01, 1.41421356e-01, 2.00000000e+00],
#        [5.70000000e+01, 9.30000000e+01, 1.41421356e-01, 2.00000000e+00],
#        [8.00000000e+01, 8.10000000e+01, 1.41421356e-01, 2.00000000e+00],
#        [1.16000000e+02, 1.37000000e+02, 1.41421356e-01, 2.00000000e+00],
#        [8.00000000e+00, 3.80000000e+01, 1.41421356e-01, 2.00000000e+00],
# ...

# %%
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z) # 分层聚类绘制为树状图

# %%
X1 = [[i] for i in [2, 8, 0, 4, 1, 9, 9, 0]] # 矩阵形式
Z1 = linkage(X1, 'single')
dn1 = dendrogram(Z1)

# %%
Z1
# Out:
# array([[ 2.,  7.,  0.,  2.],
#        [ 5.,  6.,  0.,  2.],
#        [ 0.,  4.,  1.,  2.],
#        [ 8., 10.,  1.,  4.],
#        [ 1.,  9.,  1.,  3.],
#        [ 3., 11.,  2.,  5.],
#        [12., 13.,  4.,  8.]])

# %%
# Z1生成过程
'''
1. 将2, 8, 0, 4, 1, 9, 9, 0的簇标记初始化为0, 1, 2, 3, 4, 5, 6, 7
2. 簇标记为2, 7的距离最近,距离为0,将其合并为簇8,簇8含2个样本
3. 簇标记为5, 6的距离最近,距离为0,将其合并为簇9,簇9含2个样本
4. 簇标记为0, 4的距离最近,距离为1,将其合并为簇10,簇8含2个样本
5. 簇标记为8, 10的距离最近,距离为1,将其合并为簇11,簇11含4个样本
6. 簇标记为1, 9的距离最近,距离为1,将其合并为簇12,簇12含3个样本
7. 簇标记为3, 11的距离最近,距离为2,将其合并为簇13,簇13含5个样本
8. 合并最后的簇12, 簇13,其距离为4,最终的簇含8(所有)个样本 
'''
# Out:
# '\n1. 将2, 8, 0, 4, 1, 9, 9, 0的簇标记初始化为0, 1, 2, 3, 4, 5, 6, 7\n2. 簇标记为2, 7的距离最近,距离为0,将其合并为簇8,簇8含2个样本\n3. 簇标记为5, 6的距离最近,距离为0,将其合并为簇9,簇9含2个样本\n4. 簇标记为0, 4的距离最近,距离为1,将其合并为簇10,簇8含2个样本\n5. 簇标记为8, 10的距离最近,距离为1,将其合并为簇11,簇11含4个样本\n6. 簇标记为1, 9的距离最近,距离为1,将其合并为簇12,簇12含3个样本\n7. 簇标记为3, 11的距离最近,距离为2,将其合并为簇13,簇13含5个样本\n8. 合并最后的簇12, 簇13,其距离为4,最终的簇含8(所有)个样本 \n'
