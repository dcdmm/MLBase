# %%
# 返回对象的内存地址
a = 'runoob'
id(a)

# %%
id(None)  # None的内存地址是固定的
# Out:
# 140715249519840

# %%
class Test:
    def __init__(self, name):
        self.name = name
    
    def println(self):
        print(self.name)

test = Test('duanmengmeng')        
id(test)
# Out:
# 2281495116432
