# %%
from A_PythonBasis.module_import.file_operate.read_csv_file import read_csv_file, read_csv_file_

# %%
# module_import\dir_relative_read\data\data.csv与module_import\test_relative_read_file.ipynb的相对位置
path = 'file_operate/data/data.csv'
dataframe = read_csv_file(path)
print(dataframe)
# Out:
#   something  a   b     c   d message
# A       one  1   2   3.0   4     NaN
# B       two  5   6   NaN   8   world
# C     three  9  10  11.0  12     foo

# %%
dataframe_ = read_csv_file_()
print(dataframe_)
# Out:
# C:\Users\duanm\Music\GitHubProjects\MLBase\A_PythonBasis\module_import\file_operate\data\data.csv
#   something  a   b     c   d message
# A       one  1   2   3.0   4     NaN
# B       two  5   6   NaN   8   world
# C     three  9  10  11.0  12     foo
