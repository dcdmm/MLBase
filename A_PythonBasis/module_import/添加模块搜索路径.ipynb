# %%
# 使用>import<语句导入一个第三方的模块时
# Python解析器默认会在当前目录和path路径中搜索所有已安装的内置模块和第三方模块
"""
Python添加默认模块搜索路径:

方法一：sys.path.append函数添加:
import sys
sys.path.append('D:\\PythonCode') # 临时添加(退出python环境后添加的路径会自动消失)
for i in sys.path: # sys.path是python的搜索模块的路径集,为list数据类型
    print(i)

方法二：增加*.pth文件
在所需的python(base/虚拟)环境的Lib\\site-packages目录中添加一个路径文件.如my_module_path.pth(必须以.pth为后缀),写入你要加入的模块文件所在的目录名称:
如(Windows):D:\\work\\ai_inspection
如(Linux):/root/work/ai-medic-predict
"""

import site

# Returns a list containing all global site-packages directories.
print(site.getsitepackages())

import sys

print(sys.path)
# Out:
# ['C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\Lib\\site-packages']
# ['C:\\Program Files\\JetBrains\\PyCharm 2025.1.3.1\\plugins\\python-ce\\helpers\\jupyter_debug', 'C:\\Program Files\\JetBrains\\PyCharm 2025.1.3.1\\plugins\\python-ce\\helpers\\pydev', 'C:\\Users\\duanm\\Music\\GitHubProjects\\MLBase', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\python312.zip', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\DLLs', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\Lib', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai', '', 'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\Lib\\site-packages']

# %%
sys.path.append('D:\\MyCode')
sys.path
# Out:
# ['C:\\Program Files\\JetBrains\\PyCharm 2025.1.3.1\\plugins\\python-ce\\helpers\\jupyter_debug',
#  'C:\\Program Files\\JetBrains\\PyCharm 2025.1.3.1\\plugins\\python-ce\\helpers\\pydev',
#  'C:\\Users\\duanm\\Music\\GitHubProjects\\MLBase',
#  'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\python312.zip',
#  'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\DLLs',
#  'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\Lib',
#  'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai',
#  '',
#  'C:\\Users\\duanm\\anaconda3\\envs\\transformer_ai\\Lib\\site-packages',
#  'D:\\MyCode']
