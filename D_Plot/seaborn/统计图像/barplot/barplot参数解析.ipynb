# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### matplotlib实现

# %%
groupby = tips["total_bill"].groupby(tips["day"]).mean()
groupby
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
plt.bar(groupby.index, groupby.values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### seaborn参数解析

# %%
# Draw a set of vertical bar plots grouped by a categorical variable:
sns.barplot(x="day",  # 分组列为"day"(自动识别)
            y="total_bill",
            data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Draw a set of horizontal bars
sns.barplot(x="total_bill",
            y="day",
            data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### 参数理解

# %%
groupby = tips["total_bill"].groupby([tips["day"], tips["sex"]]).mean()
groupby
# Out:
# day   sex
# Thur  Male      18.714667
#       Female    16.715312
# Fri   Male      19.857000
#       Female    14.145556
# Sat   Male      20.802542
#       Female    19.680357
# Sun   Male      21.887241
#       Female    19.872222
# Name: total_bill, dtype: float64

# %%
# Draw a set of vertical bars with nested grouping by a two variables:
sns.barplot(x="day",
            y="total_bill",
            hue="sex",  # 指定第二个分组列为"sex"
            data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Control bar order by passing an explicit order:
ax = sns.barplot(x="time", y="tip", data=tips,
                 order=["Dinner", "Lunch"])  # 自定义分组顺序

# %%
# Use median as the estimate of central tendency:
from numpy import median

# 默认estimator=np.mean
sns.barplot(x="day", y="tip", data=tips,
            estimator=median)  # 自定义聚类函数
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# Show the standard error of the mean with the error bars:
sns.barplot(x="day", y="tip", data=tips,
            ci=31)  # 误差线长度大小(置信区间)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# Show standard deviation of observations instead of a confidence interval:
sns.barplot(x="day", y="tip", data=tips,
            ci="sd")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# Add “caps” to the error bars:
sns.barplot(x="day", y="tip", data=tips,
            errcolor='green',  # 误差线的颜色
            capsize=.2)  # 误差线的宽度
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# Use a different color palette for the bars:
sns.barplot(x="day", y="total_bill", data=tips,
            palette="Set1")  # 通过调色盘为不同分组绘制不同列颜色
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# 单一颜色绘制所有列
sns.barplot(x="size", y="total_bill", data=tips,
            color="red")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
iris = sns.load_dataset("iris")

# 绘制DataFrame的所有列(未指定x,y)
sns.barplot(data=iris, orient="v")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=iris, orient="h")  # 水平方向
# Out:
# <AxesSubplot:>
