# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
from PIL import Image
from torchvision import transforms

# %%
img = Image.open('woman.png').convert('RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x22BFD6C3B48>

# %%
img_transform = transforms.Compose([transforms.ToTensor()])
img_tensor = img_transform(img)
img_tensor = torch.unsqueeze(img_tensor, 0)
img_tensor.shape
# Out:
# torch.Size([1, 3, 512, 512])

# %%
filters = torch.empty(10, 3, 5, 5)
nn.init.xavier_normal_(filters)
bias = torch.randn(10)
conv2d_f = F.conv2d(input=img_tensor,
                    weight=filters,
                    bias=bias,
                    stride=1, padding=0, dilation=1)
'''
input –
    input tensor of shape (minibatch, in_channels, iH, iW)
weight –
    filters of shape (out_channels, in_channels/groups, kH, kW)
bias –
    optional bias tensor of shape (out_channels) . Default: None
'''
conv2d_f.shape
# Out:
# torch.Size([1, 10, 508, 508])

# %%
# 灰度图(只有一个通道)
transforms.ToPILImage()(torch.squeeze(conv2d_f[:, 0, :, :])) # 特征图1(feature map)
# Out:
# <PIL.Image.Image image mode=L size=508x508 at 0x22BFD6D0848>

# %%
transforms.ToPILImage()(torch.squeeze(conv2d_f[:, 1, :, :])) # 特征图2(feature map)
# Out:
# <PIL.Image.Image image mode=L size=508x508 at 0x22BFD6D0E48>

# %%
transforms.ToPILImage()(torch.squeeze(conv2d_f[:, 2, :, :])) # 特征图3(feature map)
# Out:
# <PIL.Image.Image image mode=L size=508x508 at 0x22BFD6D26C8>

# %%
transforms.ToPILImage()(torch.squeeze(conv2d_f[:, 4, :, :])) # 特征图4(feature map)
# Out:
# <PIL.Image.Image image mode=L size=508x508 at 0x22BFD6D2F08>
