# %%
# int类被设计成可以表示任意大小的整形类,Python可以根据其整数的大小自动选择内部表示的方式
int()  # 整数个构造函数int()返回一个默认为0的值
# Out:
# 0

# %%
int(-3.14)  # 得到浮点值的整数部分
# Out:
# -3

# %%
int('123')  # 得到字符串代表的整数值
# Out:
# 123

# %%
int('duanchao')  # ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e5b7a839b77e> in <module>
# ----> 1 int('duanchao')
#       2
#
# ValueError: invalid literal for int() with base 10: 'duanchao'

# %%
int('11111', base=2)  # 将二进制11111转换为十进制
# Out:
# 31

# %%
int('12', base=8)  # 将八进制12转换为十进制(默认base=10)
# Out:
# 10

# %%
int('7f', base=16)
# Out:
# 127
