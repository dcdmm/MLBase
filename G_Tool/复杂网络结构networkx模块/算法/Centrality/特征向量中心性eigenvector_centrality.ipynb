# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

nx.draw(G)

# %%
G.degree
# Out:
# DegreeView({1: 3, 2: 2, 3: 3, 5: 2, 4: 2})

# %%
# 特征向量中心性是表征图中顶点的"全局"(相对于"局部")突出度的几个节点度量之一
# Eigenvector centrality computes the centrality for a node based on the centrality of its neighbors.
# 课程参考:http://djjr-courses.wikidot.com/soc180:eigenvector-centrality
nx.algorithms.centrality.eigenvector_centrality(G,
                                                max_iter=100000)  # 最大迭代次数
# Out:
# {1: 0.5298988890761731,
#  2: 0.4271316779596084,
#  3: 0.5298988890761731,
#  5: 0.35775191431708964,
#  4: 0.35775191431708964}
