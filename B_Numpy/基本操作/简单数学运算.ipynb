# %%
import  numpy as np

# %%
arr1 = np.array([[1., 2., 3.], [4., 5., 6.]])
arr2 = np.array([[0., 4., 1.], [7., 2., 12.]])

# %%
arr1 + arr2  # 对应元素相加
# Out:
# array([[ 1.,  6.,  4.],
#        [11.,  7., 18.]])

# %%
arr2 - arr1  # 对应元素相减
# Out:
# array([[-1.,  2., -2.],
#        [ 3., -3.,  6.]])

# %%
arr2 / arr1
# Out:
# array([[0.        , 2.        , 0.33333333],
#        [1.75      , 0.4       , 2.        ]])

# %%
arr2 // arr1
# Out:
# array([[0., 2., 0.],
#        [1., 0., 2.]])

# %%
arr2 % arr1
# Out:
# array([[0., 0., 1.],
#        [3., 2., 0.]])

# %%
arr2 > arr1
# Out:
# array([[False,  True, False],
#        [ True, False,  True]])
