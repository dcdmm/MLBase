# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ### 参考torch.optim.lr_scheduler.ReduceLROnPlateau

# %%
X = datasets.fetch_covtype().data[:5000]
y = datasets.fetch_covtype().target[:5000]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

print(X_train.shape, y_train.shape)

enc = OrdinalEncoder()
y_train = enc.fit_transform(y_train.reshape(-1, 1)).reshape(-1, )
y_test = enc.transform(y_test.reshape(-1, 1)).reshape(-1, )
print(np.unique(y_train))  # 7分类任务

X_train, X_test, y_train, y_test = tf.constant(X_train), tf.constant(X_test), tf.constant(y_train), tf.constant(y_test)
# Out:
# (4500, 54) (4500,)
# [0. 1. 2. 3. 4. 5. 6.]

# %%
inputs = tf.keras.Input(shape=(54,))
x = tf.keras.layers.Dense(256, activation='tanh')(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128)(x)
predictions = tf.keras.layers.Dense(7)(x)
model = tf.keras.Model(inputs=inputs, outputs=predictions)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 54)]              0
#
#  dense_8 (Dense)             (None, 256)               14080
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dense_11 (Dense)            (None, 7)                 903
#
# =================================================================
# Total params: 64,391
# Trainable params: 64,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",  # 'loss'/'val_loss'或accuracy/val_accuracy(根据metrics)
                                         mode='min',  # 由monitory='val_loss',故设置mode='min'
                                         # factor by which the learning rate will be reduced. new_lr = lr * factor.
                                         factor=0.5,
                                         # number of epochs with no improvement after which learning rate will be reduced.
                                         patience=3,
                                         # threshold for measuring the new optimum, to only focus on significant changes.
                                         min_delta=0.0001,
                                         # number of epochs to wait before resuming normal operation after lr has been reduced.
                                         cooldown=0,
                                         min_lr=0,  # 学习率的下限
                                         # int. 0: quiet, 1: update messages.
                                         verbose=1)

]
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test),
          # List of keras.callbacks.Callback instances.
          callbacks=callbacks)
# Out:
# Epoch 1/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.3782 - accuracy: 0.4422 - val_loss: 1.2004 - val_accuracy: 0.5280 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.2441 - accuracy: 0.4949 - val_loss: 1.1712 - val_accuracy: 0.5320 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.2043 - accuracy: 0.5158 - val_loss: 1.1642 - val_accuracy: 0.5320 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1972 - accuracy: 0.5247 - val_loss: 1.1650 - val_accuracy: 0.5280 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1757 - accuracy: 0.5227 - val_loss: 1.0999 - val_accuracy: 0.5820 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.2038 - accuracy: 0.5109 - val_loss: 1.1466 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.1808 - accuracy: 0.5127 - val_loss: 1.1119 - val_accuracy: 0.6040 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - ETA: 0s - loss: 1.1737 - accuracy: 0.5264
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1737 - accuracy: 0.5264 - val_loss: 1.1223 - val_accuracy: 0.5400 - lr: 0.0010
# Epoch 9/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1331 - accuracy: 0.5404 - val_loss: 1.0623 - val_accuracy: 0.6100 - lr: 5.0000e-04
# Epoch 10/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0782 - accuracy: 0.5607 - val_loss: 0.9994 - val_accuracy: 0.5980 - lr: 5.0000e-04
# Epoch 11/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0544 - accuracy: 0.5722 - val_loss: 0.9838 - val_accuracy: 0.6120 - lr: 5.0000e-04
# Epoch 12/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0606 - accuracy: 0.5600 - val_loss: 0.9960 - val_accuracy: 0.5900 - lr: 5.0000e-04
# Epoch 13/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0682 - accuracy: 0.5636 - val_loss: 0.9764 - val_accuracy: 0.6120 - lr: 5.0000e-04
# Epoch 14/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0370 - accuracy: 0.5796 - val_loss: 0.9592 - val_accuracy: 0.6340 - lr: 5.0000e-04
# Epoch 15/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0264 - accuracy: 0.5891 - val_loss: 0.9381 - val_accuracy: 0.6180 - lr: 5.0000e-04
# Epoch 16/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0272 - accuracy: 0.5856 - val_loss: 0.9593 - val_accuracy: 0.6300 - lr: 5.0000e-04
# Epoch 17/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0161 - accuracy: 0.5844 - val_loss: 0.9411 - val_accuracy: 0.6300 - lr: 5.0000e-04
# Epoch 18/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9985 - accuracy: 0.5858 - val_loss: 0.9105 - val_accuracy: 0.6180 - lr: 5.0000e-04
# Epoch 19/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9704 - accuracy: 0.6069 - val_loss: 0.8703 - val_accuracy: 0.6380 - lr: 5.0000e-04
# Epoch 20/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9387 - accuracy: 0.6142 - val_loss: 0.8719 - val_accuracy: 0.6460 - lr: 5.0000e-04
# Epoch 21/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9805 - accuracy: 0.6029 - val_loss: 0.8642 - val_accuracy: 0.6400 - lr: 5.0000e-04
# Epoch 22/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9635 - accuracy: 0.6029 - val_loss: 0.8720 - val_accuracy: 0.6700 - lr: 5.0000e-04
# Epoch 23/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9320 - accuracy: 0.6096 - val_loss: 0.8572 - val_accuracy: 0.6580 - lr: 5.0000e-04
# Epoch 24/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9442 - accuracy: 0.6131 - val_loss: 0.8488 - val_accuracy: 0.6860 - lr: 5.0000e-04
# Epoch 25/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9205 - accuracy: 0.6262 - val_loss: 0.8442 - val_accuracy: 0.6660 - lr: 5.0000e-04
# Epoch 26/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9222 - accuracy: 0.6176 - val_loss: 0.8309 - val_accuracy: 0.6760 - lr: 5.0000e-04
# Epoch 27/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8933 - accuracy: 0.6260 - val_loss: 0.8225 - val_accuracy: 0.6760 - lr: 5.0000e-04
# Epoch 28/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8938 - accuracy: 0.6351 - val_loss: 0.8118 - val_accuracy: 0.6680 - lr: 5.0000e-04
# Epoch 29/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8939 - accuracy: 0.6269 - val_loss: 0.8195 - val_accuracy: 0.6740 - lr: 5.0000e-04
# Epoch 30/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8695 - accuracy: 0.6456 - val_loss: 0.8006 - val_accuracy: 0.6740 - lr: 5.0000e-04
# Epoch 31/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8911 - accuracy: 0.6227 - val_loss: 0.8292 - val_accuracy: 0.6780 - lr: 5.0000e-04
# Epoch 32/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8643 - accuracy: 0.6433 - val_loss: 0.8048 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 33/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8462 - accuracy: 0.6549 - val_loss: 0.7809 - val_accuracy: 0.6860 - lr: 5.0000e-04
# Epoch 34/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8671 - accuracy: 0.6389 - val_loss: 0.7763 - val_accuracy: 0.6860 - lr: 5.0000e-04
# Epoch 35/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8490 - accuracy: 0.6527 - val_loss: 0.7456 - val_accuracy: 0.7020 - lr: 5.0000e-04
# Epoch 36/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8362 - accuracy: 0.6576 - val_loss: 0.7892 - val_accuracy: 0.7100 - lr: 5.0000e-04
# Epoch 37/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8415 - accuracy: 0.6562 - val_loss: 0.7704 - val_accuracy: 0.6780 - lr: 5.0000e-04
# Epoch 38/50
# 138/141 [============================>.] - ETA: 0s - loss: 0.8324 - accuracy: 0.6608
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8326 - accuracy: 0.6604 - val_loss: 0.8047 - val_accuracy: 0.6740 - lr: 5.0000e-04
# Epoch 39/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8107 - accuracy: 0.6709 - val_loss: 0.7612 - val_accuracy: 0.6900 - lr: 2.5000e-04
# Epoch 40/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7930 - accuracy: 0.6787 - val_loss: 0.7319 - val_accuracy: 0.7020 - lr: 2.5000e-04
# Epoch 41/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.7760 - accuracy: 0.6847 - val_loss: 0.7284 - val_accuracy: 0.7180 - lr: 2.5000e-04
# Epoch 42/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7718 - accuracy: 0.6800 - val_loss: 0.6965 - val_accuracy: 0.7200 - lr: 2.5000e-04
# Epoch 43/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7672 - accuracy: 0.6813 - val_loss: 0.7132 - val_accuracy: 0.7280 - lr: 2.5000e-04
# Epoch 44/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7615 - accuracy: 0.6880 - val_loss: 0.7198 - val_accuracy: 0.7080 - lr: 2.5000e-04
# Epoch 45/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7455 - accuracy: 0.6929 - val_loss: 0.6883 - val_accuracy: 0.7160 - lr: 2.5000e-04
# Epoch 46/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7554 - accuracy: 0.6911 - val_loss: 0.6882 - val_accuracy: 0.7260 - lr: 2.5000e-04
# Epoch 47/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7625 - accuracy: 0.6887 - val_loss: 0.6975 - val_accuracy: 0.7240 - lr: 2.5000e-04
# Epoch 48/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7377 - accuracy: 0.7084 - val_loss: 0.6913 - val_accuracy: 0.7280 - lr: 2.5000e-04
# Epoch 49/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7525 - accuracy: 0.6887 - val_loss: 0.6857 - val_accuracy: 0.7220 - lr: 2.5000e-04
# Epoch 50/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7451 - accuracy: 0.6924 - val_loss: 0.7134 - val_accuracy: 0.7200 - lr: 2.5000e-04

# %%
# 学习率衰减情况
model.history.history['lr']
# Out:
# [0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025]
