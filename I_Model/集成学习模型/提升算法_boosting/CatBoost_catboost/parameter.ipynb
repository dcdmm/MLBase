# %% [markdown]
# ## cat主要调节参数及其含义
#
# 1. 其他参数
#     * loss_function/objective===>xgboost(objective)
#     * thread_count===>xgboost(nthread)
#     * allow_writing_files
#     * eval_metric===>xgboost(eval_metric)
#     * task_type
#     * leaf_estimation_method
#     * iterations/n_estimators===>xgboost(num_boost_round)
#     * use_best_model
#     * *****************************
#     * pool===>xgboost(dtrain)
#     * early_stopping_rounds===>xgboost(early_stopping_rounds)
#     * eval_set===>xgboost(evals)
#     * verbose_eval===>xgboost(verbose_eval)
#
# 3. 树调节参数
#     * max_depth/depth===>xgboost(max_depth)
#
# 4. 防止过拟合参数
#     * colsample_bylevel/rsm===>xgboost(colsample_bylevel)
#     * learning_rate===>xgboost(learning_rate)
#     * reg_lambda===>xgboost(reg_lambda)

# %%
import catboost as cat
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X = datasets.fetch_covtype().data[:3000]
y = datasets.fetch_covtype().target[:3000]
X_train, X_test, y_train, y_test = train_test_split(X, y)

print(X_train.shape)
print(y_train.shape)
print(np.unique(y_train))  # 7分类任务
# Out:
# (2250, 54)
# (2250,)
# [1 2 3 4 5 6 7]

# %%
train_dataset = cat.Pool(data=X_train, label=y_train)

# %%
'''
# loss_function:The metric to use in training.
# eval_metric:The metric used for overfitting detection (if enabled) and best model selection (if enabled).
# loss_function/eval_metric可自定义:具体参考https://catboost.ai/docs/concepts/python-usages-examples.html#custom-loss-function-eval-metric
loss_function/eval_metric可选参数:
RMSE: 均方根误差==>loss_function/eval_metric
MAE:平均绝对误差===>loss_function/eval_metric
R2: R平方==>eval_metric

CrossEntropy:交叉熵===>loss_function/eval_metric
Logloss: 负对数似然函数值(二分类)===>loss_function/eval_metric

MultiClass:多分类logloss===>loss_function/eval_metric

Precision:查准率(多分类)===>eval_metric
Recall:召回率(多分类)===>eval_metric
F1:F1值(多分类)===>eval_metric
Accuracy:精度(多分类)===>eval_metric
AUC:多分类===>eval_metric
'''

'''
verbose:
The purpose of this parameter depends on the type of the given value:

1. bool — Defines the logging level:
    * “True”  corresponds to the Verbose logging level
    * “False” corresponds to the Silent logging level
2. int — Use the Verbose logging level and set the logging period to the value of this parameter.
'''
params = {"loss_function": "MultiClass",
          # 不支持定义多个eval_metric
          # 默认与loss_function定义相同
          "eval_metric": "MultiClass",
          # Allow to write analytical and snapshot files during training.
          # If set to “False”, the snapshot and data visualization tools are unavailable.
          # 默认allow_writing_files=True
          "allow_writing_files": False,
          # The number of threads to use during the training.
          "thread_count": -1,
          }

'''
相比xgboost/lightgbm
    * y标签不要求0开始
    * 不需要指定多分类类别数量,自动识别是否为多分类任务
'''
model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# Learning rate set to 0.082468
# 0:	learn: 1.7633679	total: 8.98ms	remaining: 8.98s
# 1:	learn: 1.6485576	total: 16.9ms	remaining: 8.41s
# 2:	learn: 1.5421658	total: 24.9ms	remaining: 8.29s
# 3:	learn: 1.4646668	total: 33ms	remaining: 8.21s
# 4:	learn: 1.3887613	total: 40.5ms	remaining: 8.06s
# 5:	learn: 1.3191996	total: 49.1ms	remaining: 8.14s
# 6:	learn: 1.2585012	total: 56.7ms	remaining: 8.05s
# 7:	learn: 1.2050367	total: 65.6ms	remaining: 8.13s
# 8:	learn: 1.1603612	total: 73.2ms	remaining: 8.06s
# 9:	learn: 1.1165846	total: 81.9ms	remaining: 8.11s
# 10:	learn: 1.0789472	total: 89.3ms	remaining: 8.03s
# 11:	learn: 1.0440096	total: 97.3ms	remaining: 8.01s
# 12:	learn: 1.0157868	total: 105ms	remaining: 7.95s
# 13:	learn: 0.9863562	total: 112ms	remaining: 7.9s
# 14:	learn: 0.9579050	total: 121ms	remaining: 7.92s
# 15:	learn: 0.9295251	total: 131ms	remaining: 8.03s
# 16:	learn: 0.9073169	total: 141ms	remaining: 8.13s
# 17:	learn: 0.8869492	total: 151ms	remaining: 8.23s
# 18:	learn: 0.8679071	total: 163ms	remaining: 8.41s
# 19:	learn: 0.8497781	total: 174ms	remaining: 8.51s
# 20:	learn: 0.8317860	total: 185ms	remaining: 8.61s
# 21:	learn: 0.8197502	total: 194ms	remaining: 8.61s
# 22:	learn: 0.8050951	total: 206ms	remaining: 8.75s
# 23:	learn: 0.7902209	total: 221ms	remaining: 8.97s
# 24:	learn: 0.7778341	total: 233ms	remaining: 9.08s
# 25:	learn: 0.7683659	total: 244ms	remaining: 9.14s
# 26:	learn: 0.7560669	total: 254ms	remaining: 9.16s
# 27:	learn: 0.7456098	total: 264ms	remaining: 9.15s
# 28:	learn: 0.7345000	total: 289ms	remaining: 9.68s
# 29:	learn: 0.7237993	total: 300ms	remaining: 9.69s
# 30:	learn: 0.7155866	total: 309ms	remaining: 9.67s
# 31:	learn: 0.7069283	total: 319ms	remaining: 9.65s
# 32:	learn: 0.6981032	total: 329ms	remaining: 9.64s
# 33:	learn: 0.6883159	total: 339ms	remaining: 9.63s
# 34:	learn: 0.6825251	total: 348ms	remaining: 9.6s
# 35:	learn: 0.6759470	total: 358ms	remaining: 9.58s
# 36:	learn: 0.6679438	total: 367ms	remaining: 9.55s
# 37:	learn: 0.6596562	total: 377ms	remaining: 9.55s
# 38:	learn: 0.6523510	total: 387ms	remaining: 9.53s
# 39:	learn: 0.6462967	total: 395ms	remaining: 9.49s
# 40:	learn: 0.6412795	total: 404ms	remaining: 9.45s
# 41:	learn: 0.6354031	total: 424ms	remaining: 9.66s
# 42:	learn: 0.6308401	total: 432ms	remaining: 9.62s
# 43:	learn: 0.6254659	total: 443ms	remaining: 9.62s
# 44:	learn: 0.6202580	total: 451ms	remaining: 9.58s
# 45:	learn: 0.6155431	total: 462ms	remaining: 9.57s
# 46:	learn: 0.6101890	total: 470ms	remaining: 9.54s
# 47:	learn: 0.6066054	total: 479ms	remaining: 9.5s
# 48:	learn: 0.6018185	total: 489ms	remaining: 9.49s
# 49:	learn: 0.5973481	total: 498ms	remaining: 9.47s
# 50:	learn: 0.5916615	total: 509ms	remaining: 9.48s
# 51:	learn: 0.5855974	total: 522ms	remaining: 9.52s
# 52:	learn: 0.5813138	total: 549ms	remaining: 9.8s
# 53:	learn: 0.5758178	total: 562ms	remaining: 9.85s
# 54:	learn: 0.5728542	total: 575ms	remaining: 9.89s
# 55:	learn: 0.5675513	total: 585ms	remaining: 9.86s
# 56:	learn: 0.5642130	total: 596ms	remaining: 9.86s
# 57:	learn: 0.5619461	total: 606ms	remaining: 9.84s
# 58:	learn: 0.5582421	total: 614ms	remaining: 9.79s
# 59:	learn: 0.5552146	total: 623ms	remaining: 9.76s
# 60:	learn: 0.5518352	total: 633ms	remaining: 9.75s
# 61:	learn: 0.5484867	total: 643ms	remaining: 9.73s
# 62:	learn: 0.5460671	total: 652ms	remaining: 9.7s
# 63:	learn: 0.5427544	total: 661ms	remaining: 9.66s
# 64:	learn: 0.5390831	total: 670ms	remaining: 9.64s
# 65:	learn: 0.5361861	total: 679ms	remaining: 9.61s
# 66:	learn: 0.5337433	total: 688ms	remaining: 9.57s
# 67:	learn: 0.5301425	total: 697ms	remaining: 9.55s
# 68:	learn: 0.5286541	total: 706ms	remaining: 9.53s
# 69:	learn: 0.5258650	total: 715ms	remaining: 9.5s
# 70:	learn: 0.5229636	total: 723ms	remaining: 9.46s
# 71:	learn: 0.5206713	total: 733ms	remaining: 9.44s
# 72:	learn: 0.5182076	total: 742ms	remaining: 9.42s
# 73:	learn: 0.5157638	total: 752ms	remaining: 9.41s
# 74:	learn: 0.5120426	total: 761ms	remaining: 9.39s
# 75:	learn: 0.5104570	total: 771ms	remaining: 9.38s
# 76:	learn: 0.5070916	total: 780ms	remaining: 9.35s
# 77:	learn: 0.5052579	total: 788ms	remaining: 9.32s
# 78:	learn: 0.5031608	total: 796ms	remaining: 9.28s
# 79:	learn: 0.5008735	total: 805ms	remaining: 9.25s
# 80:	learn: 0.4976961	total: 813ms	remaining: 9.22s
# 81:	learn: 0.4949699	total: 822ms	remaining: 9.2s
# 82:	learn: 0.4919419	total: 831ms	remaining: 9.18s
# 83:	learn: 0.4899527	total: 840ms	remaining: 9.16s
# 84:	learn: 0.4884834	total: 849ms	remaining: 9.13s
# 85:	learn: 0.4867966	total: 857ms	remaining: 9.11s
# 86:	learn: 0.4836096	total: 865ms	remaining: 9.08s
# 87:	learn: 0.4819520	total: 876ms	remaining: 9.08s
# 88:	learn: 0.4807631	total: 886ms	remaining: 9.07s
# 89:	learn: 0.4779859	total: 896ms	remaining: 9.06s
# 90:	learn: 0.4766929	total: 905ms	remaining: 9.04s
# 91:	learn: 0.4752578	total: 915ms	remaining: 9.03s
# 92:	learn: 0.4736012	total: 923ms	remaining: 9s
# 93:	learn: 0.4720891	total: 931ms	remaining: 8.97s
# 94:	learn: 0.4710221	total: 941ms	remaining: 8.97s
# 95:	learn: 0.4699354	total: 952ms	remaining: 8.96s
# 96:	learn: 0.4676881	total: 962ms	remaining: 8.95s
# 97:	learn: 0.4657409	total: 971ms	remaining: 8.93s
# 98:	learn: 0.4638170	total: 981ms	remaining: 8.93s
# 99:	learn: 0.4618454	total: 990ms	remaining: 8.9s
# 100:	learn: 0.4593926	total: 1s	remaining: 8.91s
# 101:	learn: 0.4570502	total: 1.01s	remaining: 8.9s
# 102:	learn: 0.4558995	total: 1.02s	remaining: 8.91s
# 103:	learn: 0.4546088	total: 1.03s	remaining: 8.89s
# 104:	learn: 0.4531816	total: 1.04s	remaining: 8.88s
# 105:	learn: 0.4514233	total: 1.05s	remaining: 8.86s
# 106:	learn: 0.4505444	total: 1.06s	remaining: 8.83s
# 107:	learn: 0.4491863	total: 1.08s	remaining: 8.93s
# 108:	learn: 0.4476022	total: 1.09s	remaining: 8.91s
# 109:	learn: 0.4450051	total: 1.1s	remaining: 8.89s
# 110:	learn: 0.4419226	total: 1.11s	remaining: 8.86s
# 111:	learn: 0.4405545	total: 1.11s	remaining: 8.84s
# 112:	learn: 0.4390001	total: 1.12s	remaining: 8.82s
# 113:	learn: 0.4373979	total: 1.13s	remaining: 8.81s
# 114:	learn: 0.4360307	total: 1.14s	remaining: 8.79s
# 115:	learn: 0.4343195	total: 1.15s	remaining: 8.76s
# 116:	learn: 0.4324649	total: 1.16s	remaining: 8.74s
# 117:	learn: 0.4317423	total: 1.17s	remaining: 8.72s
# 118:	learn: 0.4304852	total: 1.18s	remaining: 8.7s
# 119:	learn: 0.4286781	total: 1.19s	remaining: 8.69s
# 120:	learn: 0.4263865	total: 1.19s	remaining: 8.67s
# 121:	learn: 0.4249368	total: 1.2s	remaining: 8.65s
# 122:	learn: 0.4228590	total: 1.21s	remaining: 8.63s
# 123:	learn: 0.4216593	total: 1.22s	remaining: 8.61s
# 124:	learn: 0.4199541	total: 1.23s	remaining: 8.61s
# 125:	learn: 0.4184248	total: 1.24s	remaining: 8.59s
# 126:	learn: 0.4169473	total: 1.25s	remaining: 8.58s
# 127:	learn: 0.4158983	total: 1.25s	remaining: 8.55s
# 128:	learn: 0.4141207	total: 1.26s	remaining: 8.54s
# 129:	learn: 0.4123451	total: 1.27s	remaining: 8.52s
# 130:	learn: 0.4109612	total: 1.28s	remaining: 8.51s
# 131:	learn: 0.4098240	total: 1.29s	remaining: 8.49s
# 132:	learn: 0.4086897	total: 1.3s	remaining: 8.47s
# 133:	learn: 0.4072412	total: 1.31s	remaining: 8.45s
# 134:	learn: 0.4054024	total: 1.32s	remaining: 8.45s
# 135:	learn: 0.4044387	total: 1.33s	remaining: 8.44s
# 136:	learn: 0.4025461	total: 1.34s	remaining: 8.42s
# 137:	learn: 0.4015603	total: 1.34s	remaining: 8.4s
# 138:	learn: 0.3999541	total: 1.35s	remaining: 8.38s
# 139:	learn: 0.3979885	total: 1.36s	remaining: 8.36s
# 140:	learn: 0.3965757	total: 1.37s	remaining: 8.35s
# 141:	learn: 0.3955696	total: 1.38s	remaining: 8.33s
# 142:	learn: 0.3941483	total: 1.39s	remaining: 8.31s
# 143:	learn: 0.3928260	total: 1.4s	remaining: 8.3s
# 144:	learn: 0.3916730	total: 1.41s	remaining: 8.3s
# 145:	learn: 0.3895304	total: 1.42s	remaining: 8.29s
# 146:	learn: 0.3886710	total: 1.43s	remaining: 8.28s
# 147:	learn: 0.3876176	total: 1.44s	remaining: 8.26s
# 148:	learn: 0.3863936	total: 1.44s	remaining: 8.24s
# 149:	learn: 0.3851417	total: 1.45s	remaining: 8.22s
# 150:	learn: 0.3841453	total: 1.46s	remaining: 8.21s
# 151:	learn: 0.3828150	total: 1.47s	remaining: 8.2s
# 152:	learn: 0.3819265	total: 1.48s	remaining: 8.19s
# 153:	learn: 0.3806086	total: 1.49s	remaining: 8.17s
# 154:	learn: 0.3796563	total: 1.5s	remaining: 8.16s
# 155:	learn: 0.3783386	total: 1.51s	remaining: 8.15s
# 156:	learn: 0.3768172	total: 1.51s	remaining: 8.14s
# 157:	learn: 0.3756478	total: 1.52s	remaining: 8.13s
# 158:	learn: 0.3748358	total: 1.53s	remaining: 8.11s
# 159:	learn: 0.3735251	total: 1.54s	remaining: 8.09s
# 160:	learn: 0.3721461	total: 1.55s	remaining: 8.08s
# 161:	learn: 0.3709410	total: 1.56s	remaining: 8.06s
# 162:	learn: 0.3695141	total: 1.56s	remaining: 8.04s
# 163:	learn: 0.3683805	total: 1.57s	remaining: 8.02s
# 164:	learn: 0.3678424	total: 1.58s	remaining: 8.01s
# 165:	learn: 0.3671511	total: 1.59s	remaining: 8s
# 166:	learn: 0.3652822	total: 1.6s	remaining: 7.98s
# 167:	learn: 0.3646186	total: 1.61s	remaining: 7.97s
# 168:	learn: 0.3637131	total: 1.62s	remaining: 7.96s
# 169:	learn: 0.3626645	total: 1.63s	remaining: 7.94s
# 170:	learn: 0.3612958	total: 1.63s	remaining: 7.92s
# 171:	learn: 0.3598348	total: 1.64s	remaining: 7.91s
# 172:	learn: 0.3586482	total: 1.65s	remaining: 7.9s
# 173:	learn: 0.3569891	total: 1.66s	remaining: 7.88s
# 174:	learn: 0.3560649	total: 1.67s	remaining: 7.86s
# 175:	learn: 0.3552417	total: 1.68s	remaining: 7.85s
# 176:	learn: 0.3545238	total: 1.68s	remaining: 7.83s
# 177:	learn: 0.3537644	total: 1.69s	remaining: 7.82s
# 178:	learn: 0.3528819	total: 1.7s	remaining: 7.81s
# 179:	learn: 0.3520792	total: 1.71s	remaining: 7.79s
# 180:	learn: 0.3516247	total: 1.72s	remaining: 7.78s
# 181:	learn: 0.3506511	total: 1.73s	remaining: 7.76s
# 182:	learn: 0.3492202	total: 1.73s	remaining: 7.74s
# 183:	learn: 0.3478823	total: 1.74s	remaining: 7.72s
# 184:	learn: 0.3468574	total: 1.75s	remaining: 7.71s
# 185:	learn: 0.3459942	total: 1.76s	remaining: 7.7s
# 186:	learn: 0.3452092	total: 1.77s	remaining: 7.69s
# 187:	learn: 0.3442359	total: 1.78s	remaining: 7.68s
# 188:	learn: 0.3430894	total: 1.78s	remaining: 7.66s
# 189:	learn: 0.3419770	total: 1.79s	remaining: 7.65s
# 190:	learn: 0.3410370	total: 1.8s	remaining: 7.64s
# 191:	learn: 0.3397439	total: 1.81s	remaining: 7.63s
# 192:	learn: 0.3393230	total: 1.82s	remaining: 7.62s
# 193:	learn: 0.3378256	total: 1.83s	remaining: 7.6s
# 194:	learn: 0.3364746	total: 1.84s	remaining: 7.59s
# 195:	learn: 0.3356846	total: 1.85s	remaining: 7.58s
# 196:	learn: 0.3349592	total: 1.86s	remaining: 7.57s
# 197:	learn: 0.3333279	total: 1.87s	remaining: 7.56s
# 198:	learn: 0.3320597	total: 1.87s	remaining: 7.54s
# 199:	learn: 0.3309536	total: 1.88s	remaining: 7.53s
# 200:	learn: 0.3303614	total: 1.89s	remaining: 7.52s
# 201:	learn: 0.3296292	total: 1.9s	remaining: 7.51s
# 202:	learn: 0.3287752	total: 1.91s	remaining: 7.5s
# 203:	learn: 0.3283037	total: 1.92s	remaining: 7.48s
# 204:	learn: 0.3274002	total: 1.93s	remaining: 7.47s
# 205:	learn: 0.3267126	total: 1.93s	remaining: 7.45s
# 206:	learn: 0.3258935	total: 1.94s	remaining: 7.44s
# 207:	learn: 0.3250331	total: 1.95s	remaining: 7.43s
# 208:	learn: 0.3243286	total: 1.96s	remaining: 7.41s
# 209:	learn: 0.3237153	total: 1.97s	remaining: 7.4s
# 210:	learn: 0.3228033	total: 1.98s	remaining: 7.39s
# 211:	learn: 0.3219648	total: 1.98s	remaining: 7.37s
# 212:	learn: 0.3213116	total: 1.99s	remaining: 7.36s
# 213:	learn: 0.3207759	total: 2s	remaining: 7.34s
# 214:	learn: 0.3201834	total: 2.01s	remaining: 7.33s
# 215:	learn: 0.3193727	total: 2.02s	remaining: 7.32s
# 216:	learn: 0.3184017	total: 2.02s	remaining: 7.31s
# 217:	learn: 0.3174619	total: 2.03s	remaining: 7.29s
# 218:	learn: 0.3166936	total: 2.04s	remaining: 7.29s
# 219:	learn: 0.3156501	total: 2.05s	remaining: 7.28s
# 220:	learn: 0.3149611	total: 2.06s	remaining: 7.26s
# 221:	learn: 0.3142941	total: 2.07s	remaining: 7.25s
# 222:	learn: 0.3135366	total: 2.08s	remaining: 7.24s
# 223:	learn: 0.3127560	total: 2.08s	remaining: 7.22s
# 224:	learn: 0.3124942	total: 2.09s	remaining: 7.21s
# 225:	learn: 0.3115767	total: 2.1s	remaining: 7.2s
# 226:	learn: 0.3108681	total: 2.11s	remaining: 7.19s
# 227:	learn: 0.3098286	total: 2.12s	remaining: 7.18s
# 228:	learn: 0.3094240	total: 2.13s	remaining: 7.17s
# 229:	learn: 0.3091200	total: 2.14s	remaining: 7.16s
# 230:	learn: 0.3081344	total: 2.15s	remaining: 7.14s
# 231:	learn: 0.3077962	total: 2.16s	remaining: 7.14s
# 232:	learn: 0.3067900	total: 2.16s	remaining: 7.13s
# 233:	learn: 0.3062062	total: 2.17s	remaining: 7.12s
# 234:	learn: 0.3057507	total: 2.18s	remaining: 7.1s
# 235:	learn: 0.3053302	total: 2.19s	remaining: 7.09s
# 236:	learn: 0.3043424	total: 2.2s	remaining: 7.08s
# 237:	learn: 0.3035381	total: 2.21s	remaining: 7.07s
# 238:	learn: 0.3026538	total: 2.22s	remaining: 7.06s
# 239:	learn: 0.3014885	total: 2.23s	remaining: 7.05s
# 240:	learn: 0.3006596	total: 2.23s	remaining: 7.04s
# 241:	learn: 0.2997782	total: 2.24s	remaining: 7.02s
# 242:	learn: 0.2993324	total: 2.25s	remaining: 7.01s
# 243:	learn: 0.2985491	total: 2.26s	remaining: 7s
# 244:	learn: 0.2976641	total: 2.27s	remaining: 6.99s
# 245:	learn: 0.2970178	total: 2.28s	remaining: 6.98s
# 246:	learn: 0.2965850	total: 2.29s	remaining: 6.97s
# 247:	learn: 0.2956398	total: 2.29s	remaining: 6.95s
# 248:	learn: 0.2951067	total: 2.3s	remaining: 6.94s
# 249:	learn: 0.2946658	total: 2.31s	remaining: 6.93s
# 250:	learn: 0.2942826	total: 2.32s	remaining: 6.92s
# 251:	learn: 0.2937444	total: 2.33s	remaining: 6.91s
# 252:	learn: 0.2933691	total: 2.34s	remaining: 6.9s
# 253:	learn: 0.2927202	total: 2.35s	remaining: 6.89s
# 254:	learn: 0.2917758	total: 2.35s	remaining: 6.88s
# 255:	learn: 0.2915153	total: 2.36s	remaining: 6.87s
# 256:	learn: 0.2906255	total: 2.37s	remaining: 6.86s
# 257:	learn: 0.2900056	total: 2.38s	remaining: 6.85s
# 258:	learn: 0.2896083	total: 2.39s	remaining: 6.84s
# 259:	learn: 0.2887734	total: 2.4s	remaining: 6.82s
# 260:	learn: 0.2881835	total: 2.41s	remaining: 6.81s
# 261:	learn: 0.2873233	total: 2.42s	remaining: 6.8s
# 262:	learn: 0.2867874	total: 2.42s	remaining: 6.79s
# 263:	learn: 0.2861997	total: 2.43s	remaining: 6.78s
# 264:	learn: 0.2852651	total: 2.44s	remaining: 6.77s
# 265:	learn: 0.2844140	total: 2.45s	remaining: 6.76s
# 266:	learn: 0.2839361	total: 2.46s	remaining: 6.74s
# 267:	learn: 0.2830383	total: 2.46s	remaining: 6.74s
# 268:	learn: 0.2822838	total: 2.48s	remaining: 6.73s
# 269:	learn: 0.2818915	total: 2.48s	remaining: 6.72s
# 270:	learn: 0.2815648	total: 2.49s	remaining: 6.71s
# 271:	learn: 0.2809436	total: 2.5s	remaining: 6.69s
# 272:	learn: 0.2804043	total: 2.51s	remaining: 6.68s
# 273:	learn: 0.2796204	total: 2.52s	remaining: 6.67s
# 274:	learn: 0.2787166	total: 2.52s	remaining: 6.66s
# 275:	learn: 0.2781883	total: 2.54s	remaining: 6.65s
# 276:	learn: 0.2776112	total: 2.54s	remaining: 6.64s
# 277:	learn: 0.2771815	total: 2.56s	remaining: 6.63s
# 278:	learn: 0.2766799	total: 2.56s	remaining: 6.62s
# 279:	learn: 0.2758101	total: 2.57s	remaining: 6.62s
# 280:	learn: 0.2753097	total: 2.58s	remaining: 6.6s
# 281:	learn: 0.2749144	total: 2.59s	remaining: 6.59s
# 282:	learn: 0.2744260	total: 2.6s	remaining: 6.58s
# 283:	learn: 0.2734789	total: 2.61s	remaining: 6.57s
# 284:	learn: 0.2730044	total: 2.62s	remaining: 6.56s
# 285:	learn: 0.2726889	total: 2.62s	remaining: 6.55s
# 286:	learn: 0.2720250	total: 2.63s	remaining: 6.54s
# 287:	learn: 0.2715827	total: 2.64s	remaining: 6.53s
# 288:	learn: 0.2705799	total: 2.65s	remaining: 6.52s
# 289:	learn: 0.2697711	total: 2.66s	remaining: 6.51s
# 290:	learn: 0.2691937	total: 2.67s	remaining: 6.5s
# 291:	learn: 0.2682170	total: 2.67s	remaining: 6.49s
# 292:	learn: 0.2674539	total: 2.68s	remaining: 6.48s
# 293:	learn: 0.2669423	total: 2.69s	remaining: 6.47s
# 294:	learn: 0.2663614	total: 2.7s	remaining: 6.46s
# 295:	learn: 0.2655043	total: 2.71s	remaining: 6.45s
# 296:	learn: 0.2650607	total: 2.72s	remaining: 6.43s
# 297:	learn: 0.2646179	total: 2.73s	remaining: 6.42s
# 298:	learn: 0.2642404	total: 2.74s	remaining: 6.42s
# 299:	learn: 0.2636132	total: 2.75s	remaining: 6.41s
# 300:	learn: 0.2630604	total: 2.75s	remaining: 6.39s
# 301:	learn: 0.2623678	total: 2.76s	remaining: 6.38s
# 302:	learn: 0.2619323	total: 2.77s	remaining: 6.37s
# 303:	learn: 0.2611866	total: 2.78s	remaining: 6.37s
# 304:	learn: 0.2608570	total: 2.79s	remaining: 6.35s
# 305:	learn: 0.2602930	total: 2.8s	remaining: 6.34s
# 306:	learn: 0.2599815	total: 2.81s	remaining: 6.33s
# 307:	learn: 0.2595457	total: 2.81s	remaining: 6.33s
# 308:	learn: 0.2592304	total: 2.82s	remaining: 6.31s
# 309:	learn: 0.2584179	total: 2.83s	remaining: 6.3s
# 310:	learn: 0.2578322	total: 2.84s	remaining: 6.29s
# 311:	learn: 0.2572951	total: 2.85s	remaining: 6.28s
# 312:	learn: 0.2567760	total: 2.85s	remaining: 6.27s
# 313:	learn: 0.2560411	total: 2.86s	remaining: 6.25s
# 314:	learn: 0.2556343	total: 2.87s	remaining: 6.24s
# 315:	learn: 0.2553967	total: 2.88s	remaining: 6.23s
# 316:	learn: 0.2551161	total: 2.89s	remaining: 6.22s
# 317:	learn: 0.2547857	total: 2.89s	remaining: 6.21s
# 318:	learn: 0.2543498	total: 2.9s	remaining: 6.19s
# 319:	learn: 0.2537578	total: 2.91s	remaining: 6.18s
# 320:	learn: 0.2533192	total: 2.92s	remaining: 6.17s
# 321:	learn: 0.2524630	total: 2.92s	remaining: 6.16s
# 322:	learn: 0.2514701	total: 2.93s	remaining: 6.14s
# 323:	learn: 0.2511936	total: 2.94s	remaining: 6.13s
# 324:	learn: 0.2506994	total: 2.95s	remaining: 6.12s
# 325:	learn: 0.2505927	total: 2.96s	remaining: 6.11s
# 326:	learn: 0.2499917	total: 2.96s	remaining: 6.1s
# 327:	learn: 0.2494924	total: 2.97s	remaining: 6.08s
# 328:	learn: 0.2489535	total: 2.98s	remaining: 6.07s
# 329:	learn: 0.2484921	total: 2.98s	remaining: 6.06s
# 330:	learn: 0.2481851	total: 2.99s	remaining: 6.05s
# 331:	learn: 0.2474892	total: 3s	remaining: 6.04s
# 332:	learn: 0.2471759	total: 3.01s	remaining: 6.03s
# 333:	learn: 0.2468763	total: 3.02s	remaining: 6.02s
# 334:	learn: 0.2459200	total: 3.03s	remaining: 6.01s
# 335:	learn: 0.2454961	total: 3.04s	remaining: 6s
# 336:	learn: 0.2453452	total: 3.04s	remaining: 5.99s
# 337:	learn: 0.2446746	total: 3.05s	remaining: 5.97s
# 338:	learn: 0.2444030	total: 3.06s	remaining: 5.96s
# 339:	learn: 0.2438295	total: 3.06s	remaining: 5.95s
# 340:	learn: 0.2432709	total: 3.07s	remaining: 5.94s
# 341:	learn: 0.2424377	total: 3.08s	remaining: 5.93s
# 342:	learn: 0.2421243	total: 3.09s	remaining: 5.91s
# 343:	learn: 0.2416718	total: 3.1s	remaining: 5.9s
# 344:	learn: 0.2413065	total: 3.1s	remaining: 5.89s
# 345:	learn: 0.2409817	total: 3.11s	remaining: 5.88s
# 346:	learn: 0.2402456	total: 3.12s	remaining: 5.87s
# 347:	learn: 0.2398152	total: 3.13s	remaining: 5.86s
# 348:	learn: 0.2394408	total: 3.13s	remaining: 5.84s
# 349:	learn: 0.2389516	total: 3.14s	remaining: 5.83s
# 350:	learn: 0.2384871	total: 3.15s	remaining: 5.82s
# 351:	learn: 0.2381082	total: 3.15s	remaining: 5.81s
# 352:	learn: 0.2379592	total: 3.16s	remaining: 5.8s
# 353:	learn: 0.2374162	total: 3.17s	remaining: 5.79s
# 354:	learn: 0.2372896	total: 3.18s	remaining: 5.77s
# 355:	learn: 0.2368265	total: 3.19s	remaining: 5.76s
# 356:	learn: 0.2364789	total: 3.19s	remaining: 5.75s
# 357:	learn: 0.2358627	total: 3.2s	remaining: 5.74s
# 358:	learn: 0.2356435	total: 3.21s	remaining: 5.73s
# 359:	learn: 0.2353707	total: 3.22s	remaining: 5.72s
# 360:	learn: 0.2349982	total: 3.22s	remaining: 5.71s
# 361:	learn: 0.2345328	total: 3.23s	remaining: 5.7s
# 362:	learn: 0.2339271	total: 3.24s	remaining: 5.69s
# 363:	learn: 0.2334959	total: 3.25s	remaining: 5.68s
# 364:	learn: 0.2331651	total: 3.26s	remaining: 5.67s
# 365:	learn: 0.2328940	total: 3.27s	remaining: 5.66s
# 366:	learn: 0.2321815	total: 3.27s	remaining: 5.64s
# 367:	learn: 0.2318338	total: 3.28s	remaining: 5.63s
# 368:	learn: 0.2315755	total: 3.29s	remaining: 5.62s
# 369:	learn: 0.2309853	total: 3.29s	remaining: 5.61s
# 370:	learn: 0.2308706	total: 3.3s	remaining: 5.6s
# 371:	learn: 0.2305879	total: 3.31s	remaining: 5.59s
# 372:	learn: 0.2300384	total: 3.32s	remaining: 5.58s
# 373:	learn: 0.2296566	total: 3.33s	remaining: 5.57s
# 374:	learn: 0.2292556	total: 3.33s	remaining: 5.55s
# 375:	learn: 0.2288515	total: 3.34s	remaining: 5.54s
# 376:	learn: 0.2280424	total: 3.35s	remaining: 5.53s
# 377:	learn: 0.2275180	total: 3.36s	remaining: 5.52s
# 378:	learn: 0.2272735	total: 3.36s	remaining: 5.51s
# 379:	learn: 0.2270428	total: 3.37s	remaining: 5.5s
# 380:	learn: 0.2264430	total: 3.38s	remaining: 5.49s
# 381:	learn: 0.2258964	total: 3.39s	remaining: 5.48s
# 382:	learn: 0.2254250	total: 3.4s	remaining: 5.47s
# 383:	learn: 0.2249834	total: 3.4s	remaining: 5.46s
# 384:	learn: 0.2246564	total: 3.41s	remaining: 5.45s
# 385:	learn: 0.2242482	total: 3.42s	remaining: 5.44s
# 386:	learn: 0.2240066	total: 3.43s	remaining: 5.43s
# 387:	learn: 0.2237263	total: 3.43s	remaining: 5.42s
# 388:	learn: 0.2234453	total: 3.44s	remaining: 5.41s
# 389:	learn: 0.2230376	total: 3.45s	remaining: 5.39s
# 390:	learn: 0.2227184	total: 3.46s	remaining: 5.39s
# 391:	learn: 0.2223278	total: 3.47s	remaining: 5.38s
# 392:	learn: 0.2220313	total: 3.47s	remaining: 5.37s
# 393:	learn: 0.2215429	total: 3.5s	remaining: 5.38s
# 394:	learn: 0.2210560	total: 3.5s	remaining: 5.37s
# 395:	learn: 0.2203797	total: 3.51s	remaining: 5.36s
# 396:	learn: 0.2200902	total: 3.52s	remaining: 5.34s
# 397:	learn: 0.2194106	total: 3.53s	remaining: 5.33s
# 398:	learn: 0.2188535	total: 3.53s	remaining: 5.32s
# 399:	learn: 0.2183288	total: 3.54s	remaining: 5.31s
# 400:	learn: 0.2180237	total: 3.55s	remaining: 5.3s
# 401:	learn: 0.2175472	total: 3.56s	remaining: 5.29s
# 402:	learn: 0.2171740	total: 3.56s	remaining: 5.28s
# 403:	learn: 0.2170365	total: 3.57s	remaining: 5.27s
# 404:	learn: 0.2164814	total: 3.58s	remaining: 5.26s
# 405:	learn: 0.2162657	total: 3.59s	remaining: 5.25s
# 406:	learn: 0.2159815	total: 3.6s	remaining: 5.24s
# 407:	learn: 0.2157234	total: 3.6s	remaining: 5.23s
# 408:	learn: 0.2154051	total: 3.61s	remaining: 5.22s
# 409:	learn: 0.2151455	total: 3.62s	remaining: 5.21s
# 410:	learn: 0.2144993	total: 3.63s	remaining: 5.2s
# 411:	learn: 0.2140965	total: 3.63s	remaining: 5.19s
# 412:	learn: 0.2137151	total: 3.64s	remaining: 5.17s
# 413:	learn: 0.2134309	total: 3.65s	remaining: 5.17s
# 414:	learn: 0.2131448	total: 3.66s	remaining: 5.15s
# 415:	learn: 0.2128186	total: 3.66s	remaining: 5.14s
# 416:	learn: 0.2125167	total: 3.67s	remaining: 5.13s
# 417:	learn: 0.2122299	total: 3.68s	remaining: 5.12s
# 418:	learn: 0.2118470	total: 3.69s	remaining: 5.11s
# 419:	learn: 0.2113051	total: 3.69s	remaining: 5.1s
# 420:	learn: 0.2109938	total: 3.7s	remaining: 5.09s
# 421:	learn: 0.2105141	total: 3.71s	remaining: 5.08s
# 422:	learn: 0.2101135	total: 3.72s	remaining: 5.07s
# 423:	learn: 0.2097506	total: 3.73s	remaining: 5.06s
# 424:	learn: 0.2094025	total: 3.73s	remaining: 5.05s
# 425:	learn: 0.2092743	total: 3.74s	remaining: 5.04s
# 426:	learn: 0.2085663	total: 3.75s	remaining: 5.03s
# 427:	learn: 0.2081450	total: 3.76s	remaining: 5.02s
# 428:	learn: 0.2078590	total: 3.77s	remaining: 5.01s
# 429:	learn: 0.2075821	total: 3.77s	remaining: 5s
# 430:	learn: 0.2071179	total: 3.78s	remaining: 4.99s
# 431:	learn: 0.2068096	total: 3.79s	remaining: 4.98s
# 432:	learn: 0.2065826	total: 3.8s	remaining: 4.97s
# 433:	learn: 0.2062337	total: 3.81s	remaining: 4.96s
# 434:	learn: 0.2057735	total: 3.81s	remaining: 4.95s
# 435:	learn: 0.2055653	total: 3.82s	remaining: 4.94s
# 436:	learn: 0.2052834	total: 3.83s	remaining: 4.93s
# 437:	learn: 0.2050734	total: 3.84s	remaining: 4.92s
# 438:	learn: 0.2049025	total: 3.85s	remaining: 4.91s
# 439:	learn: 0.2046383	total: 3.85s	remaining: 4.9s
# 440:	learn: 0.2044100	total: 3.86s	remaining: 4.89s
# 441:	learn: 0.2040722	total: 3.87s	remaining: 4.88s
# 442:	learn: 0.2036040	total: 3.88s	remaining: 4.87s
# 443:	learn: 0.2032239	total: 3.88s	remaining: 4.86s
# 444:	learn: 0.2028686	total: 3.89s	remaining: 4.85s
# 445:	learn: 0.2026597	total: 3.9s	remaining: 4.84s
# 446:	learn: 0.2020274	total: 3.91s	remaining: 4.83s
# 447:	learn: 0.2014686	total: 3.92s	remaining: 4.83s
# 448:	learn: 0.2011950	total: 3.92s	remaining: 4.82s
# 449:	learn: 0.2008837	total: 3.93s	remaining: 4.81s
# 450:	learn: 0.2005633	total: 3.94s	remaining: 4.8s
# 451:	learn: 0.2000855	total: 3.95s	remaining: 4.79s
# 452:	learn: 0.1996562	total: 3.96s	remaining: 4.78s
# 453:	learn: 0.1993683	total: 3.97s	remaining: 4.77s
# 454:	learn: 0.1990115	total: 3.98s	remaining: 4.76s
# 455:	learn: 0.1983234	total: 3.98s	remaining: 4.75s
# 456:	learn: 0.1978877	total: 3.99s	remaining: 4.74s
# 457:	learn: 0.1976532	total: 4s	remaining: 4.73s
# 458:	learn: 0.1974283	total: 4.01s	remaining: 4.72s
# 459:	learn: 0.1971505	total: 4.02s	remaining: 4.71s
# 460:	learn: 0.1969434	total: 4.02s	remaining: 4.71s
# 461:	learn: 0.1967800	total: 4.03s	remaining: 4.7s
# 462:	learn: 0.1964511	total: 4.04s	remaining: 4.69s
# 463:	learn: 0.1959350	total: 4.05s	remaining: 4.68s
# 464:	learn: 0.1954941	total: 4.06s	remaining: 4.67s
# 465:	learn: 0.1952174	total: 4.07s	remaining: 4.66s
# 466:	learn: 0.1949630	total: 4.08s	remaining: 4.65s
# 467:	learn: 0.1945528	total: 4.08s	remaining: 4.64s
# 468:	learn: 0.1942406	total: 4.09s	remaining: 4.63s
# 469:	learn: 0.1939524	total: 4.1s	remaining: 4.62s
# 470:	learn: 0.1935505	total: 4.11s	remaining: 4.61s
# 471:	learn: 0.1930136	total: 4.12s	remaining: 4.6s
# 472:	learn: 0.1928813	total: 4.12s	remaining: 4.59s
# 473:	learn: 0.1925303	total: 4.13s	remaining: 4.58s
# 474:	learn: 0.1921413	total: 4.14s	remaining: 4.57s
# 475:	learn: 0.1918843	total: 4.15s	remaining: 4.56s
# 476:	learn: 0.1917633	total: 4.15s	remaining: 4.55s
# 477:	learn: 0.1913764	total: 4.16s	remaining: 4.54s
# 478:	learn: 0.1909877	total: 4.17s	remaining: 4.53s
# 479:	learn: 0.1907016	total: 4.18s	remaining: 4.52s
# 480:	learn: 0.1904619	total: 4.18s	remaining: 4.51s
# 481:	learn: 0.1901745	total: 4.19s	remaining: 4.5s
# 482:	learn: 0.1899494	total: 4.2s	remaining: 4.5s
# 483:	learn: 0.1897995	total: 4.21s	remaining: 4.49s
# 484:	learn: 0.1893424	total: 4.21s	remaining: 4.48s
# 485:	learn: 0.1888415	total: 4.22s	remaining: 4.47s
# 486:	learn: 0.1884971	total: 4.23s	remaining: 4.46s
# 487:	learn: 0.1880824	total: 4.24s	remaining: 4.45s
# 488:	learn: 0.1878262	total: 4.25s	remaining: 4.44s
# 489:	learn: 0.1875769	total: 4.26s	remaining: 4.43s
# 490:	learn: 0.1873534	total: 4.26s	remaining: 4.42s
# 491:	learn: 0.1871834	total: 4.27s	remaining: 4.41s
# 492:	learn: 0.1864607	total: 4.28s	remaining: 4.4s
# 493:	learn: 0.1859478	total: 4.29s	remaining: 4.39s
# 494:	learn: 0.1856983	total: 4.29s	remaining: 4.38s
# 495:	learn: 0.1853847	total: 4.3s	remaining: 4.37s
# 496:	learn: 0.1849272	total: 4.31s	remaining: 4.36s
# 497:	learn: 0.1845801	total: 4.32s	remaining: 4.35s
# 498:	learn: 0.1843626	total: 4.32s	remaining: 4.34s
# 499:	learn: 0.1841457	total: 4.33s	remaining: 4.33s
# 500:	learn: 0.1839233	total: 4.34s	remaining: 4.33s
# 501:	learn: 0.1834295	total: 4.35s	remaining: 4.32s
# 502:	learn: 0.1831270	total: 4.36s	remaining: 4.31s
# 503:	learn: 0.1827620	total: 4.37s	remaining: 4.3s
# 504:	learn: 0.1822956	total: 4.38s	remaining: 4.29s
# 505:	learn: 0.1820458	total: 4.38s	remaining: 4.28s
# 506:	learn: 0.1817189	total: 4.39s	remaining: 4.27s
# 507:	learn: 0.1813166	total: 4.4s	remaining: 4.26s
# 508:	learn: 0.1810270	total: 4.41s	remaining: 4.25s
# 509:	learn: 0.1807125	total: 4.42s	remaining: 4.25s
# 510:	learn: 0.1805078	total: 4.42s	remaining: 4.24s
# 511:	learn: 0.1799902	total: 4.43s	remaining: 4.22s
# 512:	learn: 0.1795955	total: 4.44s	remaining: 4.22s
# 513:	learn: 0.1793389	total: 4.45s	remaining: 4.21s
# 514:	learn: 0.1790246	total: 4.46s	remaining: 4.2s
# 515:	learn: 0.1787373	total: 4.47s	remaining: 4.19s
# 516:	learn: 0.1783782	total: 4.48s	remaining: 4.18s
# 517:	learn: 0.1780898	total: 4.49s	remaining: 4.17s
# 518:	learn: 0.1778759	total: 4.49s	remaining: 4.16s
# 519:	learn: 0.1775892	total: 4.5s	remaining: 4.15s
# 520:	learn: 0.1772556	total: 4.51s	remaining: 4.14s
# 521:	learn: 0.1768127	total: 4.52s	remaining: 4.13s
# 522:	learn: 0.1764568	total: 4.52s	remaining: 4.13s
# 523:	learn: 0.1761737	total: 4.53s	remaining: 4.12s
# 524:	learn: 0.1758280	total: 4.54s	remaining: 4.11s
# 525:	learn: 0.1756220	total: 4.55s	remaining: 4.1s
# 526:	learn: 0.1754472	total: 4.55s	remaining: 4.09s
# 527:	learn: 0.1752226	total: 4.56s	remaining: 4.08s
# 528:	learn: 0.1748650	total: 4.57s	remaining: 4.07s
# 529:	learn: 0.1745902	total: 4.58s	remaining: 4.06s
# 530:	learn: 0.1744118	total: 4.59s	remaining: 4.05s
# 531:	learn: 0.1739589	total: 4.6s	remaining: 4.04s
# 532:	learn: 0.1732355	total: 4.61s	remaining: 4.04s
# 533:	learn: 0.1731019	total: 4.62s	remaining: 4.03s
# 534:	learn: 0.1729203	total: 4.63s	remaining: 4.02s
# 535:	learn: 0.1725569	total: 4.63s	remaining: 4.01s
# 536:	learn: 0.1723434	total: 4.64s	remaining: 4s
# 537:	learn: 0.1721261	total: 4.65s	remaining: 3.99s
# 538:	learn: 0.1718971	total: 4.66s	remaining: 3.98s
# 539:	learn: 0.1716691	total: 4.67s	remaining: 3.98s
# 540:	learn: 0.1713872	total: 4.67s	remaining: 3.97s
# 541:	learn: 0.1710897	total: 4.68s	remaining: 3.96s
# 542:	learn: 0.1709255	total: 4.69s	remaining: 3.95s
# 543:	learn: 0.1706578	total: 4.7s	remaining: 3.94s
# 544:	learn: 0.1702600	total: 4.71s	remaining: 3.93s
# 545:	learn: 0.1701043	total: 4.71s	remaining: 3.92s
# 546:	learn: 0.1698711	total: 4.72s	remaining: 3.91s
# 547:	learn: 0.1692907	total: 4.73s	remaining: 3.9s
# 548:	learn: 0.1690892	total: 4.74s	remaining: 3.89s
# 549:	learn: 0.1689966	total: 4.74s	remaining: 3.88s
# 550:	learn: 0.1684219	total: 4.75s	remaining: 3.87s
# 551:	learn: 0.1682978	total: 4.76s	remaining: 3.86s
# 552:	learn: 0.1681478	total: 4.76s	remaining: 3.85s
# 553:	learn: 0.1679441	total: 4.77s	remaining: 3.84s
# 554:	learn: 0.1676772	total: 4.78s	remaining: 3.83s
# 555:	learn: 0.1673623	total: 4.79s	remaining: 3.82s
# 556:	learn: 0.1671052	total: 4.79s	remaining: 3.81s
# 557:	learn: 0.1668670	total: 4.8s	remaining: 3.81s
# 558:	learn: 0.1665822	total: 4.81s	remaining: 3.8s
# 559:	learn: 0.1664377	total: 4.82s	remaining: 3.79s
# 560:	learn: 0.1662026	total: 4.83s	remaining: 3.78s
# 561:	learn: 0.1658866	total: 4.84s	remaining: 3.77s
# 562:	learn: 0.1655132	total: 4.84s	remaining: 3.76s
# 563:	learn: 0.1653055	total: 4.85s	remaining: 3.75s
# 564:	learn: 0.1650528	total: 4.86s	remaining: 3.74s
# 565:	learn: 0.1648353	total: 4.87s	remaining: 3.73s
# 566:	learn: 0.1646504	total: 4.88s	remaining: 3.72s
# 567:	learn: 0.1645337	total: 4.88s	remaining: 3.71s
# 568:	learn: 0.1643173	total: 4.89s	remaining: 3.71s
# 569:	learn: 0.1639546	total: 4.9s	remaining: 3.7s
# 570:	learn: 0.1637996	total: 4.91s	remaining: 3.69s
# 571:	learn: 0.1636759	total: 4.92s	remaining: 3.68s
# 572:	learn: 0.1634431	total: 4.92s	remaining: 3.67s
# 573:	learn: 0.1630923	total: 4.93s	remaining: 3.66s
# 574:	learn: 0.1628945	total: 4.94s	remaining: 3.65s
# 575:	learn: 0.1623543	total: 4.95s	remaining: 3.64s
# 576:	learn: 0.1619600	total: 4.96s	remaining: 3.63s
# 577:	learn: 0.1616416	total: 4.96s	remaining: 3.62s
# 578:	learn: 0.1615065	total: 4.97s	remaining: 3.62s
# 579:	learn: 0.1612386	total: 4.98s	remaining: 3.61s
# 580:	learn: 0.1609402	total: 4.99s	remaining: 3.6s
# 581:	learn: 0.1607428	total: 5s	remaining: 3.59s
# 582:	learn: 0.1604793	total: 5s	remaining: 3.58s
# 583:	learn: 0.1602372	total: 5.01s	remaining: 3.57s
# 584:	learn: 0.1598246	total: 5.02s	remaining: 3.56s
# 585:	learn: 0.1594401	total: 5.03s	remaining: 3.55s
# 586:	learn: 0.1590625	total: 5.04s	remaining: 3.54s
# 587:	learn: 0.1586791	total: 5.04s	remaining: 3.53s
# 588:	learn: 0.1584484	total: 5.05s	remaining: 3.52s
# 589:	learn: 0.1582236	total: 5.06s	remaining: 3.52s
# 590:	learn: 0.1580763	total: 5.07s	remaining: 3.51s
# 591:	learn: 0.1577441	total: 5.08s	remaining: 3.5s
# 592:	learn: 0.1576112	total: 5.08s	remaining: 3.49s
# 593:	learn: 0.1573766	total: 5.09s	remaining: 3.48s
# 594:	learn: 0.1572327	total: 5.1s	remaining: 3.47s
# 595:	learn: 0.1570622	total: 5.11s	remaining: 3.46s
# 596:	learn: 0.1568086	total: 5.11s	remaining: 3.45s
# 597:	learn: 0.1566849	total: 5.12s	remaining: 3.44s
# 598:	learn: 0.1563867	total: 5.13s	remaining: 3.43s
# 599:	learn: 0.1561965	total: 5.14s	remaining: 3.42s
# 600:	learn: 0.1558046	total: 5.14s	remaining: 3.42s
# 601:	learn: 0.1555983	total: 5.15s	remaining: 3.41s
# 602:	learn: 0.1554835	total: 5.16s	remaining: 3.4s
# 603:	learn: 0.1550978	total: 5.17s	remaining: 3.39s
# 604:	learn: 0.1548036	total: 5.18s	remaining: 3.38s
# 605:	learn: 0.1545978	total: 5.19s	remaining: 3.37s
# 606:	learn: 0.1544035	total: 5.19s	remaining: 3.36s
# 607:	learn: 0.1542227	total: 5.2s	remaining: 3.35s
# 608:	learn: 0.1539768	total: 5.21s	remaining: 3.35s
# 609:	learn: 0.1537108	total: 5.22s	remaining: 3.34s
# 610:	learn: 0.1532519	total: 5.23s	remaining: 3.33s
# 611:	learn: 0.1530064	total: 5.24s	remaining: 3.32s
# 612:	learn: 0.1527778	total: 5.25s	remaining: 3.31s
# 613:	learn: 0.1525519	total: 5.25s	remaining: 3.3s
# 614:	learn: 0.1523390	total: 5.26s	remaining: 3.29s
# 615:	learn: 0.1520481	total: 5.27s	remaining: 3.28s
# 616:	learn: 0.1516018	total: 5.28s	remaining: 3.28s
# 617:	learn: 0.1514762	total: 5.28s	remaining: 3.27s
# 618:	learn: 0.1512586	total: 5.29s	remaining: 3.26s
# 619:	learn: 0.1510096	total: 5.3s	remaining: 3.25s
# 620:	learn: 0.1509086	total: 5.31s	remaining: 3.24s
# 621:	learn: 0.1505684	total: 5.32s	remaining: 3.23s
# 622:	learn: 0.1501400	total: 5.32s	remaining: 3.22s
# 623:	learn: 0.1498787	total: 5.33s	remaining: 3.21s
# 624:	learn: 0.1497890	total: 5.34s	remaining: 3.2s
# 625:	learn: 0.1495627	total: 5.34s	remaining: 3.19s
# 626:	learn: 0.1492635	total: 5.35s	remaining: 3.18s
# 627:	learn: 0.1490546	total: 5.36s	remaining: 3.17s
# 628:	learn: 0.1487165	total: 5.37s	remaining: 3.17s
# 629:	learn: 0.1484963	total: 5.38s	remaining: 3.16s
# 630:	learn: 0.1483456	total: 5.38s	remaining: 3.15s
# 631:	learn: 0.1481306	total: 5.39s	remaining: 3.14s
# 632:	learn: 0.1478841	total: 5.4s	remaining: 3.13s
# 633:	learn: 0.1477420	total: 5.41s	remaining: 3.12s
# 634:	learn: 0.1476331	total: 5.41s	remaining: 3.11s
# 635:	learn: 0.1474318	total: 5.42s	remaining: 3.1s
# 636:	learn: 0.1471576	total: 5.43s	remaining: 3.09s
# 637:	learn: 0.1469513	total: 5.44s	remaining: 3.08s
# 638:	learn: 0.1468055	total: 5.45s	remaining: 3.08s
# 639:	learn: 0.1466550	total: 5.45s	remaining: 3.07s
# 640:	learn: 0.1465083	total: 5.46s	remaining: 3.06s
# 641:	learn: 0.1462785	total: 5.47s	remaining: 3.05s
# 642:	learn: 0.1459261	total: 5.48s	remaining: 3.04s
# 643:	learn: 0.1457626	total: 5.49s	remaining: 3.03s
# 644:	learn: 0.1455132	total: 5.49s	remaining: 3.02s
# 645:	learn: 0.1454324	total: 5.5s	remaining: 3.02s
# 646:	learn: 0.1452655	total: 5.51s	remaining: 3.01s
# 647:	learn: 0.1450984	total: 5.52s	remaining: 3s
# 648:	learn: 0.1449556	total: 5.53s	remaining: 2.99s
# 649:	learn: 0.1446131	total: 5.55s	remaining: 2.99s
# 650:	learn: 0.1442609	total: 5.56s	remaining: 2.98s
# 651:	learn: 0.1439314	total: 5.57s	remaining: 2.97s
# 652:	learn: 0.1437933	total: 5.58s	remaining: 2.96s
# 653:	learn: 0.1435423	total: 5.58s	remaining: 2.95s
# 654:	learn: 0.1433775	total: 5.59s	remaining: 2.94s
# 655:	learn: 0.1432931	total: 5.6s	remaining: 2.94s
# 656:	learn: 0.1429819	total: 5.61s	remaining: 2.93s
# 657:	learn: 0.1427886	total: 5.61s	remaining: 2.92s
# 658:	learn: 0.1426497	total: 5.62s	remaining: 2.91s
# 659:	learn: 0.1423780	total: 5.63s	remaining: 2.9s
# 660:	learn: 0.1422927	total: 5.64s	remaining: 2.89s
# 661:	learn: 0.1421229	total: 5.65s	remaining: 2.88s
# 662:	learn: 0.1418735	total: 5.66s	remaining: 2.87s
# 663:	learn: 0.1417498	total: 5.66s	remaining: 2.87s
# 664:	learn: 0.1415317	total: 5.67s	remaining: 2.86s
# 665:	learn: 0.1413845	total: 5.68s	remaining: 2.85s
# 666:	learn: 0.1411754	total: 5.69s	remaining: 2.84s
# 667:	learn: 0.1410233	total: 5.7s	remaining: 2.83s
# 668:	learn: 0.1409143	total: 5.7s	remaining: 2.82s
# 669:	learn: 0.1406319	total: 5.71s	remaining: 2.81s
# 670:	learn: 0.1404681	total: 5.72s	remaining: 2.8s
# 671:	learn: 0.1404006	total: 5.72s	remaining: 2.79s
# 672:	learn: 0.1403058	total: 5.73s	remaining: 2.79s
# 673:	learn: 0.1400605	total: 5.74s	remaining: 2.78s
# 674:	learn: 0.1399147	total: 5.75s	remaining: 2.77s
# 675:	learn: 0.1397448	total: 5.76s	remaining: 2.76s
# 676:	learn: 0.1395095	total: 5.77s	remaining: 2.75s
# 677:	learn: 0.1391861	total: 5.78s	remaining: 2.74s
# 678:	learn: 0.1390417	total: 5.78s	remaining: 2.73s
# 679:	learn: 0.1389373	total: 5.79s	remaining: 2.73s
# 680:	learn: 0.1387098	total: 5.8s	remaining: 2.72s
# 681:	learn: 0.1384089	total: 5.81s	remaining: 2.71s
# 682:	learn: 0.1382189	total: 5.82s	remaining: 2.7s
# 683:	learn: 0.1379864	total: 5.82s	remaining: 2.69s
# 684:	learn: 0.1378759	total: 5.83s	remaining: 2.68s
# 685:	learn: 0.1376725	total: 5.84s	remaining: 2.67s
# 686:	learn: 0.1374460	total: 5.85s	remaining: 2.66s
# 687:	learn: 0.1373046	total: 5.85s	remaining: 2.65s
# 688:	learn: 0.1371839	total: 5.86s	remaining: 2.65s
# 689:	learn: 0.1370579	total: 5.87s	remaining: 2.64s
# 690:	learn: 0.1368780	total: 5.88s	remaining: 2.63s
# 691:	learn: 0.1366843	total: 5.88s	remaining: 2.62s
# 692:	learn: 0.1364630	total: 5.89s	remaining: 2.61s
# 693:	learn: 0.1363626	total: 5.9s	remaining: 2.6s
# 694:	learn: 0.1362490	total: 5.91s	remaining: 2.59s
# 695:	learn: 0.1360750	total: 5.92s	remaining: 2.58s
# 696:	learn: 0.1358434	total: 5.92s	remaining: 2.58s
# 697:	learn: 0.1355971	total: 5.93s	remaining: 2.57s
# 698:	learn: 0.1354030	total: 5.94s	remaining: 2.56s
# 699:	learn: 0.1352308	total: 5.95s	remaining: 2.55s
# 700:	learn: 0.1350052	total: 5.95s	remaining: 2.54s
# 701:	learn: 0.1349024	total: 5.96s	remaining: 2.53s
# 702:	learn: 0.1347732	total: 5.97s	remaining: 2.52s
# 703:	learn: 0.1345276	total: 5.98s	remaining: 2.52s
# 704:	learn: 0.1344516	total: 5.99s	remaining: 2.51s
# 705:	learn: 0.1341903	total: 6s	remaining: 2.5s
# 706:	learn: 0.1340252	total: 6.01s	remaining: 2.49s
# 707:	learn: 0.1337263	total: 6.01s	remaining: 2.48s
# 708:	learn: 0.1334643	total: 6.02s	remaining: 2.47s
# 709:	learn: 0.1333054	total: 6.03s	remaining: 2.46s
# 710:	learn: 0.1330528	total: 6.04s	remaining: 2.45s
# 711:	learn: 0.1327503	total: 6.05s	remaining: 2.45s
# 712:	learn: 0.1326702	total: 6.05s	remaining: 2.44s
# 713:	learn: 0.1323790	total: 6.06s	remaining: 2.43s
# 714:	learn: 0.1321169	total: 6.07s	remaining: 2.42s
# 715:	learn: 0.1319542	total: 6.08s	remaining: 2.41s
# 716:	learn: 0.1316896	total: 6.08s	remaining: 2.4s
# 717:	learn: 0.1314782	total: 6.09s	remaining: 2.39s
# 718:	learn: 0.1313393	total: 6.1s	remaining: 2.38s
# 719:	learn: 0.1312217	total: 6.11s	remaining: 2.38s
# 720:	learn: 0.1311056	total: 6.12s	remaining: 2.37s
# 721:	learn: 0.1309951	total: 6.12s	remaining: 2.36s
# 722:	learn: 0.1306746	total: 6.13s	remaining: 2.35s
# 723:	learn: 0.1305654	total: 6.14s	remaining: 2.34s
# 724:	learn: 0.1304619	total: 6.15s	remaining: 2.33s
# 725:	learn: 0.1303408	total: 6.15s	remaining: 2.32s
# 726:	learn: 0.1300772	total: 6.16s	remaining: 2.31s
# 727:	learn: 0.1299410	total: 6.17s	remaining: 2.31s
# 728:	learn: 0.1297521	total: 6.18s	remaining: 2.3s
# 729:	learn: 0.1296415	total: 6.18s	remaining: 2.29s
# 730:	learn: 0.1294162	total: 6.19s	remaining: 2.28s
# 731:	learn: 0.1292656	total: 6.2s	remaining: 2.27s
# 732:	learn: 0.1290676	total: 6.21s	remaining: 2.26s
# 733:	learn: 0.1289524	total: 6.22s	remaining: 2.25s
# 734:	learn: 0.1288225	total: 6.22s	remaining: 2.24s
# 735:	learn: 0.1286154	total: 6.24s	remaining: 2.24s
# 736:	learn: 0.1285269	total: 6.24s	remaining: 2.23s
# 737:	learn: 0.1283485	total: 6.25s	remaining: 2.22s
# 738:	learn: 0.1281121	total: 6.26s	remaining: 2.21s
# 739:	learn: 0.1279479	total: 6.27s	remaining: 2.2s
# 740:	learn: 0.1278703	total: 6.28s	remaining: 2.19s
# 741:	learn: 0.1276672	total: 6.28s	remaining: 2.18s
# 742:	learn: 0.1274532	total: 6.29s	remaining: 2.18s
# 743:	learn: 0.1273281	total: 6.3s	remaining: 2.17s
# 744:	learn: 0.1270258	total: 6.31s	remaining: 2.16s
# 745:	learn: 0.1268594	total: 6.32s	remaining: 2.15s
# 746:	learn: 0.1266775	total: 6.32s	remaining: 2.14s
# 747:	learn: 0.1263387	total: 6.33s	remaining: 2.13s
# 748:	learn: 0.1262223	total: 6.34s	remaining: 2.13s
# 749:	learn: 0.1259596	total: 6.35s	remaining: 2.12s
# 750:	learn: 0.1256262	total: 6.36s	remaining: 2.11s
# 751:	learn: 0.1254826	total: 6.37s	remaining: 2.1s
# 752:	learn: 0.1252384	total: 6.37s	remaining: 2.09s
# 753:	learn: 0.1250307	total: 6.38s	remaining: 2.08s
# 754:	learn: 0.1249180	total: 6.39s	remaining: 2.07s
# 755:	learn: 0.1248361	total: 6.4s	remaining: 2.06s
# 756:	learn: 0.1244886	total: 6.41s	remaining: 2.06s
# 757:	learn: 0.1243911	total: 6.41s	remaining: 2.05s
# 758:	learn: 0.1241941	total: 6.42s	remaining: 2.04s
# 759:	learn: 0.1240612	total: 6.43s	remaining: 2.03s
# 760:	learn: 0.1238628	total: 6.44s	remaining: 2.02s
# 761:	learn: 0.1236229	total: 6.45s	remaining: 2.01s
# 762:	learn: 0.1234074	total: 6.45s	remaining: 2s
# 763:	learn: 0.1232907	total: 6.46s	remaining: 2s
# 764:	learn: 0.1232475	total: 6.47s	remaining: 1.99s
# 765:	learn: 0.1230564	total: 6.47s	remaining: 1.98s
# 766:	learn: 0.1227817	total: 6.48s	remaining: 1.97s
# 767:	learn: 0.1225670	total: 6.49s	remaining: 1.96s
# 768:	learn: 0.1223031	total: 6.5s	remaining: 1.95s
# 769:	learn: 0.1221808	total: 6.51s	remaining: 1.94s
# 770:	learn: 0.1221049	total: 6.51s	remaining: 1.93s
# 771:	learn: 0.1218673	total: 6.52s	remaining: 1.93s
# 772:	learn: 0.1217283	total: 6.53s	remaining: 1.92s
# 773:	learn: 0.1215713	total: 6.54s	remaining: 1.91s
# 774:	learn: 0.1213785	total: 6.54s	remaining: 1.9s
# 775:	learn: 0.1211616	total: 6.55s	remaining: 1.89s
# 776:	learn: 0.1209784	total: 6.56s	remaining: 1.88s
# 777:	learn: 0.1209005	total: 6.57s	remaining: 1.87s
# 778:	learn: 0.1207866	total: 6.58s	remaining: 1.87s
# 779:	learn: 0.1204927	total: 6.59s	remaining: 1.86s
# 780:	learn: 0.1202735	total: 6.6s	remaining: 1.85s
# 781:	learn: 0.1200557	total: 6.61s	remaining: 1.84s
# 782:	learn: 0.1199778	total: 6.61s	remaining: 1.83s
# 783:	learn: 0.1197728	total: 6.62s	remaining: 1.82s
# 784:	learn: 0.1196263	total: 6.63s	remaining: 1.81s
# 785:	learn: 0.1195127	total: 6.64s	remaining: 1.81s
# 786:	learn: 0.1194327	total: 6.64s	remaining: 1.8s
# 787:	learn: 0.1192618	total: 6.65s	remaining: 1.79s
# 788:	learn: 0.1190944	total: 6.66s	remaining: 1.78s
# 789:	learn: 0.1189189	total: 6.67s	remaining: 1.77s
# 790:	learn: 0.1188249	total: 6.68s	remaining: 1.76s
# 791:	learn: 0.1186070	total: 6.69s	remaining: 1.76s
# 792:	learn: 0.1185104	total: 6.69s	remaining: 1.75s
# 793:	learn: 0.1184123	total: 6.7s	remaining: 1.74s
# 794:	learn: 0.1182318	total: 6.71s	remaining: 1.73s
# 795:	learn: 0.1179761	total: 6.72s	remaining: 1.72s
# 796:	learn: 0.1178102	total: 6.72s	remaining: 1.71s
# 797:	learn: 0.1176652	total: 6.73s	remaining: 1.7s
# 798:	learn: 0.1175666	total: 6.74s	remaining: 1.7s
# 799:	learn: 0.1173086	total: 6.75s	remaining: 1.69s
# 800:	learn: 0.1172052	total: 6.76s	remaining: 1.68s
# 801:	learn: 0.1170478	total: 6.77s	remaining: 1.67s
# 802:	learn: 0.1169029	total: 6.78s	remaining: 1.66s
# 803:	learn: 0.1168220	total: 6.79s	remaining: 1.65s
# 804:	learn: 0.1165308	total: 6.79s	remaining: 1.65s
# 805:	learn: 0.1164608	total: 6.8s	remaining: 1.64s
# 806:	learn: 0.1162159	total: 6.81s	remaining: 1.63s
# 807:	learn: 0.1159880	total: 6.82s	remaining: 1.62s
# 808:	learn: 0.1158676	total: 6.82s	remaining: 1.61s
# 809:	learn: 0.1156809	total: 6.83s	remaining: 1.6s
# 810:	learn: 0.1156074	total: 6.84s	remaining: 1.59s
# 811:	learn: 0.1154442	total: 6.85s	remaining: 1.58s
# 812:	learn: 0.1153102	total: 6.86s	remaining: 1.58s
# 813:	learn: 0.1151994	total: 6.86s	remaining: 1.57s
# 814:	learn: 0.1150839	total: 6.87s	remaining: 1.56s
# 815:	learn: 0.1149958	total: 6.88s	remaining: 1.55s
# 816:	learn: 0.1148706	total: 6.89s	remaining: 1.54s
# 817:	learn: 0.1147186	total: 6.9s	remaining: 1.53s
# 818:	learn: 0.1145780	total: 6.9s	remaining: 1.52s
# 819:	learn: 0.1144305	total: 6.91s	remaining: 1.52s
# 820:	learn: 0.1143634	total: 6.92s	remaining: 1.51s
# 821:	learn: 0.1142469	total: 6.93s	remaining: 1.5s
# 822:	learn: 0.1140287	total: 6.93s	remaining: 1.49s
# 823:	learn: 0.1138940	total: 6.94s	remaining: 1.48s
# 824:	learn: 0.1137449	total: 6.95s	remaining: 1.47s
# 825:	learn: 0.1135704	total: 6.96s	remaining: 1.47s
# 826:	learn: 0.1134339	total: 6.97s	remaining: 1.46s
# 827:	learn: 0.1133022	total: 6.98s	remaining: 1.45s
# 828:	learn: 0.1132055	total: 6.99s	remaining: 1.44s
# 829:	learn: 0.1131152	total: 6.99s	remaining: 1.43s
# 830:	learn: 0.1129934	total: 7s	remaining: 1.42s
# 831:	learn: 0.1129132	total: 7.01s	remaining: 1.42s
# 832:	learn: 0.1128286	total: 7.02s	remaining: 1.41s
# 833:	learn: 0.1126402	total: 7.02s	remaining: 1.4s
# 834:	learn: 0.1125714	total: 7.03s	remaining: 1.39s
# 835:	learn: 0.1124485	total: 7.04s	remaining: 1.38s
# 836:	learn: 0.1123476	total: 7.05s	remaining: 1.37s
# 837:	learn: 0.1121757	total: 7.05s	remaining: 1.36s
# 838:	learn: 0.1118997	total: 7.06s	remaining: 1.35s
# 839:	learn: 0.1117113	total: 7.07s	remaining: 1.35s
# 840:	learn: 0.1116233	total: 7.08s	remaining: 1.34s
# 841:	learn: 0.1114251	total: 7.09s	remaining: 1.33s
# 842:	learn: 0.1112933	total: 7.09s	remaining: 1.32s
# 843:	learn: 0.1111540	total: 7.1s	remaining: 1.31s
# 844:	learn: 0.1110352	total: 7.11s	remaining: 1.3s
# 845:	learn: 0.1109243	total: 7.12s	remaining: 1.3s
# 846:	learn: 0.1108220	total: 7.13s	remaining: 1.29s
# 847:	learn: 0.1106780	total: 7.14s	remaining: 1.28s
# 848:	learn: 0.1106018	total: 7.15s	remaining: 1.27s
# 849:	learn: 0.1104666	total: 7.15s	remaining: 1.26s
# 850:	learn: 0.1103570	total: 7.16s	remaining: 1.25s
# 851:	learn: 0.1102048	total: 7.17s	remaining: 1.25s
# 852:	learn: 0.1100806	total: 7.18s	remaining: 1.24s
# 853:	learn: 0.1100016	total: 7.18s	remaining: 1.23s
# 854:	learn: 0.1098428	total: 7.19s	remaining: 1.22s
# 855:	learn: 0.1097364	total: 7.2s	remaining: 1.21s
# 856:	learn: 0.1096851	total: 7.21s	remaining: 1.2s
# 857:	learn: 0.1095645	total: 7.22s	remaining: 1.19s
# 858:	learn: 0.1094766	total: 7.22s	remaining: 1.19s
# 859:	learn: 0.1093418	total: 7.23s	remaining: 1.18s
# 860:	learn: 0.1092506	total: 7.24s	remaining: 1.17s
# 861:	learn: 0.1091101	total: 7.25s	remaining: 1.16s
# 862:	learn: 0.1090098	total: 7.26s	remaining: 1.15s
# 863:	learn: 0.1089038	total: 7.26s	remaining: 1.14s
# 864:	learn: 0.1087249	total: 7.27s	remaining: 1.13s
# 865:	learn: 0.1086055	total: 7.28s	remaining: 1.13s
# 866:	learn: 0.1083668	total: 7.29s	remaining: 1.12s
# 867:	learn: 0.1081872	total: 7.29s	remaining: 1.11s
# 868:	learn: 0.1079786	total: 7.3s	remaining: 1.1s
# 869:	learn: 0.1078339	total: 7.31s	remaining: 1.09s
# 870:	learn: 0.1076672	total: 7.32s	remaining: 1.08s
# 871:	learn: 0.1075568	total: 7.33s	remaining: 1.07s
# 872:	learn: 0.1074440	total: 7.33s	remaining: 1.07s
# 873:	learn: 0.1073654	total: 7.34s	remaining: 1.06s
# 874:	learn: 0.1072452	total: 7.35s	remaining: 1.05s
# 875:	learn: 0.1071179	total: 7.36s	remaining: 1.04s
# 876:	learn: 0.1070164	total: 7.36s	remaining: 1.03s
# 877:	learn: 0.1068724	total: 7.37s	remaining: 1.02s
# 878:	learn: 0.1067852	total: 7.38s	remaining: 1.02s
# 879:	learn: 0.1066844	total: 7.39s	remaining: 1.01s
# 880:	learn: 0.1065784	total: 7.4s	remaining: 1000ms
# 881:	learn: 0.1063441	total: 7.41s	remaining: 991ms
# 882:	learn: 0.1062062	total: 7.42s	remaining: 983ms
# 883:	learn: 0.1061473	total: 7.42s	remaining: 974ms
# 884:	learn: 0.1060452	total: 7.43s	remaining: 966ms
# 885:	learn: 0.1059592	total: 7.44s	remaining: 958ms
# 886:	learn: 0.1057954	total: 7.45s	remaining: 949ms
# 887:	learn: 0.1056668	total: 7.46s	remaining: 941ms
# 888:	learn: 0.1055205	total: 7.47s	remaining: 932ms
# 889:	learn: 0.1054154	total: 7.47s	remaining: 924ms
# 890:	learn: 0.1053288	total: 7.48s	remaining: 915ms
# 891:	learn: 0.1051364	total: 7.49s	remaining: 907ms
# 892:	learn: 0.1049299	total: 7.5s	remaining: 898ms
# 893:	learn: 0.1048351	total: 7.5s	remaining: 890ms
# 894:	learn: 0.1046752	total: 7.51s	remaining: 881ms
# 895:	learn: 0.1044425	total: 7.52s	remaining: 873ms
# 896:	learn: 0.1041726	total: 7.53s	remaining: 864ms
# 897:	learn: 0.1040911	total: 7.53s	remaining: 856ms
# 898:	learn: 0.1039966	total: 7.54s	remaining: 847ms
# 899:	learn: 0.1038516	total: 7.55s	remaining: 839ms
# 900:	learn: 0.1037483	total: 7.56s	remaining: 831ms
# 901:	learn: 0.1036058	total: 7.57s	remaining: 822ms
# 902:	learn: 0.1034927	total: 7.58s	remaining: 814ms
# 903:	learn: 0.1033883	total: 7.58s	remaining: 806ms
# 904:	learn: 0.1033055	total: 7.59s	remaining: 797ms
# 905:	learn: 0.1032112	total: 7.6s	remaining: 789ms
# 906:	learn: 0.1029956	total: 7.61s	remaining: 780ms
# 907:	learn: 0.1029162	total: 7.62s	remaining: 772ms
# 908:	learn: 0.1028075	total: 7.62s	remaining: 763ms
# 909:	learn: 0.1026607	total: 7.63s	remaining: 755ms
# 910:	learn: 0.1025944	total: 7.64s	remaining: 746ms
# 911:	learn: 0.1025003	total: 7.65s	remaining: 738ms
# 912:	learn: 0.1023871	total: 7.66s	remaining: 730ms
# 913:	learn: 0.1022240	total: 7.67s	remaining: 721ms
# 914:	learn: 0.1021459	total: 7.67s	remaining: 713ms
# 915:	learn: 0.1020541	total: 7.68s	remaining: 704ms
# 916:	learn: 0.1019428	total: 7.69s	remaining: 696ms
# 917:	learn: 0.1017856	total: 7.7s	remaining: 688ms
# 918:	learn: 0.1016744	total: 7.71s	remaining: 679ms
# 919:	learn: 0.1016066	total: 7.71s	remaining: 671ms
# 920:	learn: 0.1014268	total: 7.72s	remaining: 662ms
# 921:	learn: 0.1013120	total: 7.73s	remaining: 654ms
# 922:	learn: 0.1011226	total: 7.74s	remaining: 646ms
# 923:	learn: 0.1010072	total: 7.75s	remaining: 637ms
# 924:	learn: 0.1008630	total: 7.75s	remaining: 629ms
# 925:	learn: 0.1007378	total: 7.76s	remaining: 620ms
# 926:	learn: 0.1006260	total: 7.77s	remaining: 612ms
# 927:	learn: 0.1004167	total: 7.78s	remaining: 604ms
# 928:	learn: 0.1002345	total: 7.79s	remaining: 595ms
# 929:	learn: 0.1001006	total: 7.8s	remaining: 587ms
# 930:	learn: 0.1000329	total: 7.81s	remaining: 579ms
# 931:	learn: 0.0998953	total: 7.81s	remaining: 570ms
# 932:	learn: 0.0998005	total: 7.82s	remaining: 562ms
# 933:	learn: 0.0996411	total: 7.83s	remaining: 553ms
# 934:	learn: 0.0994764	total: 7.84s	remaining: 545ms
# 935:	learn: 0.0993028	total: 7.84s	remaining: 536ms
# 936:	learn: 0.0991906	total: 7.85s	remaining: 528ms
# 937:	learn: 0.0991181	total: 7.86s	remaining: 520ms
# 938:	learn: 0.0989649	total: 7.87s	remaining: 511ms
# 939:	learn: 0.0988750	total: 7.88s	remaining: 503ms
# 940:	learn: 0.0987983	total: 7.88s	remaining: 494ms
# 941:	learn: 0.0986586	total: 7.89s	remaining: 486ms
# 942:	learn: 0.0985225	total: 7.9s	remaining: 477ms
# 943:	learn: 0.0983486	total: 7.91s	remaining: 469ms
# 944:	learn: 0.0982275	total: 7.91s	remaining: 461ms
# 945:	learn: 0.0981662	total: 7.92s	remaining: 452ms
# 946:	learn: 0.0980960	total: 7.93s	remaining: 444ms
# 947:	learn: 0.0979809	total: 7.94s	remaining: 436ms
# 948:	learn: 0.0978618	total: 7.95s	remaining: 427ms
# 949:	learn: 0.0977637	total: 7.96s	remaining: 419ms
# 950:	learn: 0.0976628	total: 7.97s	remaining: 410ms
# 951:	learn: 0.0975875	total: 7.97s	remaining: 402ms
# 952:	learn: 0.0974697	total: 7.98s	remaining: 394ms
# 953:	learn: 0.0973656	total: 7.99s	remaining: 385ms
# 954:	learn: 0.0972571	total: 8s	remaining: 377ms
# 955:	learn: 0.0971017	total: 8.01s	remaining: 369ms
# 956:	learn: 0.0969693	total: 8.01s	remaining: 360ms
# 957:	learn: 0.0968053	total: 8.02s	remaining: 352ms
# 958:	learn: 0.0966920	total: 8.03s	remaining: 343ms
# 959:	learn: 0.0965744	total: 8.04s	remaining: 335ms
# 960:	learn: 0.0964818	total: 8.04s	remaining: 326ms
# 961:	learn: 0.0963803	total: 8.05s	remaining: 318ms
# 962:	learn: 0.0962754	total: 8.06s	remaining: 310ms
# 963:	learn: 0.0961237	total: 8.07s	remaining: 301ms
# 964:	learn: 0.0959801	total: 8.08s	remaining: 293ms
# 965:	learn: 0.0959220	total: 8.08s	remaining: 285ms
# 966:	learn: 0.0957845	total: 8.09s	remaining: 276ms
# 967:	learn: 0.0956824	total: 8.1s	remaining: 268ms
# 968:	learn: 0.0955531	total: 8.11s	remaining: 259ms
# 969:	learn: 0.0954793	total: 8.12s	remaining: 251ms
# 970:	learn: 0.0953720	total: 8.12s	remaining: 243ms
# 971:	learn: 0.0952903	total: 8.13s	remaining: 234ms
# 972:	learn: 0.0951390	total: 8.14s	remaining: 226ms
# 973:	learn: 0.0950228	total: 8.15s	remaining: 217ms
# 974:	learn: 0.0948980	total: 8.15s	remaining: 209ms
# 975:	learn: 0.0947510	total: 8.16s	remaining: 201ms
# 976:	learn: 0.0946620	total: 8.17s	remaining: 192ms
# 977:	learn: 0.0945257	total: 8.18s	remaining: 184ms
# 978:	learn: 0.0943912	total: 8.19s	remaining: 176ms
# 979:	learn: 0.0942598	total: 8.19s	remaining: 167ms
# 980:	learn: 0.0941035	total: 8.2s	remaining: 159ms
# 981:	learn: 0.0939109	total: 8.21s	remaining: 150ms
# 982:	learn: 0.0937276	total: 8.22s	remaining: 142ms
# 983:	learn: 0.0936141	total: 8.23s	remaining: 134ms
# 984:	learn: 0.0934694	total: 8.23s	remaining: 125ms
# 985:	learn: 0.0933326	total: 8.24s	remaining: 117ms
# 986:	learn: 0.0932291	total: 8.25s	remaining: 109ms
# 987:	learn: 0.0930655	total: 8.26s	remaining: 100ms
# 988:	learn: 0.0930197	total: 8.27s	remaining: 91.9ms
# 989:	learn: 0.0929109	total: 8.27s	remaining: 83.6ms
# 990:	learn: 0.0927654	total: 8.28s	remaining: 75.2ms
# 991:	learn: 0.0926936	total: 8.29s	remaining: 66.9ms
# 992:	learn: 0.0926057	total: 8.3s	remaining: 58.5ms
# 993:	learn: 0.0925498	total: 8.31s	remaining: 50.2ms
# 994:	learn: 0.0924210	total: 8.32s	remaining: 41.8ms
# 995:	learn: 0.0923390	total: 8.32s	remaining: 33.4ms
# 996:	learn: 0.0922673	total: 8.33s	remaining: 25.1ms
# 997:	learn: 0.0921444	total: 8.34s	remaining: 16.7ms
# 998:	learn: 0.0919989	total: 8.35s	remaining: 8.36ms
# 999:	learn: 0.0919277	total: 8.35s	remaining: 0us
# (750, 7)

# %%
"""
The method used to calculate the values in leaves.
    * Possible values:
    * Newton
    * Gradient
    * Exact

默认值:
Depends on the mode and the selected loss function:
    * Regression with Quantile or MAE loss functions — One Exact iteration.
    * Regression with any loss function but Quantile or MAE – One Gradient iteration.
    * Classification mode – Ten Newton iterations.
    * Multiclassification mode – One Newton iteration.
"""
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          "leaf_estimation_method": "Gradient"
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          "n_estimators": 200  # 默认n_estimators=1000
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          # 默认6 (16 if the growing policy is set to Lossguide)
          "max_depth": 5  # 设置最高16
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          # Random subspace method. The percentage of features to use at each split selection, when features are selected over again at random.
          "colsample_bylevel": 0.8  # 默认colsample_bylevel=1
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          # Used for reducing the gradient step.
          "learning_rate": 0.01
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          # Coefficient at the L2 regularization term of the cost function.
          "reg_lambda": 1  # 默认reg_lambda=3.0
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# (750, 7)

# %%
"""
If this parameter is set, the number of trees that are saved in the resulting model is defined as follows:
    Build the number of trees defined by the training parameters.
    Use the validation dataset to identify the iteration with the optimal value of the metric specified in  --eval-metric (eval_metric).
"""
params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          # 通过eval_metric选择最优模型
          # 必须设置eval_set参数
          "use_best_model": True
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Input In [22], in <cell line: 14>()
#       1 """
#       2 If this parameter is set, the number of trees that are saved in the resulting model is defined as follows:
#       3     Build the number of trees defined by the training parameters.
#       4     Use the validation dataset to identify the iteration with the optimal value of the metric specified in  --eval-metric (eval_metric).
#       5 """
#       6 params = {"loss_function": "MultiClass",
#       7           "allow_writing_files": False,
#       8           "verbose": False,
#    (...)
#      11           "use_best_model": True
#      12           }
# ---> 14 model = cat.train(pool=train_dataset, params=params)
#      15 model.predict(X_test).shape
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\catboost\core.py:5984, in train(pool, params, dtrain, logging_level, verbose, iterations, num_boost_round, evals, eval_set, plot, verbose_eval, metric_period, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, log_cout, log_cerr)
#    5981     eval_set = evals
#    5983 model = CatBoost(params)
# -> 5984 model.fit(X=pool, eval_set=eval_set, logging_level=logging_level, plot=plot, verbose=verbose,
#    5985           verbose_eval=verbose_eval, metric_period=metric_period,
#    5986           early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    5987           snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    5988           log_cout=log_cout, log_cerr=log_cerr)
#    5989 return model
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\catboost\core.py:2238, in CatBoost.fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2113 def fit(self, X, y=None, cat_features=None, text_features=None, embedding_features=None, pairs=None, sample_weight=None, group_id=None,
#    2114         group_weight=None, subgroup_id=None, pairs_weight=None, baseline=None, use_best_model=None,
#    2115         eval_set=None, verbose=None, logging_level=None, plot=False, column_description=None,
#    2116         verbose_eval=None, metric_period=None, silent=None, early_stopping_rounds=None,
#    2117         save_snapshot=None, snapshot_file=None, snapshot_interval=None, init_model=None, callbacks=None,
#    2118         log_cout=sys.stdout, log_cerr=sys.stderr):
#    2119     """
#    2120     Fit the CatBoost model.
#    2121
#    (...)
#    2236     model : CatBoost
#    2237     """
# -> 2238     return self._fit(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id,
#    2239                      pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot,
#    2240                      column_description, verbose_eval, metric_period, silent, early_stopping_rounds,
#    2241                      save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\catboost\core.py:2073, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2070 if y is None and not isinstance(X, PATH_TYPES + (Pool,)):
#    2071     raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
# -> 2073 train_params = self._prepare_train_params(
#    2074     X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    2075     pairs=pairs, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#    2076     subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline, use_best_model=use_best_model,
#    2077     eval_set=eval_set, verbose=verbose, logging_level=logging_level, plot=plot,
#    2078     column_description=column_description, verbose_eval=verbose_eval, metric_period=metric_period,
#    2079     silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    2080     snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    2081     callbacks=callbacks
#    2082 )
#    2083 params = train_params["params"]
#    2084 train_pool = train_params["train_pool"]
#
# File ~\anaconda3\envs\pytorch_env\lib\site-packages\catboost\core.py:2046, in CatBoost._prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    2043         raise CatBoostError("Invalid type of 'eval_set': {}, while expected Pool or (X, y) or filename, or list thereof.".format(type(eval_set)))
#    2045 if self.get_param('use_best_model') and eval_total_row_count == 0:
# -> 2046     raise CatBoostError("To employ param {'use_best_model': True} provide non-empty 'eval_set'.")
#    2048 if (init_model is not None) and isinstance(init_model, PATH_TYPES):
#    2049     try:
#
# CatBoostError: To employ param {'use_best_model': True} provide non-empty 'eval_set'.

# %%
# %%timeit

params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          "task_type" : "CPU"
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# 8.02 s ± 283 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

params = {"loss_function": "MultiClass",
          "allow_writing_files": False,
          "verbose": False,
          "task_type" : "GPU"  # 默认task_type='CPU'
          }

model = cat.train(pool=train_dataset, params=params)
model.predict(X_test).shape
# Out:
# 6.08 s ± 217 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
