# %%
from PIL import Image
from torchvision import transforms

# %%
img = Image.open('test_picture/1yuan.jpg').convert('RGB')  # 读取图片(RGB模式)
img
# Out:
# <PIL.Image.Image image mode=RGB size=704x355 at 0x17D7D4529C8>

# %%
# Converts a PIL Image or numpy.ndarray (H x W x C) in the range [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0]
trans = transforms.ToTensor()
tensor_img = trans(img)
tensor_img  # 范围为[0.0, 1.0]
# Out:
# tensor([[[0.7412, 0.6941, 0.7882,  ..., 0.7725, 0.7725, 0.7529],
#          [0.6745, 0.6549, 0.7451,  ..., 0.8157, 0.8157, 0.8431],
#          [0.7294, 0.7765, 0.7490,  ..., 0.8000, 0.7961, 0.7843],
#          ...,
#          [0.7725, 0.7569, 0.7529,  ..., 0.8588, 0.8588, 0.8471],
#          [0.8235, 0.8039, 0.8314,  ..., 0.8431, 0.8510, 0.8431],
#          [0.7451, 0.7451, 0.7373,  ..., 0.8549, 0.8667, 0.8588]],
#
#         [[0.7529, 0.7059, 0.8000,  ..., 0.8078, 0.8078, 0.7882],
#          [0.6863, 0.6667, 0.7569,  ..., 0.8510, 0.8510, 0.8784],
#          [0.7412, 0.7882, 0.7608,  ..., 0.8353, 0.8314, 0.8196],
#          ...,
#          [0.7961, 0.7765, 0.7725,  ..., 0.8941, 0.8941, 0.8824],
#          [0.8471, 0.8235, 0.8510,  ..., 0.8784, 0.8863, 0.8784],
#          [0.7686, 0.7647, 0.7569,  ..., 0.8902, 0.9020, 0.8941]],
#
#         [[0.7176, 0.6706, 0.7647,  ..., 0.7882, 0.7882, 0.7686],
#          [0.6510, 0.6314, 0.7216,  ..., 0.8314, 0.8314, 0.8588],
#          [0.7137, 0.7608, 0.7333,  ..., 0.8157, 0.8118, 0.8000],
#          ...,
#          [0.7804, 0.7608, 0.7569,  ..., 0.8824, 0.8824, 0.8706],
#          [0.8314, 0.8078, 0.8353,  ..., 0.8667, 0.8745, 0.8667],
#          [0.7529, 0.7490, 0.7412,  ..., 0.8784, 0.8902, 0.8824]]])

# %%
tensor_img.shape  # C x H x W
# Out:
# torch.Size([3, 355, 704])
