# %%
import torch

# %%
# 类似numpy.linspace
torch.linspace(-2, 7, steps=10)  # 在指定的间隔内返回均匀间隔的数字
# Out:
# tensor([-2., -1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.])

# %%
# 类似numpy.logspace
torch.logspace(-2, 7, steps=10, base=10)  # 以10为底
# Out:
# tensor([1.0000e-02, 1.0000e-01, 1.0000e+00, 1.0000e+01, 1.0000e+02, 1.0000e+03,
#         1.0000e+04, 1.0000e+05, 1.0000e+06, 1.0000e+07])
