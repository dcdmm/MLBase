# %%
example = '  I  Duanmengmeng Love?'
example
# Out:
# '  I  Duanmengmeng Love?'

# %%
example.startswith('')  # 开头是否为空白字符
# Out:
# True

# %%
example.endswith('Love?')  # 结尾是否为'Love?'
# Out:
# True
