# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ### 参考torch.optim.lr_scheduler.ReduceLROnPlateau

# %%
X = datasets.fetch_covtype().data[:5000]
y = datasets.fetch_covtype().target[:5000]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

print(X_train.shape, y_train.shape)

enc = OrdinalEncoder()
y_train = enc.fit_transform(y_train.reshape(-1, 1)).reshape(-1, )
y_test = enc.transform(y_test.reshape(-1, 1)).reshape(-1, )
print(np.unique(y_train))  # 7分类任务

X_train, X_test, y_train, y_test = tf.constant(X_train), tf.constant(X_test), tf.constant(y_train), tf.constant(y_test)
# Out:
# (4500, 54) (4500,)
# [0. 1. 2. 3. 4. 5. 6.]

# %%
inputs = tf.keras.Input(shape=(54,))
x = tf.keras.layers.Dense(256, activation='tanh')(inputs)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128)(x)
predictions = tf.keras.layers.Dense(7)(x)
model = tf.keras.Model(inputs=inputs, outputs=predictions)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 54)]              0
#
#  dense (Dense)               (None, 256)               14080
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 64,391
# Trainable params: 64,391
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",  # 'loss'/'val_loss'或accuracy/val_accuracy(根据metrics)
                                         mode='min',  # 由monitory='val_loss',故设置mode='min'
                                         # factor by which the learning rate will be reduced. new_lr = lr * factor.
                                         factor=0.5,
                                         # number of epochs with no improvement after which learning rate will be reduced.
                                         patience=3,
                                         # threshold for measuring the new optimum, to only focus on significant changes.
                                         min_delta=0.0001,
                                         # number of epochs to wait before resuming normal operation after lr has been reduced.
                                         cooldown=0,
                                         min_lr=0  # 学习率的下限
                                         )

]
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test),
          # List of keras.callbacks.Callback instances.
          callbacks=callbacks)
# Out:
# Epoch 1/50
# 141/141 [==============================] - 2s 5ms/step - loss: 1.3699 - accuracy: 0.4598 - val_loss: 1.1793 - val_accuracy: 0.5560 - lr: 0.0010
# Epoch 2/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.2380 - accuracy: 0.5091 - val_loss: 1.2488 - val_accuracy: 0.4940 - lr: 0.0010
# Epoch 3/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.2071 - accuracy: 0.5087 - val_loss: 1.1214 - val_accuracy: 0.5420 - lr: 0.0010
# Epoch 4/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1763 - accuracy: 0.5182 - val_loss: 1.1729 - val_accuracy: 0.5480 - lr: 0.0010
# Epoch 5/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1940 - accuracy: 0.5173 - val_loss: 1.0815 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 6/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1684 - accuracy: 0.5280 - val_loss: 1.1383 - val_accuracy: 0.5040 - lr: 0.0010
# Epoch 7/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.1467 - accuracy: 0.5287 - val_loss: 1.1176 - val_accuracy: 0.5540 - lr: 0.0010
# Epoch 8/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.1638 - accuracy: 0.5340 - val_loss: 1.0985 - val_accuracy: 0.5900 - lr: 0.0010
# Epoch 9/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0793 - accuracy: 0.5584 - val_loss: 0.9950 - val_accuracy: 0.5980 - lr: 5.0000e-04
# Epoch 10/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.0717 - accuracy: 0.5551 - val_loss: 0.9747 - val_accuracy: 0.6180 - lr: 5.0000e-04
# Epoch 11/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.0659 - accuracy: 0.5584 - val_loss: 0.9554 - val_accuracy: 0.6340 - lr: 5.0000e-04
# Epoch 12/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.0504 - accuracy: 0.5720 - val_loss: 0.9289 - val_accuracy: 0.6520 - lr: 5.0000e-04
# Epoch 13/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.0277 - accuracy: 0.5758 - val_loss: 0.9183 - val_accuracy: 0.6420 - lr: 5.0000e-04
# Epoch 14/50
# 141/141 [==============================] - 0s 3ms/step - loss: 1.0074 - accuracy: 0.5860 - val_loss: 0.9161 - val_accuracy: 0.6600 - lr: 5.0000e-04
# Epoch 15/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9953 - accuracy: 0.5891 - val_loss: 0.9097 - val_accuracy: 0.6480 - lr: 5.0000e-04
# Epoch 16/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9786 - accuracy: 0.5996 - val_loss: 0.8873 - val_accuracy: 0.6660 - lr: 5.0000e-04
# Epoch 17/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.9699 - accuracy: 0.5951 - val_loss: 0.8908 - val_accuracy: 0.6540 - lr: 5.0000e-04
# Epoch 18/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9701 - accuracy: 0.5931 - val_loss: 0.8878 - val_accuracy: 0.6780 - lr: 5.0000e-04
# Epoch 19/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9466 - accuracy: 0.6116 - val_loss: 0.8295 - val_accuracy: 0.6900 - lr: 5.0000e-04
# Epoch 20/50
# 141/141 [==============================] - 1s 5ms/step - loss: 0.9652 - accuracy: 0.6013 - val_loss: 0.8335 - val_accuracy: 0.6760 - lr: 5.0000e-04
# Epoch 21/50
# 141/141 [==============================] - 1s 5ms/step - loss: 0.9220 - accuracy: 0.6173 - val_loss: 0.8031 - val_accuracy: 0.7160 - lr: 5.0000e-04
# Epoch 22/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.9078 - accuracy: 0.6222 - val_loss: 0.7996 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 23/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9141 - accuracy: 0.6227 - val_loss: 0.8172 - val_accuracy: 0.6860 - lr: 5.0000e-04
# Epoch 24/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8990 - accuracy: 0.6222 - val_loss: 0.7792 - val_accuracy: 0.6880 - lr: 5.0000e-04
# Epoch 25/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.8981 - accuracy: 0.6229 - val_loss: 0.7999 - val_accuracy: 0.6860 - lr: 5.0000e-04
# Epoch 26/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9132 - accuracy: 0.6167 - val_loss: 0.7833 - val_accuracy: 0.6940 - lr: 5.0000e-04
# Epoch 27/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.9035 - accuracy: 0.6227 - val_loss: 0.7926 - val_accuracy: 0.6760 - lr: 5.0000e-04
# Epoch 28/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8563 - accuracy: 0.6444 - val_loss: 0.7697 - val_accuracy: 0.7120 - lr: 2.5000e-04
# Epoch 29/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.8426 - accuracy: 0.6476 - val_loss: 0.7261 - val_accuracy: 0.7360 - lr: 2.5000e-04
# Epoch 30/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8215 - accuracy: 0.6527 - val_loss: 0.7467 - val_accuracy: 0.7220 - lr: 2.5000e-04
# Epoch 31/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.8197 - accuracy: 0.6553 - val_loss: 0.7391 - val_accuracy: 0.7280 - lr: 2.5000e-04
# Epoch 32/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.8177 - accuracy: 0.6587 - val_loss: 0.6802 - val_accuracy: 0.7400 - lr: 2.5000e-04
# Epoch 33/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7911 - accuracy: 0.6720 - val_loss: 0.7071 - val_accuracy: 0.7220 - lr: 2.5000e-04
# Epoch 34/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7815 - accuracy: 0.6707 - val_loss: 0.6832 - val_accuracy: 0.7320 - lr: 2.5000e-04
# Epoch 35/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7776 - accuracy: 0.6720 - val_loss: 0.6865 - val_accuracy: 0.7420 - lr: 2.5000e-04
# Epoch 36/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7606 - accuracy: 0.6811 - val_loss: 0.6774 - val_accuracy: 0.7560 - lr: 1.2500e-04
# Epoch 37/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7431 - accuracy: 0.6833 - val_loss: 0.6797 - val_accuracy: 0.7360 - lr: 1.2500e-04
# Epoch 38/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7507 - accuracy: 0.6831 - val_loss: 0.6609 - val_accuracy: 0.7560 - lr: 1.2500e-04
# Epoch 39/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7445 - accuracy: 0.6804 - val_loss: 0.6446 - val_accuracy: 0.7640 - lr: 1.2500e-04
# Epoch 40/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.7437 - accuracy: 0.6904 - val_loss: 0.6584 - val_accuracy: 0.7700 - lr: 1.2500e-04
# Epoch 41/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7369 - accuracy: 0.6889 - val_loss: 0.6431 - val_accuracy: 0.7680 - lr: 1.2500e-04
# Epoch 42/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.7334 - accuracy: 0.6969 - val_loss: 0.6511 - val_accuracy: 0.7500 - lr: 1.2500e-04
# Epoch 43/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7243 - accuracy: 0.6924 - val_loss: 0.6468 - val_accuracy: 0.7680 - lr: 1.2500e-04
# Epoch 44/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7200 - accuracy: 0.6958 - val_loss: 0.6418 - val_accuracy: 0.7640 - lr: 1.2500e-04
# Epoch 45/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.7159 - accuracy: 0.7049 - val_loss: 0.6300 - val_accuracy: 0.7700 - lr: 1.2500e-04
# Epoch 46/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7075 - accuracy: 0.6987 - val_loss: 0.6333 - val_accuracy: 0.7640 - lr: 1.2500e-04
# Epoch 47/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7085 - accuracy: 0.7031 - val_loss: 0.6147 - val_accuracy: 0.7720 - lr: 1.2500e-04
# Epoch 48/50
# 141/141 [==============================] - 0s 3ms/step - loss: 0.7078 - accuracy: 0.6987 - val_loss: 0.6394 - val_accuracy: 0.7600 - lr: 1.2500e-04
# Epoch 49/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.7008 - accuracy: 0.7064 - val_loss: 0.6298 - val_accuracy: 0.7520 - lr: 1.2500e-04
# Epoch 50/50
# 141/141 [==============================] - 0s 4ms/step - loss: 0.7001 - accuracy: 0.7064 - val_loss: 0.6235 - val_accuracy: 0.7500 - lr: 1.2500e-04

# %%
# 学习率衰减情况
model.history.history['lr']
# Out:
# [0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.001,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.0005,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.00025,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125,
#  0.000125]
