# %%
# %run ipython_scripy_test/hello.py  # 执行了整个python脚本
# Out:
# Hello python !
# play LOL !

# %%
hello('duanchao')
# Out:
# Hello duanchao !

# %%
game('DNF')  # 脚本中的函数被加载入Jupyter notebook
# Out:
# play DNF !
