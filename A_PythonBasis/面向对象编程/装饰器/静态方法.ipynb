# %%
class People:
    country = 'china'

    # 静态方法(使用staticmethod作为装饰器)
    @staticmethod
    def getCountry(age):  # 静态方法不需要多定义参数cls
        print(age)
        return People.country

print(People.getCountry(22))
# Out:
# 22
# china
