# %%
import tensorflow as tf

# %% [markdown]
# ### 参考numpy索引切片

# %%
tor_mul = tf.random.stateless_normal(shape=(5, 7, 4), seed=(1, 2))
tor_mul
# Out:
# <tf.Tensor: shape=(5, 7, 4), dtype=float32, numpy=
# array([[[ 0.5441101 ,  0.20738031,  0.07356433,  0.04643455],
#         [-1.30159   , -0.95385665,  0.84172857,  1.9396868 ],
#         [ 0.6512578 ,  1.1048867 ,  1.3746228 ,  1.148752  ],
#         [ 1.0821314 ,  0.55104923,  0.07009614,  0.707385  ],
#         [ 0.88857085, -0.46432722,  1.2084333 , -0.79011595],
#         [-0.7304904 , -0.7207538 ,  0.36527526, -0.16950758],
#         [ 0.20318079, -0.90232295, -0.65045786,  2.4152768 ]],
#
#        [[ 0.5703469 ,  0.8770354 ,  0.36876458, -0.57617044],
#         [-0.66170377, -1.0227758 ,  0.6109012 , -0.2563904 ],
#         [ 2.1067173 , -0.04597485, -0.2069098 ,  0.6324636 ],
#         [ 0.42266   ,  0.05165391, -0.73736423, -1.1144085 ],
#         [ 0.4858592 , -1.4368211 ,  1.7883171 ,  0.47844714],
#         [-1.3764827 ,  0.79399854, -2.1332254 , -0.17303157],
#         [-1.7487346 , -0.46926638, -1.5576217 , -0.8941696 ]],
#
#        [[ 0.21992801,  0.148727  , -0.8418422 , -1.4702468 ],
#         [-0.48143446,  0.91328293,  0.75411063, -0.45545915],
#         [-0.5482289 , -0.95850194,  0.17038241,  0.6320987 ],
#         [-0.11597513, -0.9985191 , -0.74675995, -1.0898854 ],
#         [-0.8605409 , -0.6180766 ,  1.0560111 ,  0.05375697],
#         [ 0.17810917,  0.2230358 ,  1.8982831 ,  1.9089541 ],
#         [ 1.1501542 ,  0.04781999, -0.29954264, -0.39296842]],
#
#        [[-0.40649495,  0.9669032 , -0.96526605,  1.2539274 ],
#         [-0.75256586,  1.9798673 ,  0.61334556, -1.0796703 ],
#         [-2.4858878 , -1.1869806 ,  0.36859393,  0.1624776 ],
#         [-0.15005542, -0.87605983,  0.8303878 , -0.61972153],
#         [-0.10822038, -0.31497297, -0.9072747 ,  1.3264713 ],
#         [ 0.5923632 , -0.614873  ,  1.5092608 , -0.92937726],
#         [ 0.64020216, -0.16729811,  0.23366703,  1.1880982 ]],
#
#        [[ 0.01143784, -1.0229038 ,  2.0762193 ,  0.43485036],
#         [-0.42088583,  0.37880573, -0.8772612 ,  0.56490797],
#         [-0.13349706, -1.2438124 , -0.01040924,  1.7967224 ],
#         [ 1.9191644 ,  0.18920553,  0.30753702,  0.62975395],
#         [ 1.9127743 ,  1.3880405 , -1.2387553 ,  0.30893365],
#         [-1.1250733 ,  1.0818013 , -1.5788761 , -1.2301681 ],
#         [ 0.7859695 ,  0.14259626, -1.1223226 , -1.7291968 ]]],
#       dtype=float32)>

# %%
tor_mul[0, 1, 1]  # 索引,返回常量tensor
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-0.95385665>

# %%
tor_mul[0]  # 从第零个维度开始索引切片(DataFrame从列开始进行索引切片)
# Out:
# <tf.Tensor: shape=(7, 4), dtype=float32, numpy=
# array([[ 0.5441101 ,  0.20738031,  0.07356433,  0.04643455],
#        [-1.30159   , -0.95385665,  0.84172857,  1.9396868 ],
#        [ 0.6512578 ,  1.1048867 ,  1.3746228 ,  1.148752  ],
#        [ 1.0821314 ,  0.55104923,  0.07009614,  0.707385  ],
#        [ 0.88857085, -0.46432722,  1.2084333 , -0.79011595],
#        [-0.7304904 , -0.7207538 ,  0.36527526, -0.16950758],
#        [ 0.20318079, -0.90232295, -0.65045786,  2.4152768 ]],
#       dtype=float32)>

# %%
tor_mul[0, 0, -1]  # 索引,返回常量tensor.支持负数索引
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.046434548>

# %%
tor_mul[0:2]  # 切片,返回常量tensor
# Out:
# <tf.Tensor: shape=(2, 7, 4), dtype=float32, numpy=
# array([[[ 0.5441101 ,  0.20738031,  0.07356433,  0.04643455],
#         [-1.30159   , -0.95385665,  0.84172857,  1.9396868 ],
#         [ 0.6512578 ,  1.1048867 ,  1.3746228 ,  1.148752  ],
#         [ 1.0821314 ,  0.55104923,  0.07009614,  0.707385  ],
#         [ 0.88857085, -0.46432722,  1.2084333 , -0.79011595],
#         [-0.7304904 , -0.7207538 ,  0.36527526, -0.16950758],
#         [ 0.20318079, -0.90232295, -0.65045786,  2.4152768 ]],
#
#        [[ 0.5703469 ,  0.8770354 ,  0.36876458, -0.57617044],
#         [-0.66170377, -1.0227758 ,  0.6109012 , -0.2563904 ],
#         [ 2.1067173 , -0.04597485, -0.2069098 ,  0.6324636 ],
#         [ 0.42266   ,  0.05165391, -0.73736423, -1.1144085 ],
#         [ 0.4858592 , -1.4368211 ,  1.7883171 ,  0.47844714],
#         [-1.3764827 ,  0.79399854, -2.1332254 , -0.17303157],
#         [-1.7487346 , -0.46926638, -1.5576217 , -0.8941696 ]]],
#       dtype=float32)>

# %%
tor_mul[0:2, 0:3, 0]  # 在多个维度上索引切片
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 0.5441101 , -1.30159   ,  0.6512578 ],
#        [ 0.5703469 , -0.66170377,  2.1067173 ]], dtype=float32)>

# %%
tor_mul[0:2, 0:6:2, 2]  # 第一个维度上的切片步长为2(不支持步长为负数),切片范围为0-6
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 0.07356433,  1.3746228 ,  1.2084333 ],
#        [ 0.36876458, -0.2069098 ,  1.7883171 ]], dtype=float32)>

# %%
tor_mul[:]  # 等价于tor_mul[:, :, :]
# Out:
# <tf.Tensor: shape=(5, 7, 4), dtype=float32, numpy=
# array([[[ 0.5441101 ,  0.20738031,  0.07356433,  0.04643455],
#         [-1.30159   , -0.95385665,  0.84172857,  1.9396868 ],
#         [ 0.6512578 ,  1.1048867 ,  1.3746228 ,  1.148752  ],
#         [ 1.0821314 ,  0.55104923,  0.07009614,  0.707385  ],
#         [ 0.88857085, -0.46432722,  1.2084333 , -0.79011595],
#         [-0.7304904 , -0.7207538 ,  0.36527526, -0.16950758],
#         [ 0.20318079, -0.90232295, -0.65045786,  2.4152768 ]],
#
#        [[ 0.5703469 ,  0.8770354 ,  0.36876458, -0.57617044],
#         [-0.66170377, -1.0227758 ,  0.6109012 , -0.2563904 ],
#         [ 2.1067173 , -0.04597485, -0.2069098 ,  0.6324636 ],
#         [ 0.42266   ,  0.05165391, -0.73736423, -1.1144085 ],
#         [ 0.4858592 , -1.4368211 ,  1.7883171 ,  0.47844714],
#         [-1.3764827 ,  0.79399854, -2.1332254 , -0.17303157],
#         [-1.7487346 , -0.46926638, -1.5576217 , -0.8941696 ]],
#
#        [[ 0.21992801,  0.148727  , -0.8418422 , -1.4702468 ],
#         [-0.48143446,  0.91328293,  0.75411063, -0.45545915],
#         [-0.5482289 , -0.95850194,  0.17038241,  0.6320987 ],
#         [-0.11597513, -0.9985191 , -0.74675995, -1.0898854 ],
#         [-0.8605409 , -0.6180766 ,  1.0560111 ,  0.05375697],
#         [ 0.17810917,  0.2230358 ,  1.8982831 ,  1.9089541 ],
#         [ 1.1501542 ,  0.04781999, -0.29954264, -0.39296842]],
#
#        [[-0.40649495,  0.9669032 , -0.96526605,  1.2539274 ],
#         [-0.75256586,  1.9798673 ,  0.61334556, -1.0796703 ],
#         [-2.4858878 , -1.1869806 ,  0.36859393,  0.1624776 ],
#         [-0.15005542, -0.87605983,  0.8303878 , -0.61972153],
#         [-0.10822038, -0.31497297, -0.9072747 ,  1.3264713 ],
#         [ 0.5923632 , -0.614873  ,  1.5092608 , -0.92937726],
#         [ 0.64020216, -0.16729811,  0.23366703,  1.1880982 ]],
#
#        [[ 0.01143784, -1.0229038 ,  2.0762193 ,  0.43485036],
#         [-0.42088583,  0.37880573, -0.8772612 ,  0.56490797],
#         [-0.13349706, -1.2438124 , -0.01040924,  1.7967224 ],
#         [ 1.9191644 ,  0.18920553,  0.30753702,  0.62975395],
#         [ 1.9127743 ,  1.3880405 , -1.2387553 ,  0.30893365],
#         [-1.1250733 ,  1.0818013 , -1.5788761 , -1.2301681 ],
#         [ 0.7859695 ,  0.14259626, -1.1223226 , -1.7291968 ]]],
#       dtype=float32)>

# %%
tor_mul[::2]  # 第一个维度上切片步长为2,范围为整个维度;等价于tor_mul[::2, :, :]
# Out:
# <tf.Tensor: shape=(3, 7, 4), dtype=float32, numpy=
# array([[[ 0.5441101 ,  0.20738031,  0.07356433,  0.04643455],
#         [-1.30159   , -0.95385665,  0.84172857,  1.9396868 ],
#         [ 0.6512578 ,  1.1048867 ,  1.3746228 ,  1.148752  ],
#         [ 1.0821314 ,  0.55104923,  0.07009614,  0.707385  ],
#         [ 0.88857085, -0.46432722,  1.2084333 , -0.79011595],
#         [-0.7304904 , -0.7207538 ,  0.36527526, -0.16950758],
#         [ 0.20318079, -0.90232295, -0.65045786,  2.4152768 ]],
#
#        [[ 0.21992801,  0.148727  , -0.8418422 , -1.4702468 ],
#         [-0.48143446,  0.91328293,  0.75411063, -0.45545915],
#         [-0.5482289 , -0.95850194,  0.17038241,  0.6320987 ],
#         [-0.11597513, -0.9985191 , -0.74675995, -1.0898854 ],
#         [-0.8605409 , -0.6180766 ,  1.0560111 ,  0.05375697],
#         [ 0.17810917,  0.2230358 ,  1.8982831 ,  1.9089541 ],
#         [ 1.1501542 ,  0.04781999, -0.29954264, -0.39296842]],
#
#        [[ 0.01143784, -1.0229038 ,  2.0762193 ,  0.43485036],
#         [-0.42088583,  0.37880573, -0.8772612 ,  0.56490797],
#         [-0.13349706, -1.2438124 , -0.01040924,  1.7967224 ],
#         [ 1.9191644 ,  0.18920553,  0.30753702,  0.62975395],
#         [ 1.9127743 ,  1.3880405 , -1.2387553 ,  0.30893365],
#         [-1.1250733 ,  1.0818013 , -1.5788761 , -1.2301681 ],
#         [ 0.7859695 ,  0.14259626, -1.1223226 , -1.7291968 ]]],
#       dtype=float32)>

# %%
tor_complex = tf.random.stateless_normal(shape=(12, 7, 8, 10, 9, 15, 14), seed=(1, 2))
tor_complex.shape
# Out:
# TensorShape([12, 7, 8, 10, 9, 15, 14])

# %%
print(tor_complex[1:5].shape)
print(tor_complex[1:5, :, :, :, :, :].shape)
print(tor_complex[1:5, ...].shape)  # ...:剩余维度上所有数据
# Out:
# (4, 7, 8, 10, 9, 15, 14)
# (4, 7, 8, 10, 9, 15, 14)
# (4, 7, 8, 10, 9, 15, 14)

# %%
print(tor_complex[:, :, :, :, :, :, 2:4].shape)
print(tor_complex[..., 2:4].shape)
# Out:
# (12, 7, 8, 10, 9, 15, 2)
# (12, 7, 8, 10, 9, 15, 2)

# %%
print(tor_complex[2:7, :, :, :, :, :, 4].shape)
print(tor_complex[2:7, ..., 4].shape)
# Out:
# (5, 7, 8, 10, 9, 15)
# (5, 7, 8, 10, 9, 15)
