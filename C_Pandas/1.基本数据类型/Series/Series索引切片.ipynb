# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### .at方法
# Similar to loc, in that both provide label-based lookups. Use at if you only need to get or set a single value in a DataFrame or Series.
#
# ### .iat方法
# Similar to iloc, in that both provide integer-based lookups. Use iat if you only need to get or set a single value in a DataFrame or Series.

# %%
obj1 = pd.Series(np.arange(7.), index=list('abcdefg'))
obj1
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# dtype: float64

# %% [markdown]
# ### 标签索引(优先级高于位置索引)

# %%
print(obj1['b'])
print(obj1.loc['b'])
# Out:
# 1.0
# 1.0

# %%
print(obj1[['b', 'a', 'd']], end='\n\n')
print(obj1.loc[['b', 'a', 'd']])
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64
#
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %%
print(obj1['b':'e'], end='\n\n')  # 按照标签进行切片(包含尾部)
print(obj1.loc['b':'e'])
# Out:
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64
#
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %% [markdown]
# ### 位置索引

# %%
print(obj1[1])  # 位置索引(容易产生混淆,不推荐使用)
print(obj1.iloc[1])
# Out:
# 1.0
# 1.0
# C:\Users\duanm\AppData\Local\Temp\ipykernel_14860\3662632557.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(obj1[1])  # 位置索引(容易产生混淆,不推荐使用)

# %%
print(obj1[-1])  # 负数索引
print(obj1.iloc[-1])
# Out:
# 6.0
# 6.0
# C:\Users\duanm\AppData\Local\Temp\ipykernel_14860\2225457155.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(obj1[-1])  # 负数索引

# %%
print(obj1[2:4], end='\n\n')  # 按照标签位置进行切片(不包含尾部)
print(obj1.iloc[2:4])  # 不包含尾部
# Out:
# c    2.0
# d    3.0
# dtype: float64
#
# c    2.0
# d    3.0
# dtype: float64

# %%
print(obj1[[1, 3, 5]], end='\n\n')
print(obj1.iloc[[1, 3, 5]])
# Out:
# b    1.0
# d    3.0
# f    5.0
# dtype: float64
#
# b    1.0
# d    3.0
# f    5.0
# dtype: float64
# C:\Users\duanm\AppData\Local\Temp\ipykernel_14860\3660071480.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(obj1[[1, 3, 5]], end='\n\n')

# %%
print(print(obj1.iloc[3]), end='\n\n')
print(print(obj1.iloc[3:4]))  # 切片的结果为Series
# Out:
# 3.0
# None
#
# d    3.0
# dtype: float64
# None

# %% [markdown]
# ### 布尔索引

# %%
obj1 < 5
# Out:
# a     True
# b     True
# c     True
# d     True
# e     True
# f    False
# g    False
# dtype: bool

# %%
obj1[obj1 < 5]
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
a = obj1 < 5
obj1[a.values]  # 与上等价(按序)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
b = obj1 < 5
b.index = ['g', 'f', 'e', 'd', 'c', 'b', 'a']
# Series与字典类似(一一映射关系,映射键为index)
obj1[b]
# Out:
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# dtype: float64
