# %% [markdown]
# <font color='red' size='4'>表达式:</font>
# \begin{equation}
#     y=
#     \begin{cases}
#         1, & x > 0 \\
#         0, & x = 0 \\
#         -1, & x < 0
#     \end{cases}
# \end{equation}

# %%
import torch
import numpy as np

# 等价numpy.sign
torch.sign(torch.tensor([-5., 4.5, 0, np.nan]))
# Out:
# tensor([-1.,  1.,  0.,  0.])
