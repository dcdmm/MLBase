# %%
# %matplotlib inline
import  numpy as np
import  matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 1, figsize=(10, 7))
x = np.linspace(0, 1, 500)
y1 = np.sin(4 * np.pi * x) * np.exp(-5*x)
y2 = -np.sin(4 * np.pi * x) * np.exp(-5*x)
axes.fill(x, y1, color='red', # color
          alpha=0.5, label='y1') # 绘制曲线y1和y1首尾坐标连线构成的直线之间的区域
axes.fill(x, y2, color='g', alpha=0.5, label='y2') 
axes.plot([x[0], x[-1]], [y1[0], y1[-1]], c='b', alpha=1, linewidth=3)
axes.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-649e52818a2a> in <module>
#       7 y1 = np.sin(4 * np.pi * x) * np.exp(-5*x)
#       8 y2 = -np.sin(4 * np.pi * x) * np.exp(-5*x)
# ----> 9 axes.fill(x, y1, color=['red', 'green'], alpha=0.5, label='y1') #绘制曲线y1和y1首尾坐标连线构成的直线之间的区域
#      10 axes.fill(x, y2, color='g', alpha=0.5, label='y2')
#      11 axes.plot([x[0], x[-1]], [y1[0], y1[-1]], c='b', alpha=1, linewidth=3)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill(self, data, *args, **kwargs)
#    5089         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
#    5090         # _get_patches_for_fill returns a generator, convert it to a list.
# -> 5091         patches = [*self._get_patches_for_fill(*args, data=data, **kwargs)]
#    5092         for poly in patches:
#    5093             self.add_patch(poly)
#
# ...
