# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
df.style
# Out:
# <style  type="text/css" >
# </style><table id="T_5f7bed10_b5ea_11e9_ae75_54ee75f33bb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f7bed10_b5ea_11e9_ae75_54ee75f33bb6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5f7bed10_b5ea_11e9_ae75_54ee75f33bb6row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5f7bed10_b5ea_11e9_ae75_54ee75f33bb6row0_col1" class="data row0 col1" >1.32921</td>
#                         <td id="T_5f7bed10_b5ea_11e9_ae75_54ee75f33bb6row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color # 颜色设置

s = df.style.applymap(color_negative_red) # 按元素运行
s
# Out:
# <style  type="text/css" >
#     #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row0_col0 {
#             color:  black;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row0_col1 {
#             color:  black;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row0_col2 {
#             color:  black;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row0_col3 {
#             color:  red;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row0_col4 {
#             color:  red;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row1_col0 {
#             color:  black;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row1_col1 {
#             color:  red;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row1_col2 {
#             color:  red;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row1_col3 {
#             color:  black;
#         }    #T_5f886602_b5ea_11e9_a6c8_54ee75f33bb6row1_col4 {
#             color:  black;
# ...

# %%
df.style.applymap(color_negative_red,
                  subset=pd.IndexSlice[2:5, ['B','D']]) # 切片
# Out:
# <style  type="text/css" >
#     #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row2_col1 {
#             color:  red;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row2_col3 {
#             color:  black;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row3_col1 {
#             color:  black;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row3_col3 {
#             color:  red;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row4_col1 {
#             color:  black;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row4_col3 {
#             color:  black;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row5_col1 {
#             color:  red;
#         }    #T_5f8d92a2_b5ea_11e9_9f21_54ee75f33bb6row5_col3 {
#             color:  black;
# ...

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max] # 背景色设置

df.style.apply(highlight_max, axis=1) # 一次传递一列
# Out:
# <style  type="text/css" >
#     #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row0_col1 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row1_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row2_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row3_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row4_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row5_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row6_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row7_col0 {
#             background-color:  yellow;
#         }    #T_5f9ca378_b5ea_11e9_a10d_54ee75f33bb6row8_col0 {
#             background-color:  yellow;
# ...

# %%
df.style.apply(highlight_max, subset=pd.IndexSlice[:, 'B':'D']) # 切片
# Out:
# <style  type="text/css" >
#     #T_5fa48ea6_b5ea_11e9_b860_54ee75f33bb6row6_col2 {
#             background-color:  yellow;
#         }    #T_5fa48ea6_b5ea_11e9_b860_54ee75f33bb6row8_col1 {
#             background-color:  yellow;
#         }    #T_5fa48ea6_b5ea_11e9_b860_54ee75f33bb6row8_col3 {
#             background-color:  yellow;
#         }</style><table id="T_5fa48ea6_b5ea_11e9_b860_54ee75f33bb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fa48ea6_b5ea_11e9_b860_54ee75f33bb6level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max) # 同时进行多个设置
# Out:
# <style  type="text/css" >
#     #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row0_col0 {
#             color:  black;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row0_col1 {
#             color:  black;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row0_col2 {
#             color:  black;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row0_col3 {
#             color:  red;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row0_col4 {
#             color:  red;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row1_col0 {
#             color:  black;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row1_col1 {
#             color:  red;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row1_col2 {
#             color:  red;
#             : ;
#         }    #T_5fb98d76_b5ea_11e9_82a3_54ee75f33bb6row1_col3 {
# ...

# %%
def highlight_all_max(s, all_max, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    is_max = s == all_max
    attr = 'background-color: {}'.format(color)
    return attr if is_max  else ''

all_max = df.max().max()
v = df.style.applymap(highlight_all_max, color='blue', all_max=all_max)
v
# Out:
# <style  type="text/css" >
#     #T_5fc546c0_b5ea_11e9_b1d6_54ee75f33bb6row9_col0 {
#             background-color:  blue;
#         }</style><table id="T_5fc546c0_b5ea_11e9_b1d6_54ee75f33bb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fc546c0_b5ea_11e9_b1d6_54ee75f33bb6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5fc546c0_b5ea_11e9_b1d6_54ee75f33bb6row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5fc546c0_b5ea_11e9_b1d6_54ee75f33bb6row0_col1" class="data row0 col1" >1.32921</td>
# ...
