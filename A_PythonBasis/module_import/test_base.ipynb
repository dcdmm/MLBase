# %%
# `import`
# 1. 若源文件发生改变,运行test_base.py文件不能即刻生效,需重启jupyter notebook
# 2. 可以通过ctrl + 鼠标左击 进入导入库的源代码

# 自动重载模块:源文件修改后无需重启内核即可生效(整个notebook全局生效)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from base.print_hello import print_hello

print_hello('python')
# Out:
# hello: python!!

# %%
from base.print_hello1 import print_hello1

print_hello1("c++")
# Out:
# PI: 3.14159
# hello: c++!!
