# %%
import xgboost as xgb
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import OrdinalEncoder

# %%
X = datasets.fetch_covtype().data[:3000]
y = datasets.fetch_covtype().target[:3000]
X_1, X_test, y_1, y_test = train_test_split(X, y, test_size=0.1)
X_train, X_va, y_train, y_va = train_test_split(X_1, y_1)

print(X_train.shape, y_train.shape)
print(np.unique(y_train))  # 7分类任务
# Out:
# (2025, 54) (2025,)
# [1 2 3 4 5 6 7]

# %%
enc = OrdinalEncoder()
y_train_enc = enc.fit_transform(y_train.reshape(-1, 1)).reshape(-1, )
y_test_enc = enc.transform(y_test.reshape(-1, 1)).reshape(-1, )
y_va_enc = enc.fit_transform(y_va.reshape(-1, 1)).reshape(-1, )
print(np.unique(y_train_enc))
print(y_train_enc.shape)
# Out:
# [0. 1. 2. 3. 4. 5. 6.]
# (2025,)

# %%
# 标签格式要求:label.shape = (num_sample, )
train_dataset = xgb.DMatrix(data=X_train, label=y_train_enc)
val_dataset = xgb.DMatrix(data=X_va, label=y_va_enc)
test_dataset = xgb.DMatrix(data=X_test)

# %%
params = {'objective': 'multi:softmax',
          "eval_metric": 'mlogloss',
          "verbosity": 0,
          "max_depth": 3,
          'num_class': 7}

# train_dataset的名称为train_,val_dataset的名称定义为val_
eval_set = [(train_dataset, "train_"), (val_dataset, "val_")]
evals_result = {}  # 储存评估指标(内置和自定义)结果

# %%
from sklearn.metrics import log_loss


def my_xgb_loss(y_pred, y_true):
    """xgboost自定义验证数据集损失函数格式"""
    loss = log_loss(y_true.get_label(), y_pred)
    return 'MY_GBM_LOSS', loss

# %%
model = xgb.train(params=params,
                  dtrain=train_dataset,
                  # num_boost_round (int) – Number of boosting iterations.
                  # 默认num_boost_round=10
                  num_boost_round=200,
                  # List of validation sets for which metrics will evaluated during training.
                  evals=eval_set,
                  early_stopping_rounds=100,
                  # verbose_eval (bool or int) – Requires at least one item in evals.
                  # If verbose_eval is True then the evaluation metric on the validation set is printed at each boosting stage.
                  # If verbose_eval is an integer then the evaluation metric on the validation set is printed at every given verbose_eval boosting stage.
                  # The last boosting stage / the boosting stage found by using
                  verbose_eval=20,  # 默认verbose_eval=True
                  evals_result=evals_result,
                  feval=my_xgb_loss,
                  )
# Out:
# [0]	train_-mlogloss:1.48348	train_-MY_GBM_LOSS:1.34955	val_-mlogloss:1.52273	val_-MY_GBM_LOSS:1.38820
# [20]	train_-mlogloss:0.41501	train_-MY_GBM_LOSS:0.67774	val_-mlogloss:0.57203	val_-MY_GBM_LOSS:1.07709
# [40]	train_-mlogloss:0.27703	train_-MY_GBM_LOSS:0.55718	val_-mlogloss:0.50226	val_-MY_GBM_LOSS:1.23239
# [60]	train_-mlogloss:0.20692	train_-MY_GBM_LOSS:0.48820	val_-mlogloss:0.47789	val_-MY_GBM_LOSS:1.14027
# [80]	train_-mlogloss:0.16591	train_-MY_GBM_LOSS:0.44838	val_-mlogloss:0.47108	val_-MY_GBM_LOSS:1.25738
# [100]	train_-mlogloss:0.13260	train_-MY_GBM_LOSS:0.41311	val_-mlogloss:0.46271	val_-MY_GBM_LOSS:1.37652
# [102]	train_-mlogloss:0.12938	train_-MY_GBM_LOSS:0.41041	val_-mlogloss:0.46224	val_-MY_GBM_LOSS:1.37304

# %%
# 预测结果为概率向量(多分类)
# test_dataset:The dmatrix storing the input
model.predict(test_dataset).shape
# Out:
# (300,)

# %%
evals_result
# Out:
# {'train_': OrderedDict([('mlogloss',
#                [1.483478,
#                 1.239187,
#                 1.076006,
#                 0.954508,
#                 0.85777,
#                 0.78456,
#                 0.729572,
#                 0.67819,
#                 0.637874,
#                 0.60021,
#                 0.567286,
#                 0.544997,
#                 0.520836,
#                 0.503902,
#                 0.485906,
#                 0.47205,
#                 0.459534,
#                 0.44724,
#                 0.435368,
#                 0.424364,
#                 0.415008,
#                 0.406925,
#                 0.396066,
#                 0.386726,
#                 0.379768,
#                 0.370347,
#                 0.364417,
#                 0.357633,
#                 0.35141,
#                 0.344348,
#                 0.33661,
#                 0.330165,
#                 0.322884,
#                 0.315585,
#                 0.308721,
#                 0.303873,
#                 0.297878,
#                 0.291752,
#                 0.287099,
#                 0.281988,
#                 0.27703,
#                 0.271695,
#                 0.2663,
#                 0.261846,
#                 0.257371,
#                 0.253559,
#                 0.249888,
#                 0.246301,
#                 0.242186,
#                 0.239162,
#                 0.235345,
#                 0.232369,
#                 0.229223,
#                 0.226568,
#                 0.22448,
#                 0.220602,
#                 0.217209,
#                 0.214069,
#                 0.211769,
#                 0.209946,
#                 0.20692,
#                 0.203704,
#                 0.2021,
#                 0.200163,
#                 0.196751,
#                 0.19417,
#                 0.191879,
#                 0.189345,
#                 0.18771,
#                 0.185565,
#                 0.183222,
#                 0.181659,
#                 0.179912,
#                 0.178589,
#                 0.175972,
#                 0.174791,
#                 0.172915,
#                 0.171016,
#                 0.169219,
#                 0.167609,
#                 0.165913,
#                 0.163954,
#                 0.161867,
#                 0.160038,
#                 0.15738,
#                 0.154644,
#                 0.152219,
#                 0.150511,
#                 0.149214,
#                 0.147418,
#                 0.145858,
#                 0.143893,
#                 0.14181,
#                 0.140643,
#                 0.139781,
#                 0.138838,
#                 0.137835,
#                 0.136333,
#                 0.135305,
#                 0.13398,
#                 0.132604,
#                 0.131029,
#                 0.129379]),
#               ('MY_GBM_LOSS',
#                [1.349551,
#                 1.074838,
#                 0.776031,
#                 0.921212,
#                 0.926409,
#                 0.915833,
#                 0.932059,
#                 0.90119,
#                 0.906572,
#                 0.856273,
#                 0.828066,
#                 0.801884,
#                 0.79103,
#                 0.790128,
#                 0.786473,
#                 0.782339,
#                 0.738715,
#                 0.731024,
#                 0.723833,
#                 0.712853,
#                 0.677739,
#                 0.673643,
#                 0.670086,
#                 0.661742,
#                 0.6547,
#                 0.648679,
#                 0.643465,
#                 0.638221,
#                 0.634471,
#                 0.627196,
#                 0.623226,
#                 0.618255,
#                 0.612952,
#                 0.605271,
#                 0.600345,
#                 0.59762,
#                 0.591866,
#                 0.586126,
#                 0.582163,
#                 0.577029,
#                 0.557176,
#                 0.568216,
#                 0.560402,
#                 0.541433,
#                 0.536112,
#                 0.533063,
#                 0.530005,
#                 0.525451,
#                 0.522827,
#                 0.520998,
#                 0.51667,
#                 0.514496,
#                 0.511288,
#                 0.506854,
#                 0.505374,
#                 0.502694,
#                 0.498817,
#                 0.494684,
#                 0.491828,
#                 0.491613,
#                 0.4882,
#                 0.483607,
#                 0.482848,
#                 0.480399,
#                 0.477805,
#                 0.475031,
#                 0.471211,
#                 0.469159,
#                 0.466949,
#                 0.464159,
#                 0.46329,
#                 0.462331,
#                 0.460383,
#                 0.458296,
#                 0.457685,
#                 0.456306,
#                 0.454576,
#                 0.452246,
#                 0.451422,
#                 0.449849,
#                 0.448378,
#                 0.447146,
#                 0.444834,
#                 0.443184,
#                 0.43969,
#                 0.437244,
#                 0.434143,
#                 0.433155,
#                 0.431497,
#                 0.429722,
#                 0.427122,
#                 0.423766,
#                 0.422324,
#                 0.421334,
#                 0.420657,
#                 0.419444,
#                 0.41856,
#                 0.417655,
#                 0.416574,
#                 0.414595,
#                 0.413106,
#                 0.41238,
#                 0.410411])]),
#  'val_': OrderedDict([('mlogloss',
#                [1.522726,
#                 1.298693,
#                 1.148934,
#                 1.040968,
#                 0.952551,
#                 0.88683,
#                 0.835284,
#                 0.789619,
#                 0.752647,
#                 0.723294,
#                 0.698128,
#                 0.676238,
#                 0.655954,
#                 0.642341,
#                 0.626669,
#                 0.613643,
#                 0.604666,
#                 0.594919,
#                 0.584397,
#                 0.578362,
#                 0.57203,
#                 0.566795,
#                 0.558312,
#                 0.550816,
#                 0.546893,
#                 0.54336,
#                 0.538906,
#                 0.533513,
#                 0.529687,
#                 0.526635,
#                 0.520666,
#                 0.518737,
#                 0.515573,
#                 0.512241,
#                 0.51079,
#                 0.509229,
#                 0.507327,
#                 0.506033,
#                 0.504817,
#                 0.504581,
#                 0.502259,
#                 0.499634,
#                 0.497928,
#                 0.49626,
#                 0.494068,
#                 0.493336,
#                 0.491651,
#                 0.491394,
#                 0.490458,
#                 0.488583,
#                 0.488439,
#                 0.485384,
#                 0.484132,
#                 0.483747,
#                 0.483043,
#                 0.48135,
#                 0.482191,
#                 0.481385,
#                 0.481081,
#                 0.479401,
#                 0.477886,
#                 0.477185,
#                 0.476454,
#                 0.47674,
#                 0.474665,
#                 0.474276,
#                 0.472878,
#                 0.472837,
#                 0.473369,
#                 0.472897,
#                 0.473861,
#                 0.473455,
#                 0.473616,
#                 0.4727,
#                 0.471997,
#                 0.47112,
#                 0.471922,
#                 0.471041,
#                 0.470287,
#                 0.470513,
#                 0.471082,
#                 0.469466,
#                 0.468826,
#                 0.467186,
#                 0.465795,
#                 0.463705,
#                 0.46294,
#                 0.463719,
#                 0.463532,
#                 0.463525,
#                 0.464052,
#                 0.462941,
#                 0.461983,
#                 0.461693,
#                 0.461767,
#                 0.461537,
#                 0.462896,
#                 0.462917,
#                 0.461296,
#                 0.46239,
#                 0.462711,
#                 0.462544,
#                 0.462242]),
#               ('MY_GBM_LOSS',
#                [1.388198,
#                 1.124752,
#                 0.888959,
#                 1.337507,
#                 1.386572,
#                 1.380249,
#                 1.424691,
#                 1.410941,
#                 1.415126,
#                 1.318806,
#                 1.22372,
#                 1.165594,
#                 1.159641,
#                 1.153852,
#                 1.152518,
#                 1.145753,
#                 1.098276,
#                 1.094801,
#                 1.085116,
#                 1.077141,
#                 1.077094,
#                 1.072551,
#                 1.070859,
#                 1.018334,
#                 1.012527,
#                 1.104488,
#                 1.103935,
#                 1.094294,
#                 1.089739,
#                 1.181876,
#                 1.222588,
#                 1.219065,
#                 1.256742,
#                 1.253441,
#                 1.251728,
#                 1.247432,
#                 1.244224,
#                 1.196247,
#                 1.242301,
#                 1.284638,
#                 1.232394,
#                 1.230574,
#                 1.226657,
#                 1.226613,
#                 1.224149,
#                 1.222783,
#                 1.220943,
#                 1.217731,
#                 1.214484,
#                 1.21235,
#                 1.207714,
#                 1.204841,
#                 1.207483,
#                 1.250519,
#                 1.247465,
#                 1.157389,
#                 1.153742,
#                 1.151215,
#                 1.146609,
#                 1.146729,
#                 1.140268,
#                 1.192123,
#                 1.1872,
#                 1.229445,
#                 1.227924,
#                 1.182886,
#                 1.225055,
#                 1.223721,
#                 1.268069,
#                 1.266764,
#                 1.268531,
#                 1.313556,
#                 1.265469,
#                 1.262606,
#                 1.264322,
#                 1.263729,
#                 1.263543,
#                 1.260331,
#                 1.259454,
#                 1.259332,
#                 1.257382,
#                 1.302823,
#                 1.299959,
#                 1.299101,
#                 1.256094,
#                 1.247556,
#                 1.293679,
#                 1.293501,
#                 1.342899,
#                 1.338762,
#                 1.335562,
#                 1.331656,
#                 1.332537,
#                 1.332014,
#                 1.330127,
#                 1.329585,
#                 1.377249,
#                 1.376741,
#                 1.376102,
#                 1.421911,
#                 1.376518,
#                 1.376317,
#                 1.373039])])}

# %%
evals_result['train_'].keys()
# Out:
# odict_keys(['mlogloss', 'MY_GBM_LOSS'])

# %%
# 绘制特征的相对重要性
xgb.plot_importance(model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# 可视化lgb分割过程
img = xgb.to_graphviz(model,
                      # 目标函数是所有树的预测值相加等于预测值
                      num_trees=0)
# leaf=-0.15269695
# leaf=0.056757
# leaf=-0.125725
# leaf=-0.160423
# ......
# 表示xgboost论文中的$ \mathcal{L}_split $(决定特征的最佳分裂点)
img

# %%
# 数据类型graphviz.files.Source
type(img)
# Out:
# graphviz.sources.Source

# %%
# Parse a boosted tree model text dump into a pandas DataFrame structure.
# This feature is only defined when the decision tree model is chosen as base learner (booster in {gbtree, dart}).
df = model.trees_to_dataframe()
df.head()
# Out:
#    Tree  Node   ID Feature   Split  Yes    No Missing        Gain       Cover  \
# 0     0     0  0-0      f0  3003.5  0-1   0-2     0-1  342.961212  495.918396
# 1     0     1  0-1      f5  2894.0  0-3   0-4     0-3   26.477249  377.877563
# 2     0     2  0-2      f5  2905.0  0-5   0-6     0-5   46.089783  118.040825
# 3     0     3  0-3      f0  2936.5  0-7   0-8     0-7    4.924873  310.530640
# 4     0     4  0-4      f9  2145.0  0-9  0-10     0-9    6.405077   67.346947
#
#    Category
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# 决策路径
df[df['Tree'] == 0]
# Out:
#     Tree  Node    ID Feature   Split   Yes    No Missing        Gain  \
# 0      0     0   0-0      f0  3003.5   0-1   0-2     0-1  342.961212
# 1      0     1   0-1      f5  2894.0   0-3   0-4     0-3   26.477249
# 2      0     2   0-2      f5  2905.0   0-5   0-6     0-5   46.089783
# 3      0     3   0-3      f0  2936.5   0-7   0-8     0-7    4.924873
# 4      0     4   0-4      f9  2145.0   0-9  0-10     0-9    6.405077
# 5      0     5   0-5      f1    77.5  0-11  0-12    0-11   14.424637
# 6      0     6   0-6      f7   244.5  0-13  0-14    0-13   21.541412
# 7      0     7   0-7    Leaf     NaN   NaN   NaN     NaN   -0.153506
# 8      0     8   0-8    Leaf     NaN   NaN   NaN     NaN    0.053165
# 9      0     9   0-9    Leaf     NaN   NaN   NaN     NaN   -0.080215
# 10     0    10  0-10    Leaf     NaN   NaN   NaN     NaN    0.119268
# 11     0    11  0-11    Leaf     NaN   NaN   NaN     NaN    0.438632
# 12     0    12  0-12    Leaf     NaN   NaN   NaN     NaN    0.016920
# 13     0    13  0-13    Leaf     NaN   NaN   NaN     NaN    0.643738
# 14     0    14  0-14    Leaf     NaN   NaN   NaN     NaN    0.171057
#
#          Cover  Category
# 0   495.918396       NaN
# 1   377.877563       NaN
# 2   118.040825       NaN
# 3   310.530640       NaN
# 4    67.346947       NaN
# 5    31.836737       NaN
# 6    86.204086       NaN
# 7   300.244934       NaN
# 8    10.285715       NaN
# 9    19.836737       NaN
# 10   47.510208       NaN
# 11   10.040817       NaN
# 12   21.795919       NaN
# 13   75.428574       NaN
# 14   10.775511       NaN
