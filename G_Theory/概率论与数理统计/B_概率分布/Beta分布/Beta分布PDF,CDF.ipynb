# %% [markdown]
# ## 概率密度函数(Probability Density Function)

# %%
from scipy.stats import beta

# additional import for plotting
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15, 8), dpi=100)
ax = plt.subplot(111)

# continuous pdf for the plot
x_s = np.linspace(0, 1, 100)
y_s = beta.pdf(a=2, b=2, x=x_s)
ax.scatter(x_s, y_s);

# %% [markdown]
# ## Cumulative Probability Density Function

# %%
from scipy.stats import beta

# probability of x less or equal 0.3
print("P(X <0.3) = {:.3}".format(beta.cdf(a=2, b=2, x=0.3)))

# probability of x in [0.1, +0.2]
print("P(0.1 < X < 0.2) = {:.3}".format(beta.cdf(a=2, b=2, x=0.2) - beta.cdf(a=2, b=2, x=0.1)))
# Out:
# P(X <0.3) = 0.216
# P(0.1 < X < 0.2) = 0.076
