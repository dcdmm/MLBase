# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('paper')  # 设置全局context parameters
'''
seaborn.set_context(context=None, font_scale=1, rc=None)
Set the plotting context parameters.
    
    Parameters:	
    context : dict, None, or one of {paper, notebook, talk, poster}
'''
fig = plt.figure(figsize=(10, 25))

with sns.plotting_context('poster'):
    # 设置局部context parameters,用with做代码块区分
    ax1 = plt.subplot(311)
    plt.plot(np.c_[np.zeros(8), np.arange(8)].T)

ax2 = plt.subplot(312)


def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(7):
        plt.plot(x, np.sin(x + i * 0.5) * (7 - i) * flip)


sinplot()

data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
ax3 = plt.subplot(313)
ax3.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x1d83819f898>,
#  <matplotlib.lines.Line2D at 0x1d83819f9e8>,
#  <matplotlib.lines.Line2D at 0x1d83819fb38>,
#  <matplotlib.lines.Line2D at 0x1d83819fc88>,
#  <matplotlib.lines.Line2D at 0x1d83819fdd8>,
#  <matplotlib.lines.Line2D at 0x1d83819ff28>]
